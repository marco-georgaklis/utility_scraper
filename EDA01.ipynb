# %% [markdown]
# # Exploratory Data Analysis: Web Scraping Utilities with Beautiful Soup
#
# In this notebook, I hope to create a parser for web scraping the linux man pages to gather information on some of the most common utilities and their corresponding flags.

# %%
import requests
from bs4 import BeautifulSoup

# %%
# some of the most common utilities
utilities = [
    "find",
    "xargs",
    "grep",
    "rm",
    "echo",
    "ls",
    "sort",
    "chmod",
    "wc",
    "cat",
    "cut",
    "head",
    "mv",
    "chown",
    "cp",
    "mkdir",
    "tr",
    "tail",
    "dirname",
    "tar",
    "uniq",
    "ln",
    "split",
    "tee",
    "date",
    "pwd",
    "ssh",
    "diff",
    "du",
    "file",
    "rename",
    "md5sum",
    "comm",
    "mktemp",
    "df",
    "rev",
    "rmdir",
    "od",
    "hostname",
]
len(utilities)
# Out:
# 39

# %% [markdown]
# ## Finding Flags for 1 Utility
# First, we want to create a parser to find the available flags for just one of the utilities. We will start with the 'find' utility and use the BeautifulSoup package to parse for the corresponding flags.

# %%
utility = "uniq"
utility_url = f'https://man7.org/linux/man-pages/man1/{utility}.1.html'
r = requests.get(utility_url)
soup = BeautifulSoup(r.text)
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    uniq(1) - Linux manual page
#   </title>
#   <link href="../../../style.css" rel="stylesheet" title="style" type="text/css"/>
#   <link href="../style.css" rel="stylesheet" title="style" type="text/css"/>
#  </head>
#  <body>
#   <div class="page-top">
#    <a id="top_of_page">
#    </a>
#   </div>
#   <!--%%%TOP_BAR%%%-->
#   <div class="nav-bar">
#    <table class="nav-table">
#     <tr>
#      <td class="nav-cell">
#       <p class="nav-text">
#        <a href="../../../index.html">
#         man7.org
#        </a>
#        &gt; Linux &gt;
#        <a href="../index.html">
#         man-pages
#        </a>
#       </p>
#      </td>
#      <td class="training-cell">
#       <p class="training-text">
#        <a class="training-link" href="http://man7.org/training/">
#         Linux/UNIX system programming training
#        </a>
#       </p>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <hr cl

# %% [markdown]
# The syntax example could definitely be extremely useful in the future when creating the generator and determining the order in which to assemble the options and arguments.

# %%
desc = soup.find_all('pre')[2].text
print(desc)
# Out:
#        uniq [OPTION]... [INPUT [OUTPUT]]

# %%
options = "\n".join([soup.find_all('pre')[3].text, soup.find_all('pre')[4].text])
print(options[:500])
# Out:
#        Filter adjacent matching lines from INPUT (or standard input),
#        writing to OUTPUT (or standard output).
#
#        With no options, matching lines are merged to the first
#        occurrence.
#
#        Mandatory arguments to long options are mandatory for short
#        options too.
#
#        -c, --count
#               prefix lines by the number of occurrences
#
#        -d, --repeated
#               only print duplicate lines, one for each group
#
#        -D     print all duplicate lines
#
#        --

# %%
# extracting and cleaning the corresponding flags
punctuation = set(_ for _ in ",.()")
stripped_options = [line.strip() for line in options.split('\n')]
flag_lines = list(filter(lambda x: x and x[0] == "-", stripped_options))
flags = [line.split(" ")[0] for line in flag_lines]
clean_flags = [f if f[-1] not in punctuation else f[:-1] for f in flags]
clean_flags = [f if "[" not in f else f.split("[")[0] for f in clean_flags]
set(clean_flags)
# Out:
# {'--all-repeated',
#  '--group',
#  '--help',
#  '--version',
#  '-D',
#  '-c',
#  '-d',
#  '-f',
#  '-i',
#  '-s',
#  '-u',
#  '-w',
#  '-z'}

# %% [markdown]
# ## Scaling for all of our utilities
#
# Now that we've been able to get a list of flags for one of our utilities, we can scale the solution to collect all of the available flags for each utility in our list of 23 utilities. To do this, we will apply the same parsing above to each utility webpage.

# %%
data = {}
descs = {}

# %%
for utility in utilities:
    utility_url = f'https://man7.org/linux/man-pages/man1/{utility}.1.html'
    r = requests.get(utility_url)
    soup = BeautifulSoup(r.text)
    desc = soup.find_all('pre')[2].text
    descs[utility] = desc.split('\n')[1].strip()
    pre_len = len(soup.find_all('pre'))
    options = "\n".join([soup.find_all('pre')[i].text for i in range(3, pre_len)])
    stripped_options = [line.strip() for line in options.split('\n')]
    flag_lines = list(filter(lambda x: x and x[0] == "-", stripped_options))
    clean_flags = flag_lines
    d = set(flag for flag in clean_flags)
    data[utility] = {}
    data[utility]['lines'] = d
    print(desc)
# Out:
#        find [-H] [-L] [-P] [-D debugopts] [-Olevel] [starting-point...]
#        [expression]
#
#
#        xargs [options] [command [initial-arguments]]
#
#
#        grep [OPTION...] PATTERNS [FILE...]
#        grep [OPTION...] -e PATTERNS ... [FILE...]
#        grep [OPTION...] -f PATTERN_FILE ... [FILE...]
#
#
#        rm [OPTION]... [FILE]...
#
#
#        echo [SHORT-OPTION]... [STRING]...
#        echo LONG-OPTION
#
#
#        ls [OPTION]... [FILE]...
#
#
#        sort [OPTION]... [FILE]...
#        sort [OPTION]... --files0-from=F
#
#
#        chmod [OPTION]... MODE[,MODE]... FILE...
#        chmod [OPTION]... OCTAL-MODE FILE...
#        chmod [OPTION]... --reference=RFILE FILE...
#
#
#        wc [OPTION]... [FILE]...
#        wc [OPTION]... --files0-from=F
#
#
#        cat [OPTION]... [FILE]...
#
#
#        cut OPTION... [FILE]...
#
#
#        head [OPTION]... [FILE]...
#
#
#        mv [OPTION]... [-T] SOURCE DEST
#        mv [OPTION]... SOURCE... DIRECTORY
#        mv [OPTION]... -t DIRECTORY SOURCE...
#
#
#        chown [OPTION]... [OWNER][:[GROUP]] FILE...
#        chown [OPTION]... --reference=RFILE FILE...
#
#
#        cp [OPTION]... [-T] SOURCE DEST
#        cp [OPTION]... SOURCE... DIRECTORY
#        cp [OPTION]... -t DIRECTORY SOURCE...
#
#
#        mkdir [OPTION]... DIRECTORY...
#
#
#        tr [OPTION]... SET1 [SET2]
#
#
#        tail [OPTION]... [FILE]...
#
#
#        dirname [OPTION] NAME...
#
#
#    Traditional usage
#        tar {A|c|d|r|t|u|x}[GnSkUWOmpsMBiajJzZhPlRvwo] [ARG...]
#
#    UNIX-style usage
#        tar -A [OPTIONS] ARCHIVE ARCHIVE
#
#        tar -c [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -d [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -t [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#        tar -r [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -u [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -x [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#    GNU-style usage
#        tar {--catenate|--concatenate} [OPTIONS] ARCHIVE ARCHIVE
#
#        tar --create [--file ARCHIVE] [OPTIONS] [FILE...]
#
#        tar {--diff|--compare} [--file ARCHIVE] [OPTIONS] [FILE...]
#
#        tar --delete [--file ARCHIVE] [OPTIONS] [MEMBER...]
#
#        tar --append [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar --list [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#        tar --test-label [--file ARCHIVE] [OPTIONS] [LABEL...]
#
#        tar --update [--file ARCHIVE] [OPTIONS] [FILE...]
#
#        tar --update [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar {--extract|--get} [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#
#        uniq [OPTION]... [INPUT [OUTPUT]]
#
#
#        ln [OPTION]... [-T] TARGET LINK_NAME
#        ln [OPTION]... TARGET
#        ln [OPTION]... TARGET... DIRECTORY
#        ln [OPTION]... -t DIRECTORY TARGET...
#
#
#        split [OPTION]... [FILE [PREFIX]]
#
#
#        tee [OPTION]... [FILE]...
#
#
#        date [OPTION]... [+FORMAT]
#        date [-u|--utc|--universal] [MMDDhhmm[[CC]YY][.ss]]
#
#
#        pwd [OPTION]...
#
#
#      ssh [-46AaCfGgKkMNnqsTtVvXxYy] [-B bind_interface]
#          [-b bind_address] [-c cipher_spec] [-D [bind_address:]port]
#          [-E log_file] [-e escape_char] [-F configfile] [-I pkcs11]
#          [-i identity_file] [-J destination] [-L address]
#          [-l login_name] [-m mac_spec] [-O ctl_cmd] [-o option]
#          [-p port] [-Q query_option] [-R address] [-S ctl_path]
#          [-W host:port] [-w local_tun[:remote_tun]] destination
#          [command]
#
#
#        diff [OPTION]... FILES
#
#
#        du [OPTION]... [FILE]...
#        du [OPTION]... --files0-from=F
#
#
#      file [-bcdEhiklLNnprsSvzZ0] [--apple] [--exclude-quiet]
#           [--extension] [--mime-encoding] [--mime-type] [-e testname]
#           [-F separator] [-f namefile] [-m magicfiles] [-P name=value]
#           file ...
#      file -C [-m magicfiles]
#      file [--help]
#
#
#        rename [options] expression replacement file...
#
#
#        md5sum [OPTION]... [FILE]...
#
#
#        comm [OPTION]... FILE1 FILE2
#
#
#        mktemp [OPTION]... [TEMPLATE]
#
#
#        df [OPTION]... [FILE]...
#
#
#        rev [option] [file...]
#
#
#        rmdir [OPTION]... DIRECTORY...
#
#
#        od [OPTION]... [FILE]...
#        od [-abcdfilosx]... [FILE] [[+]OFFSET[.][b]]
#        od --traditional [OPTION]... [FILE] [[+]OFFSET[.][b]
#        [+][LABEL][.][b]]
#
#
#        hostname [-v] [-s|--short]
#
#        hostname [-v] [-a|--alias] [-d|--domain] [-f|--fqdn|--long]
#        [-i|--ip-address]
#
#        hostname [-v] [-y|--yp|--nis] [-n|--node]
#
#        hostname [-v] [-F filename|--file filename] [newname]
#
#        domainname [-v] [-F filename|--file filename] [newname]
#
#        nodename [-v] [-F filename|--file filename] [newname]
#
#        hostname [-v|--verbose] [-h|--help] [-V|--version]
#
#        dnsdomainname [-v]
#        nisdomainname [-v]
#        ypdomainname [-v]

# %%
data
# Out:
# {'find': {'lines': {'-D                     4.3.1',
#    '-D debugopts',
#    '-D help.  Valid debug options include',
#    '-H                     4.2.5      POSIX',
#    '-H     Do not follow symbolic links, except while processing the',
#    '-H     This option is supported.',
#    '-H option or the -L option is in effect, then the time of',
#    '-H, -L and -P and any previous -follow, but the reference file is',
#    '-L                     4.2.5      POSIX',
#    '-L     Follow symbolic links.  When find examines or prints',
#    '-L     This option is supported.',
#    '-O                     4.3.1',
#    '-Olevel',
#    '-P                     4.2.5      BSD',
#    '-P     Never follow symbolic links.  This is the default',
#    '-amin n',
#    '-anewer reference',
#    '-atime n',
#    '-cmin n',
#    '-cnewer reference',
#    '-cnewer.',
#    '-context pattern',
#    '-ctime n',
#    '-d                     4.2.3      BSD',
#    '-d     A synonym for -depth, for compatibility with FreeBSD,',
#    '-daystart',
#    '-delete',
#    '-delete                4.2.3',
#    '-delete implies -depth, you cannot usefully use -prune and',
#    '-delete together.  For example, to skip the directory',
#    '-delete, -exec, -execdir, -ok, -okdir, -fls, -fprint, -fprintf,',
#    "-depth Process each directory's contents before the directory",
#    '-depth).',
#    '-empty File is empty and is either a regular file or a directory.',
#    '-exec ... +            4.2.12     POSIX',
#    '-exec command ;',
#    '-exec command {} +',
#    '-exec, the {} should be quoted if find is being invoked',
#    '-execdir               4.2.12     BSD',
#    '-execdir command ;',
#    '-execdir command {} +',
#    '-execdir option instead.',
#    '-execdir should be used instead.',
#    '-execdir, -ok and -okdir',
#    '-executable',
#    '-executable            4.3.0',
#    '-false Always false.',
#    '-files0-from           4.9.0',
#    '-files0-from - to read the list of starting points from',
#    '-files0-from file',
#    '-files0-from to pass arbitrary starting points to find.',
#    '-fls                   4.0',
#    '-fls file',
#    '-follow',
#    '-fprint file',
#    '-fprint0 file',
#    '-fprintf action can be used to list the various matched',
#    '-fprintf file format',
#    '-fprintf.  If you are using find in a script or in a',
#    '-fstype type',
#    "-gid n File's numeric group ID is less than, more than or exactly",
#    '-group gname',
#    '-help, --help',
#    '-ignore_readdir_race',
#    '-ignore_readdir_race   4.2.0',
#    '-ilname                3.8',
#    '-ilname pattern',
#    '-iname                 3.8',
#    '-iname pattern',
#    '-inum n',
#    '-ipath                 3.8',
#    '-ipath pattern',
#    '-ipath.',
#    '-iregex                3.8',
#    '-iregex pattern',
#    '-iwholename            4.2.0',
#    '-iwholename pattern',
#    '-links n',
#    '-links, -mtime, -nogroup, -nouser, -ok, -path, -print,',
#    '-lname pattern',
#    '-ls    True; list current file in ls -dils format on standard',
#    '-ls, -fls',
#    '-ls, -print and -printf.',
#    '-maxdepth levels',
#    '-mindepth levels',
#    '-mmin n',
#    "-mount Don't descend directories on other filesystems.  An",
#    '-mtime n',
#    '-mtime, -gid, -inum, -links, -size, -uid and -used) as',
#    '-n     for less than n,',
#    '-name  This option is supported, but POSIX conformance depends on',
#    '-name afile -o -name bfile -print will never print afile.',
#    '-name pattern',
#    '-newer Supported.  If the file specified is a symbolic link, it',
#    '-newer reference',
#    '-newerXY               4.3.3      BSD',
#    '-newerXY reference',
#    '-newerXY, -anewer and -cnewer.  Similarly, the -type',
#    '-nogroup',
#    '-noignore_readdir_race',
#    '-noleaf',
#    '-noleaf.  If you later use the -P option, -noleaf will',
#    '-not expr',
#    '-nouser',
#    '-o is in parentheses only for clarity.  It emphasises that',
#    '-ok    Supported.  Interpretation of the response is according to',
#    '-ok command ;',
#    '-okdir                 4.2.12',
#    '-okdir command ;',
#    "-or -exec test -d '{}/.git' \\; \\",
#    "-or -exec test -d '{}/CVS' \\; \\",
#    '-path pattern',
#    '-perm  Supported.  If the POSIXLY_CORRECT environment variable is',
#    '-perm +mode',
#    '-perm -mode',
#    '-perm /mode',
#    '-perm mode',
#    '-print True; print the full file name on the standard output,',
#    '-print action for example prints the name of the current',
#    '-print, -fprint',
#    '-print.',
#    '-print0',
#    '-print0, -fprint0',
#    '-printf format',
#    '-printf, -fprintf',
#    '-prune True; if the file is a directory, do not descend into it.',
#    '-prune or -quit.  Actions which inhibit the default -print are',
#    '-prune, -size, -user and -xdev are all supported.',
#    '-quit                  4.2.3',
#    '-quit  Exit immediately (with return value zero if no errors have',
#    '-quit simply makes find stop immediately.  No child',
#    '-readable',
#    '-readable              4.3.0',
#    '-regex pattern',
#    '-regex) are performed first.',
#    '-regextype             4.2.24',
#    '-regextype help.  The Texinfo documentation (see SEE ALSO)',
#    '-regextype option for example is positional, specifying',
#    '-regextype type',
#    '-samefile              4.2.11',
#    '-samefile name',
#    '-size n[cwbkMG]',
#    '-true  Always true.',
#    "-type  Supported.  POSIX specifies `b', `c', `d', `l', `p', `f'",
#    '-type c',
#    "-uid n File's numeric user ID is less than, more than or exactly",
#    '-used n',
#    '-user uname',
#    '-version, --version',
#    '-warn, -nowarn',
#    '-wholename             4.2.0',
#    '-wholename pattern',
#    '-writable',
#    '-writable              4.3.0',
#    "-xdev  Don't descend directories on other filesystems.",
#    '-xtype c'}},
#  'xargs': {'lines': {'--delimiter=delim, -d delim',
#    '--help Print a summary of the options to xargs and exit.',
#    '--process-slot-var=name',
#    '--show-limits',
#    '--version',
#    '-0, --null',
#    '-E eof-str',
#    '-I replace-str',
#    '-L max-lines',
#    '-P max-procs, --max-procs=max-procs',
#    '-P option.',
#    '-a file, --arg-file=file',
#    '-e[eof-str], --eof[=eof-str]',
#    '-i[replace-str], --replace[=replace-str]',
#    '-l[max-lines], --max-lines[=max-lines]',
#    '-n max-args, --max-args=max-args',
#    '-o, --open-tty',
#    '-p, --interactive',
#    '-r, --no-run-if-empty',
#    '-s max-chars, --max-chars=max-chars',
#    '-s option to increase the amount of buffer space that xargs uses,',
#    '-s option) is exceeded, unless the -x option is given, in',
#    '-t, --verbose',
#    '-x, --exit'}},
#  'grep': {'lines': {'--binary-files=TYPE',
#    '--binary-files=without-match option.',
#    '--color[=WHEN], --colour[=WHEN]',
#    '--count option is also used, grep does not output a count',
#    '--exclude-dir=GLOB',
#    '--exclude-from=FILE',
#    '--exclude=GLOB',
#    '--group-separator=SEP',
#    '--help Output a usage message and exit.',
#    '--include=GLOB',
#    '--label=LABEL',
#    '--line-buffered',
#    '--no-group-separator',
#    '--no-ignore-case',
#    '--no-messages option.',
#    '--only-matching option, this has no effect and a warning',
#    '-A NUM, --after-context=NUM',
#    '-B NUM, --before-context=NUM',
#    '-C NUM, -NUM, --context=NUM',
#    '-D ACTION, --devices=ACTION',
#    '-E, --extended-regexp',
#    '-F, --fixed-strings',
#    '-G, --basic-regexp',
#    '-H, --with-filename',
#    '-I     Process a binary file as if it did not contain matching',
#    '-L, --files-without-match',
#    '-P, --perl-regexp',
#    '-R, --dereference-recursive',
#    '-T, --initial-tab',
#    '-U, --binary',
#    '-V, --version',
#    '-Z, --null',
#    '-a, --text',
#    '-b, --byte-offset',
#    '-c, --count',
#    '-d ACTION, --directories=ACTION',
#    '-d recurse option.',
#    '-e PATTERNS, --regexp=PATTERNS',
#    '-f FILE, --file=FILE',
#    '-h, --no-filename',
#    '-i, --ignore-case',
#    '-l, --files-with-matches',
#    '-m NUM, --max-count=NUM',
#    '-n option outputs line numbers, the -- argument treats expansions',
#    '-n, --line-number',
#    '-o, --only-matching',
#    '-q or --quiet or --silent is used and a line is selected, the',
#    '-q, --quiet, --silent',
#    '-r, --recursive',
#    '-s, --no-messages',
#    '-v command-line option is omitted, or a context line when',
#    '-v is specified).  The default is 01;31, which means a',
#    '-v, --invert-match',
#    '-w, --word-regexp',
#    '-x, --line-regexp',
#    '-y     Obsolete synonym for -i.',
#    '-z, --null-data',
#    '-z, and xargs -0 to process arbitrary file names, even'}},
#  'rm': {'lines': {'--help display this help and exit',
#    '--interactive=always option is given, rm prompts the user for',
#    '--interactive[=WHEN]',
#    '--no-preserve-root',
#    '--one-file-system',
#    '--preserve-root[=all]',
#    '--version',
#    '-I     prompt once before removing more than three files, or when',
#    '-d, --dir',
#    '-f, --force',
#    '-i     prompt before every removal',
#    '-r, -R, --recursive',
#    '-v, --verbose'}},
#  'echo': {'lines': {'--help display this help and exit',
#    '--version',
#    '-E     disable interpretation of backslash escapes (default)',
#    '-e     enable interpretation of backslash escapes',
#    '-n     do not output the trailing newline'}},
#  'ls': {'lines': {'--author',
#    '--block-size=SIZE',
#    '--color[=WHEN]',
#    '--dereference-command-line-symlink-to-dir',
#    '--file-type',
#    '--format=WORD',
#    '--full-time',
#    '--group-directories-first',
#    '--help display this help and exit',
#    '--hide=PATTERN',
#    '--hyperlink[=WHEN]',
#    '--indicator-style=WORD',
#    '--quoting-style=WORD',
#    '--show-control-chars',
#    '--si   likewise, but use powers of 1000 not 1024',
#    '--sort is specified.',
#    '--sort=WORD',
#    '--sort=none (-U) disables grouping',
#    '--sort=time, sort by WORD (newest first)',
#    '--time-style=TIME_STYLE',
#    '--time=WORD',
#    '--version',
#    "-1     list one file per line.  Avoid '\\n' with -q or -b",
#    '-A, --almost-all',
#    '-B, --ignore-backups',
#    '-C     list entries by columns',
#    '-D, --dired',
#    '-F, --classify',
#    '-G, --no-group',
#    '-H, --dereference-command-line',
#    '-I, --ignore=PATTERN',
#    '-L, --dereference',
#    '-N, --literal',
#    '-Q, --quote-name',
#    '-R, --recursive',
#    '-S     sort by file size, largest first',
#    '-T, --tabsize=COLS',
#    '-U     do not sort; list entries in directory order',
#    '-X     sort alphabetically by entry extension',
#    '-Z, --context',
#    '-a, --all',
#    '-b, --escape',
#    '-c     with -lt: sort by, and show, ctime (time of last',
#    '-d, --directory',
#    '-f     do not sort, enable -aU, disable -ls --color',
#    '-g     like -l, but do not list owner',
#    '-h, --human-readable',
#    '-i, --inode',
#    '-k, --kibibytes',
#    '-l     use a long listing format',
#    '-m     fill width with a comma separated list of entries',
#    '-n, --numeric-uid-gid',
#    '-o     like -l, but do not list group information',
#    '-p, --indicator-style=slash',
#    '-q, --hide-control-chars',
#    '-r, --reverse',
#    '-s and per directory totals',
#    '-s, --size',
#    '-t     sort by time, newest first; see --time',
#    '-u     with -lt: sort by, and show, access time; with -l: show',
#    '-v     natural sort of (version) numbers within text',
#    '-w, --width=COLS',
#    '-x     list entries by lines instead of by columns'}},
#  'sort': {'lines': {'--batch-size=NMERGE',
#    '--compress-program=PROG',
#    '--debug',
#    '--files0-from=F',
#    '--help display this help and exit',
#    '--parallel=N',
#    '--random-source=FILE',
#    '--sort=WORD',
#    '--version',
#    '-C, --check=quiet, --check=silent',
#    '-M, --month-sort',
#    '-R, --random-sort',
#    '-S, --buffer-size=SIZE',
#    '-T, --temporary-directory=DIR',
#    '-V, --version-sort',
#    '-b, --ignore-leading-blanks',
#    '-c, --check, --check=diagnose-first',
#    '-d',
#    '-d, --dictionary-order',
#    '-f, --ignore-case',
#    '-g, --general-numeric-sort',
#    '-h, --human-numeric-sort',
#    '-h, month -M, numeric -n, random -R, version -V',
#    '-i, --ignore-nonprinting',
#    '-k, --key=KEYDEF',
#    '-m, --merge',
#    '-n, --numeric-sort',
#    '-o, --output=FILE',
#    '-r, --reverse',
#    '-s, --stable',
#    '-t, --field-separator=SEP',
#    '-u, --unique',
#    '-z, --zero-terminated'}},
#  'chmod': {'lines': {'--help display this help and exit',
#    '--no-preserve-root',
#    '--preserve-root',
#    '--reference=RFILE',
#    '--version',
#    '-R, --recursive',
#    '-c, --changes',
#    '-f, --silent, --quiet',
#    '-v, --verbose'}},
#  'wc': {'lines': {'--files0-from=F',
#    '--help display this help and exit',
#    '--version',
#    '-L, --max-line-length',
#    '-c, --bytes',
#    '-l, --lines',
#    '-m, --chars',
#    '-w, --words'}},
#  'cat': {'lines': {'--help display this help and exit',
#    '--version',
#    '-A, --show-all',
#    '-E, --show-ends',
#    '-T, --show-tabs',
#    '-b, --number-nonblank',
#    '-e     equivalent to -vE',
#    '-n, --number',
#    '-s, --squeeze-blank',
#    '-t     equivalent to -vT',
#    '-u     (ignored)',
#    '-v, --show-nonprinting'}},
#  'cut': {'lines': {'--complement',
#    '--help display this help and exit',
#    '--output-delimiter=STRING',
#    '--version',
#    "-M     from first to M'th (included) byte, character or field",
#    '-b, --bytes=LIST',
#    '-c, --characters=LIST',
#    '-d, --delimiter=DELIM',
#    '-f, --fields=LIST',
#    '-n     (ignored)',
#    '-s, --only-delimited',
#    '-z, --zero-terminated'}},
#  'head': {'lines': {'--help display this help and exit',
#    '--version',
#    '-c, --bytes=[-]NUM',
#    '-n, --lines=[-]NUM',
#    '-q, --quiet, --silent',
#    '-v, --verbose',
#    '-z, --zero-terminated'}},
#  'mv': {'lines': {'--backup[=CONTROL]',
#    '--help display this help and exit',
#    '--strip-trailing-slashes',
#    '--version',
#    '-S, --suffix=SUFFIX',
#    '-T, --no-target-directory',
#    '-Z, --context',
#    '-b     like --backup but does not accept an argument',
#    '-f, --force',
#    '-i, --interactive',
#    '-n, --no-clobber',
#    '-t, --target-directory=DIRECTORY',
#    '-u, --update',
#    '-v, --verbose'}},
#  'chown': {'lines': {'--dereference',
#    '--from=CURRENT_OWNER:CURRENT_GROUP',
#    '--help display this help and exit',
#    '--no-preserve-root',
#    '--preserve-root',
#    '--reference=RFILE',
#    '--version',
#    '-H     if a command line argument is a symbolic link to a',
#    '-L     traverse every symbolic link to a directory encountered',
#    '-P     do not traverse any symbolic links (default)',
#    '-R, --recursive',
#    '-c, --changes',
#    '-f, --silent, --quiet',
#    '-h, --no-dereference',
#    '-v, --verbose'}},
#  'cp': {'lines': {'--attributes-only',
#    '--backup[=CONTROL]',
#    '--context[=CTX]',
#    '--copy-contents',
#    '--help display this help and exit',
#    '--no-preserve=ATTR_LIST',
#    '--parents',
#    '--preserve[=ATTR_LIST]',
#    '--reflink[=WHEN]',
#    '--remove-destination',
#    '--sparse=WHEN',
#    '--strip-trailing-slashes',
#    '--version',
#    '-H     follow command-line symbolic links in SOURCE',
#    '-L, --dereference',
#    '-P, --no-dereference',
#    '-R, -r, --recursive',
#    '-S, --suffix=SUFFIX',
#    '-T, --no-target-directory',
#    '-Z     set SELinux security context of destination file to',
#    '-a, --archive',
#    '-b     like --backup but does not accept an argument',
#    '-d     same as --no-dereference --preserve=links',
#    '-f, --force',
#    '-i, --interactive',
#    '-l, --link',
#    '-n, --no-clobber',
#    '-p     same as --preserve=mode,ownership,timestamps',
#    '-s, --symbolic-link',
#    '-t, --target-directory=DIRECTORY',
#    '-u, --update',
#    '-v, --verbose',
#    '-x, --one-file-system'}},
#  'mkdir': {'lines': {'--context[=CTX]',
#    '--help display this help and exit',
#    '--version',
#    '-Z     set SELinux security context of each created directory to',
#    '-m, --mode=MODE',
#    '-p, --parents',
#    '-v, --verbose'}},
#  'tr': {'lines': {'--help display this help and exit',
#    '--version',
#    '-c, -C, --complement',
#    '-d, --delete',
#    '-s, --squeeze-repeats',
#    '-t, --truncate-set1'}},
#  'tail': {'lines': {'--follow=name in that case.  That causes tail to track the named',
#    '--help display this help and exit',
#    '--max-unchanged-stats=N',
#    '--pid=PID',
#    '--retry',
#    '--version',
#    '-F     same as --follow=name --retry',
#    '-c, --bytes=[+]NUM',
#    '-f, --follow[={name|descriptor}]',
#    '-n +NUM to output starting with line NUM',
#    '-n, --lines=[+]NUM',
#    '-q, --quiet, --silent',
#    '-s, --sleep-interval=N',
#    '-v, --verbose',
#    '-z, --zero-terminated'}},
#  'dirname': {'lines': {'--help display this help and exit',
#    '--version',
#    '-> "."',
#    '-> "/usr"',
#    '-> "dir1" followed by "dir2"',
#    '-z, --zero'}},
#  'tar': {'lines': {'--acls Enable POSIX ACLs support.',
#    '--add-file=FILE',
#    '--anchored',
#    '--atime-preserve[=METHOD]',
#    '--auto-compress).',
#    '--backup[=CONTROL]',
#    '--check-device',
#    '--checkpoint-action=ACTION',
#    '--checkpoint[=N]',
#    '--clamp-mtime',
#    '--delay-directory-restore',
#    '--delete',
#    '--exclude-backups',
#    '--exclude-caches',
#    '--exclude-caches-all',
#    '--exclude-caches-under',
#    '--exclude-ignore-recursive=FILE',
#    '--exclude-ignore=FILE',
#    '--exclude-tag-all=FILE',
#    '--exclude-tag-under=FILE',
#    '--exclude-tag=FILE',
#    '--exclude-vcs',
#    '--exclude-vcs-ignores',
#    '--exclude=PATTERN',
#    '--file=remotehost:/dev/sr0',
#    '--force-local',
#    '--full-time',
#    '--group-map=FILE',
#    '--group=NAME[:GID]',
#    '--hard-dereference',
#    '--help output.',
#    '--hole-detection=METHOD',
#    '--ignore-case',
#    '--ignore-command-error',
#    '--ignore-failed-read',
#    '--index-file=FILE',
#    '--keep-directory-symlink',
#    '--keep-newer-files',
#    '--level=NUMBER',
#    '--list and when a list of files is given either on the',
#    '--lzip Filter the archive through lzip(1).',
#    '--lzma Filter the archive through lzma(1).',
#    '--lzop Filter the archive through lzop(1).',
#    '--mode=CHANGES',
#    '--mtime=DATE-OR-FILE',
#    '--multi-volume, tar will keep track of which volume of a',
#    '--newer-mtime=DATE',
#    '--no-acls',
#    '--no-anchored',
#    '--no-auto-compress',
#    '--no-check-device',
#    '--no-delay-directory-restore',
#    '--no-ignore-case',
#    '--no-ignore-command-error',
#    '--no-null',
#    '--no-overwrite-dir',
#    '--no-quote-chars=STRING',
#    '--no-recursion',
#    '--no-same-owner',
#    '--no-same-permissions',
#    '--no-seek',
#    '--no-selinux',
#    '--no-unquote',
#    '--no-verbatim-files-from',
#    '--no-verbatim-files-from option is provided as a way to',
#    '--no-wildcards',
#    '--no-wildcards-match-slash',
#    '--no-xattrs',
#    '--null Instruct subsequent -T options to read null-terminated',
#    '--numeric-owner',
#    '--occurrence[=N]',
#    '--old-archive, --portability',
#    '--one-file-system',
#    '--one-top-level[=DIR]',
#    '--overwrite',
#    '--overwrite-dir',
#    '--owner-map=FILE',
#    '--owner=NAME[:UID]',
#    '--pax-option=keyword[[:]=value][,keyword[[:]=value]]...',
#    '--posix',
#    '--quote-chars=STRING',
#    '--quoting-style=STYLE',
#    '--record-size=NUMBER',
#    '--recursion',
#    '--recursive-unlink',
#    '--remove-files',
#    '--restrict',
#    '--rmt-command option.',
#    '--rmt-command=COMMAND',
#    '--rsh-command=/usr/bin/ssh',
#    '--rsh-command=COMMAND',
#    '--same-owner',
#    '--selinux',
#    '--show-defaults',
#    '--show-omitted-dirs',
#    '--show-transformed-names, --show-stored-names',
#    '--skip-old-files',
#    '--sort=ORDER',
#    '--sparse).  This option implies --sparse.  Valid argument',
#    '--sparse-version=MAJOR[.MINOR]',
#    '--strip-components=NUMBER',
#    '--suffix=STRING',
#    '--test-label',
#    '--to-command=COMMAND',
#    '--totals[=SIGNAL]',
#    '--transform=EXPRESSION, --xform=EXPRESSION',
#    '--unquote',
#    '--usage',
#    '--utc  Print file modification times in UTC.',
#    '--verbatim-files-from',
#    '--verbatim-files-from option disables this behavior.',
#    '--verbatim-files-from option or end of line, whichever',
#    '--version',
#    '--volno-file=FILE',
#    '--warning=KEYWORD',
#    '--wildcards',
#    '--wildcards-match-slash',
#    '--xattrs',
#    '--xattrs-exclude=PATTERN',
#    '--xattrs-include=PATTERN',
#    '--zstd Filter the archive through zstd(1).',
#    '-?, --help',
#    '-A, --catenate, --concatenate',
#    '-B, --read-full-records',
#    '-C, --directory=DIR',
#    '-F, --info-script=COMMAND, --new-volume-script=COMMAND',
#    '-G, --incremental',
#    '-H, --format=FORMAT',
#    '-I, --use-compress-program=COMMAND',
#    '-J, --xz',
#    '-K, --starting-file=MEMBER',
#    '-L, --tape-length=N',
#    '-M, --multi-volume',
#    '-N, --newer=DATE, --after-date=DATE',
#    '-O, --to-stdout',
#    '-P, --absolute-names',
#    '-R, --block-number',
#    '-S, --sparse',
#    '-T, --files-from=FILE',
#    '-U, --unlink-first',
#    '-V, --label=TEXT',
#    '-W, --verify',
#    '-X, --exclude-from=FILE',
#    '-Z, --compress, --uncompress',
#    '-a, --auto-compress',
#    '-b, --blocking-factor=BLOCKS',
#    "-c and -r options.  Notice, that newer files don't replace",
#    '-c, --create',
#    '-d, --diff, --compare',
#    '-f, --file=ARCHIVE',
#    '-g, --listed-incremental=FILE',
#    '-h, --dereference',
#    '-i, --ignore-zeros',
#    '-j, --bzip2',
#    '-k, --keep-old-files',
#    '-l, --check-links',
#    '-m, --touch',
#    '-n, --seek',
#    '-o     When creating, same as --old-archive.  When extracting,',
#    '-p, --preserve-permissions, --same-permissions',
#    '-r, --append',
#    '-s, --preserve-order, --same-order',
#    '-t, --list',
#    '-u, --update',
#    '-v, --verbose',
#    '-w, --interactive, --confirmation',
#    '-x, --extract, --get',
#    '-z, --gzip, --gunzip, --ungzip'}},
#  'uniq': {'lines': {'--all-repeated[=METHOD]',
#    '--group[=METHOD]',
#    '--help display this help and exit',
#    '--version',
#    '-D     print all duplicate lines',
#    '-c, --count',
#    '-d, --repeated',
#    '-f, --skip-fields=N',
#    '-i, --ignore-case',
#    '-s, --skip-chars=N',
#    '-u, --unique',
#    '-w, --check-chars=N',
#    '-z, --zero-terminated'}},
#  'ln': {'lines': {'--backup[=CONTROL]',
#    '--help display this help and exit',
#    '--symbolic.  By default, each destination (name of new link)',
#    '--version',
#    '-L, --logical',
#    '-P, --physical',
#    '-P.',
#    '-S, --suffix=SUFFIX',
#    '-T, --no-target-directory',
#    '-b     like --backup but does not accept an argument',
#    '-d, -F, --directory',
#    '-f, --force',
#    '-i, --interactive',
#    '-n, --no-dereference',
#    '-r, --relative',
#    '-s, --symbolic',
#    '-t, --target-directory=DIRECTORY',
#    '-v, --verbose'}},
#  'split': {'lines': {'--additional-suffix=SUFFIX',
#    '--filter=COMMAND',
#    '--help display this help and exit',
#    '--hex-suffixes[=FROM]',
#    '--numeric-suffixes[=FROM]',
#    '--verbose',
#    '--version',
#    '-C, --line-bytes=SIZE',
#    '-a, --suffix-length=N',
#    '-b, --bytes=SIZE',
#    '-d     use numeric suffixes starting at 0, not alphabetic',
#    '-e, --elide-empty-files',
#    '-l, --lines=NUMBER',
#    '-n, --number=CHUNKS',
#    '-t, --separator=SEP',
#    '-u, --unbuffered',
#    '-x     use hex suffixes starting at 0, not alphabetic'}},
#  'tee': {'lines': {'--help display this help and exit',
#    '--output-error[=MODE]',
#    '--version',
#    '-a, --append',
#    '-i, --ignore-interrupts',
#    '-p     diagnose errors writing to non pipes'}},
#  'date': {'lines': {'-      (hyphen) do not pad the field',
#    '--debug',
#    '--help display this help and exit',
#    '--rfc-3339=FMT',
#    '--version',
#    '-04, +05:30)',
#    '-I[FMT], --iso-8601[=FMT]',
#    '-R, --rfc-email',
#    '-d, --date=STRING',
#    '-f, --file=DATEFILE',
#    '-r, --reference=FILE',
#    '-s, --set=STRING',
#    '-u, --utc, --universal'}},
#  'pwd': {'lines': {'--help display this help and exit',
#    '--version',
#    '-L, --logical',
#    '-P, --physical'}},
#  'ssh': {'lines': {'-4      Forces ssh to use IPv4 addresses only.',
#    '-6      Forces ssh to use IPv6 addresses only.',
#    '-A      Enables forwarding of connections from an authentication',
#    '-B bind_interface',
#    '-C      Requests compression of all data (including stdin, stdout,',
#    '-D [bind_address:]port',
#    '-E log_file',
#    '-F configfile',
#    '-G      Causes ssh to print its configuration after evaluating Host',
#    '-I pkcs11',
#    '-J destination',
#    '-K      Enables GSSAPI-based authentication and forwarding',
#    '-KD[bind_address:]port for dynamic port-forwardings.',
#    '-KR[bind_address:]port for remote and',
#    '-L [bind_address:]port:host:hostport',
#    '-L [bind_address:]port:remote_socket',
#    '-L local_socket:host:hostport',
#    '-L local_socket:remote_socket',
#    '-M      Places the ssh client into â\x80\x9cmasterâ\x80\x9d mode for connection',
#    '-N      Do not execute a remote command.  This is useful for just',
#    '-N, -T, ExitOnForwardFailure and ClearAllForwardings,',
#    '-O ctl_cmd',
#    '-Q query_option',
#    '-R [bind_address:]port',
#    '-R [bind_address:]port:host:hostport',
#    '-R [bind_address:]port:local_socket',
#    '-R remote_socket:host:hostport',
#    '-R remote_socket:local_socket',
#    '-S ctl_path',
#    '-T      Disable pseudo-terminal allocation.',
#    '-V      Display the version number and exit.',
#    '-W host:port',
#    '-X      Enables X11 forwarding.  This can also be specified on a',
#    '-Y      Enables trusted X11 forwarding.  Trusted X11 forwardings',
#    '-a      Disables forwarding of the authentication agent connection.',
#    '-b bind_address',
#    '-c cipher_spec',
#    '-e escape_char',
#    '-f      Requests ssh to go to background just before command',
#    '-g      Allows remote hosts to connect to local forwarded ports.',
#    '-i identity_file',
#    '-k      Disables forwarding (delegation) of GSSAPI credentials to',
#    '-l login_name',
#    '-m mac_spec',
#    '-n      Redirects stdin from /dev/null (actually, prevents reading',
#    '-o option',
#    '-p port',
#    '-q      Quiet mode.  Causes most warning and diagnostic messages to',
#    '-s      May be used to request invocation of a subsystem on the',
#    '-t      Force pseudo-terminal allocation.  This can be used to',
#    '-v      Verbose mode.  Causes ssh to print debugging messages about',
#    '-w local_tun[:remote_tun]',
#    '-x      Disables X11 forwarding.',
#    '-y      Send log information using the syslog(3) system module.  By'}},
#  'diff': {'lines': {'--GTYPE-group-format=GFMT',
#    '--LTYPE-line-format=LFMT',
#    '--color[=WHEN]',
#    '--from-file=FILE1',
#    '--help display this help and exit',
#    '--horizon-lines=NUM',
#    '--ignore-file-name-case',
#    '--label LABEL',
#    '--left-column',
#    '--line-format=LFMT',
#    '--no-dereference',
#    '--no-ignore-file-name-case',
#    '--normal',
#    '--palette=PALETTE',
#    '--speed-large-files',
#    '--strip-trailing-cr',
#    '--suppress-blank-empty',
#    '--suppress-common-lines',
#    '--tabsize=NUM',
#    '--to-file=FILE2',
#    '--unidirectional-new-file',
#    '-B, --ignore-blank-lines',
#    '-D, --ifdef=NAME',
#    '-E, --ignore-tab-expansion',
#    '-F, --show-function-line=RE',
#    '-I, --ignore-matching-lines=RE',
#    '-N, --new-file',
#    '-S, --starting-file=FILE',
#    '-T, --initial-tab',
#    '-W, --width=NUM',
#    '-X, --exclude-from=FILE',
#    '-Z, --ignore-trailing-space',
#    '-a, --text',
#    '-b, --ignore-space-change',
#    '-c, -C NUM, --context[=NUM]',
#    '-d, --minimal',
#    '-e, --ed',
#    '-i, --ignore-case',
#    '-l, --paginate',
#    '-n, --rcs',
#    '-p, --show-c-function',
#    '-q, --brief',
#    '-r, --recursive',
#    '-s, --report-identical-files',
#    '-t, --expand-tabs',
#    '-u, -U NUM, --unified[=NUM]',
#    '-v, --version',
#    '-w, --ignore-all-space',
#    '-x, --exclude=PAT',
#    '-y, --side-by-side'}},
#  'du': {'lines': {'--apparent-size',
#    '--block-size, and the DU_BLOCK_SIZE, BLOCK_SIZE and BLOCKSIZE',
#    '--exclude=PATTERN',
#    '--files0-from=F',
#    '--help display this help and exit',
#    '--inodes',
#    '--si   like -h, but use powers of 1000 not 1024',
#    '--time show time of the last modification of any file in the',
#    '--time-style=STYLE',
#    '--time=WORD',
#    '--version',
#    '-0, --null',
#    '-B, --block-size=SIZE',
#    '-D, --dereference-args',
#    '-H     equivalent to --dereference-args (-D)',
#    '-L, --dereference',
#    '-P, --no-dereference',
#    '-S, --separate-dirs',
#    '-X, --exclude-from=FILE',
#    '-a, --all',
#    '-b, --bytes',
#    '-c, --total',
#    '-d, --max-depth=N',
#    '-h, --human-readable',
#    '-k     like --block-size=1K',
#    '-l, --count-links',
#    '-m     like --block-size=1M',
#    '-s, --summarize',
#    '-t, --threshold=SIZE',
#    '-x, --one-file-system'}},
#  'file': {'lines': {'--apple',
#    '--exclude-quiet',
#    '--extension',
#    '--help  Print a help message and exit.',
#    '--mime-type, --mime-encoding',
#    '-0, --print0',
#    '-C, --compile',
#    '-E      On filesystem errors (file not found etc), instead of',
#    '-F, --separator separator',
#    '-L, --dereference',
#    '-N, --no-pad',
#    '-P, --parameter name=value',
#    '-S option disables sandboxing which is enabled by default.',
#    '-S, --no-sandbox',
#    '-Z, --uncompress-noreport',
#    '-b, --brief',
#    '-c, --checking-printout',
#    '-d      Prints internal debugging information to stderr.',
#    '-e, --exclude testname',
#    '-f, --files-from namefile',
#    '-h, --no-dereference',
#    '-i, --mime',
#    '-k, --keep-going',
#    '-l, --list',
#    '-m, --magic-file magicfiles',
#    '-n, --no-buffer',
#    '-p, --preserve-date',
#    '-r, --raw',
#    '-s, --special-files',
#    '-v, --version',
#    '-z, --uncompress'}},
#  'rename': {'lines': {'-V, --version',
#    '-a, --all',
#    '-h, --help',
#    '-i, --interactive',
#    '-l, --last',
#    '-n, --no-act',
#    '-o, --no-overwrite',
#    '-s, --symlink',
#    '-v, --verbose'}},
#  'md5sum': {'lines': {'--help display this help and exit',
#    '--ignore-missing',
#    '--quiet',
#    '--status',
#    '--strict',
#    '--tag  create a BSD-style checksum',
#    '--version',
#    '-b, --binary',
#    '-c, --check',
#    '-t, --text',
#    '-w, --warn',
#    '-z, --zero'}},
#  'comm': {'lines': {'--check-order',
#    '--help display this help and exit',
#    '--nocheck-order',
#    '--output-delimiter=STR',
#    '--total',
#    '--version',
#    '-1     suppress column 1 (lines unique to FILE1)',
#    '-2     suppress column 2 (lines unique to FILE2)',
#    '-3     suppress column 3 (lines that appear in both files)',
#    '-z, --zero-terminated'}},
#  'mktemp': {'lines': {'--help display this help and exit',
#    '--suffix=SUFF',
#    '--tmpdir is implied.  Files are created u+rw, and directories',
#    '--version',
#    '-d, --directory',
#    '-p DIR, --tmpdir[=DIR]',
#    '-q, --quiet',
#    '-t     interpret TEMPLATE as a single file name component,',
#    '-t, TEMPLATE may contain slashes, but mktemp creates only',
#    '-u, --dry-run'}},
#  'df': {'lines': {'--block-size, and the DF_BLOCK_SIZE, BLOCK_SIZE and BLOCKSIZE',
#    '--help display this help and exit',
#    '--no-sync',
#    '--output[=FIELD_LIST]',
#    '--sync invoke sync before getting usage info',
#    '--total',
#    '--version',
#    '-B, --block-size=SIZE',
#    '-H, --si',
#    '-P, --portability',
#    '-T, --print-type',
#    '-a, --all',
#    '-h, --human-readable',
#    '-i, --inodes',
#    '-k     like --block-size=1K',
#    '-l, --local',
#    '-t, --type=TYPE',
#    '-v     (ignored)',
#    '-x, --exclude-type=TYPE'}},
#  'rev': {'lines': {'-V, --version', '-h, --help'}},
#  'rmdir': {'lines': {'--help display this help and exit',
#    '--ignore-fail-on-non-empty',
#    '--version',
#    '-p, --parents',
#    '-v, --verbose'}},
#  'od': {'lines': {'--endian={big|little}',
#    '--help display this help and exit',
#    '--traditional',
#    '--version',
#    '-A, --address-radix=RADIX',
#    '-N, --read-bytes=BYTES',
#    '-S BYTES, --strings[=BYTES]',
#    '-a     same as -t a,  select named characters, ignoring',
#    '-b     same as -t o1, select octal bytes',
#    '-c     same as -t c,  select printable characters or backslash',
#    '-d     same as -t u2, select unsigned decimal 2-byte units',
#    '-f     same as -t fF, select floats',
#    '-i     same as -t dI, select decimal ints',
#    '-j, --skip-bytes=BYTES',
#    '-l     same as -t dL, select decimal longs',
#    '-o     same as -t o2, select octal 2-byte units',
#    '-s     same as -t d2, select decimal 2-byte units',
#    '-t, --format=TYPE',
#    '-v, --output-duplicates',
#    '-w[BYTES], --width[=BYTES]',
#    '-x     same as -t x2, select hexadecimal 2-byte units'}},
#  'hostname': {'lines': {'--file name ) the root can also set a new node name.',
#    '--file name ) then root can also set a new NIS domain.',
#    '-F, --file filename',
#    '-V, --version',
#    '-a, --alias',
#    '-d, --domain',
#    '-f, --fqdn, --long',
#    '-h, --help',
#    '-i, --ip-address',
#    '-n, --node',
#    '-s, --short',
#    '-v, --verbose',
#    '-y, --yp, --nis'}}}

# %%
# The number of flags in our data structure
sum(len(data[x]['lines']) for x in data)
# Out:
# 1001

# %%
def get_inner_brackets(s):
    open_idx = s.index("[") + 1
    closed_idx = s.index("]")
    a = s[open_idx: closed_idx]
    a = a.replace("=", "")
    return a

def get_equal_arg(s):
    return remove_punctuation(s.split("=")[1])
    
def remove_punctuation(s):
    punctuation = set(_ for _ in ",.()")
    return "".join([x if x not in punctuation else "" for x in s])
    
def remove_brackets(s):
    brackets = {"[", "]"}
    return "".join([x if x not in brackets else "" for x in s])

def get_flag(line):
    punctuation = set(p for p in "[].,()=[]")
    for val in punctuation:
        line = line.replace(val, " ")
    flag = line.split(" ")[0]
    return flag

# %% [markdown]
# ## Cleaning Flags

# %%
for ut in data:
    for flag_line in data[ut]['lines']:
        flag_line = remove_punctuation(flag_line)
        flag, arg = get_flag(flag_line), None
        if "[" in flag_line and "]" in flag_line:
            arg = get_inner_brackets(flag_line)
        elif "=" in flag_line:
            arg = get_equal_arg(flag_line)
        data[ut][flag] = arg

# %%
for ut in data:
    if 'lines' in data[ut]:
        del data[ut]['lines']
        
data
# Out:
# {'find': {'-ls': None,
#   '-delete': None,
#   '-cnewer': None,
#   '-ignore_readdir_race': None,
#   '-Olevel': None,
#   '-cmin': None,
#   '-perm': None,
#   '-fstype': None,
#   '-not': None,
#   '-printf': None,
#   '-writable': None,
#   '-follow': None,
#   '-H': None,
#   '-O': None,
#   '-print': None,
#   '-prune': None,
#   '-fls': None,
#   '-L': None,
#   '-lname': None,
#   '-D': None,
#   '-links': None,
#   '-atime': None,
#   '-quit': None,
#   '-wholename': None,
#   '-name': None,
#   '-uid': None,
#   '-iwholename': None,
#   '-group': None,
#   '-iname': None,
#   '-execdir': None,
#   '-path': None,
#   '-newer': None,
#   '-inum': None,
#   '-fprintf': None,
#   '-mtime': None,
#   '-noignore_readdir_race': None,
#   '-warn': None,
#   '-ilname': None,
#   '-files0-from': None,
#   '-true': None,
#   '-ok': None,
#   '-xtype': None,
#   '-help': None,
#   '-iregex': None,
#   '-newerXY': None,
#   '-regextype': None,
#   '-depth': None,
#   '-samefile': None,
#   '-or': None,
#   '-regex': None,
#   '-amin': None,
#   '-executable': None,
#   '-ipath': None,
#   '-type': None,
#   '-readable': None,
#   '-mmin': None,
#   '-user': None,
#   '-fprint0': None,
#   '-okdir': None,
#   '-noleaf': None,
#   '-exec': None,
#   '-anewer': None,
#   '-false': None,
#   '-daystart': None,
#   '-fprint': None,
#   '-context': None,
#   '-mindepth': None,
#   '-maxdepth': None,
#   '-size': 'cwbkMG',
#   '-print0': None,
#   '-empty': None,
#   '-P': None,
#   '-o': None,
#   '-d': None,
#   '-n': None,
#   '-mount': None,
#   '-gid': None,
#   '-ctime': None,
#   '-nouser': None,
#   '-version': None,
#   '-nogroup': None,
#   '-xdev': None,
#   '-used': None},
#  'xargs': {'-n': 'max-args',
#   '-e': 'eof-str',
#   '-x': None,
#   '-I': None,
#   '-P': 'max-procs',
#   '-o': None,
#   '-0': None,
#   '-p': None,
#   '-s': None,
#   '--show-limits': None,
#   '-a': 'file',
#   '-i': 'replace-str',
#   '-L': None,
#   '-r': None,
#   '-l': 'max-lines',
#   '-E': None,
#   '--help': None,
#   '--process-slot-var': 'name',
#   '--version': None,
#   '-t': None,
#   '--delimiter': 'delim -d delim'},
#  'grep': {'-y': None,
#   '-H': None,
#   '-r': None,
#   '--group-separator': 'SEP',
#   '-U': None,
#   '--no-group-separator': None,
#   '-z': None,
#   '-e': 'PATTERNS',
#   '--no-ignore-case': None,
#   '--binary-files': 'TYPE',
#   '-i': None,
#   '-T': None,
#   '-C': 'NUM',
#   '--color': 'WHEN',
#   '--count': None,
#   '-D': 'ACTION',
#   '-q': None,
#   '-F': None,
#   '-w': None,
#   '--line-buffered': None,
#   '--exclude-from': 'FILE',
#   '--no-messages': None,
#   '--include': 'GLOB',
#   '-d': None,
#   '-E': None,
#   '--label': 'LABEL',
#   '-v': None,
#   '--exclude-dir': 'GLOB',
#   '-f': 'FILE',
#   '--exclude': 'GLOB',
#   '-n': None,
#   '-b': None,
#   '--help': None,
#   '-V': None,
#   '-P': None,
#   '-x': None,
#   '-G': None,
#   '-c': None,
#   '-L': None,
#   '-I': None,
#   '-o': None,
#   '-h': None,
#   '-Z': None,
#   '--only-matching': None,
#   '-A': 'NUM',
#   '-s': None,
#   '-l': None,
#   '-m': 'NUM',
#   '-R': None,
#   '-a': None,
#   '-B': 'NUM'},
#  'rm': {'-r': None,
#   '--interactive': 'always option is given rm prompts the user for',
#   '-f': None,
#   '-v': None,
#   '-I': None,
#   '--no-preserve-root': None,
#   '-d': None,
#   '-i': None,
#   '--help': None,
#   '--version': None,
#   '--one-file-system': None,
#   '--preserve-root': 'all'},
#  'echo': {'-e': None,
#   '-E': None,
#   '--help': None,
#   '--version': None,
#   '-n': None},
#  'ls': {'-H': None,
#   '-b': None,
#   '-p': 'slash',
#   '-d': None,
#   '--time-style': 'TIME_STYLE',
#   '--show-control-chars': None,
#   '--author': None,
#   '--full-time': None,
#   '-g': None,
#   '--sort': None,
#   '-a': None,
#   '-v': None,
#   '--color': 'WHEN',
#   '--indicator-style': 'WORD',
#   '--hyperlink': 'WHEN',
#   '-t': None,
#   '--help': None,
#   '-Z': None,
#   '-c': None,
#   '-X': None,
#   '-F': None,
#   '-u': None,
#   '-Q': None,
#   '-f': None,
#   '-N': None,
#   '--file-type': None,
#   '-m': None,
#   '--si': None,
#   '-q': None,
#   '-L': None,
#   '-U': None,
#   '-I': 'PATTERN',
#   '-i': None,
#   '--quoting-style': 'WORD',
#   '-l': None,
#   '-G': None,
#   '--dereference-command-line-symlink-to-dir': None,
#   '-x': None,
#   '-n': None,
#   '-h': None,
#   '-C': None,
#   '--format': 'WORD',
#   '-w': 'COLS',
#   '-o': None,
#   '-r': None,
#   '-k': None,
#   '-s': None,
#   '-1': None,
#   '--hide': 'PATTERN',
#   '-S': None,
#   '--time': 'WORD',
#   '-T': 'COLS',
#   '-D': None,
#   '-A': None,
#   '--block-size': 'SIZE',
#   '-R': None,
#   '--group-directories-first': None,
#   '--version': None,
#   '-B': None},
#  'sort': {'-t': 'SEP',
#   '-S': 'SIZE',
#   '-f': None,
#   '-m': None,
#   '-s': None,
#   '-b': None,
#   '-u': None,
#   '--help': None,
#   '--compress-program': 'PROG',
#   '-z': None,
#   '-C': 'quiet --check',
#   '-i': None,
#   '-d': None,
#   '-T': 'DIR',
#   '--random-source': 'FILE',
#   '-c': 'diagnose-first',
#   '-V': None,
#   '-M': None,
#   '-r': None,
#   '-R': None,
#   '-h': None,
#   '--parallel': 'N',
#   '--sort': 'WORD',
#   '-n': None,
#   '-o': 'FILE',
#   '--batch-size': 'NMERGE',
#   '-k': 'KEYDEF',
#   '--files0-from': 'F',
#   '--debug': None,
#   '--version': None,
#   '-g': None},
#  'chmod': {'-c': None,
#   '-R': None,
#   '-v': None,
#   '-f': None,
#   '--no-preserve-root': None,
#   '--reference': 'RFILE',
#   '--help': None,
#   '--version': None,
#   '--preserve-root': None},
#  'wc': {'-l': None,
#   '--files0-from': 'F',
#   '-L': None,
#   '-w': None,
#   '--help': None,
#   '--version': None,
#   '-m': None,
#   '-c': None},
#  'cat': {'-E': None,
#   '-e': None,
#   '-b': None,
#   '-n': None,
#   '--help': None,
#   '-A': None,
#   '-s': None,
#   '-v': None,
#   '--version': None,
#   '-t': None,
#   '-T': None,
#   '-u': None},
#  'cut': {'-f': 'LIST',
#   '-M': None,
#   '--complement': None,
#   '-n': None,
#   '-z': None,
#   '-d': 'DELIM',
#   '--output-delimiter': 'STRING',
#   '--help': None,
#   '-c': 'LIST',
#   '-s': None,
#   '--version': None,
#   '-b': 'LIST'},
#  'head': {'-z': None,
#   '-v': None,
#   '--help': None,
#   '--version': None,
#   '-n': '-',
#   '-q': None,
#   '-c': '-'},
#  'mv': {'-i': None,
#   '-f': None,
#   '-n': None,
#   '-b': None,
#   '-S': 'SUFFIX',
#   '-u': None,
#   '-v': None,
#   '--help': None,
#   '-t': 'DIRECTORY',
#   '-T': None,
#   '--version': None,
#   '--strip-trailing-slashes': None,
#   '--backup': 'CONTROL',
#   '-Z': None},
#  'chown': {'-L': None,
#   '-c': None,
#   '-P': None,
#   '--dereference': None,
#   '-v': None,
#   '-h': None,
#   '-R': None,
#   '--no-preserve-root': None,
#   '--reference': 'RFILE',
#   '--preserve-root': None,
#   '--help': None,
#   '--version': None,
#   '--from': 'CURRENT_OWNER:CURRENT_GROUP',
#   '-H': None,
#   '-f': None},
#  'cp': {'--copy-contents': None,
#   '--help': None,
#   '--strip-trailing-slashes': None,
#   '--sparse': 'WHEN',
#   '-a': None,
#   '-i': None,
#   '-P': None,
#   '-Z': None,
#   '-S': 'SUFFIX',
#   '-b': None,
#   '--no-preserve': 'ATTR_LIST',
#   '--parents': None,
#   '--reflink': 'WHEN',
#   '-L': None,
#   '-x': None,
#   '-H': None,
#   '--attributes-only': None,
#   '-f': None,
#   '--remove-destination': None,
#   '--preserve': 'ATTR_LIST',
#   '-T': None,
#   '-p': 'modeownershiptimestamps',
#   '-l': None,
#   '--backup': 'CONTROL',
#   '-t': 'DIRECTORY',
#   '-n': None,
#   '-v': None,
#   '-u': None,
#   '-s': None,
#   '--context': 'CTX',
#   '--version': None,
#   '-R': None,
#   '-d': 'links'},
#  'mkdir': {'-m': 'MODE',
#   '-v': None,
#   '--help': None,
#   '--context': 'CTX',
#   '-p': None,
#   '--version': None,
#   '-Z': None},
#  'tr': {'-d': None,
#   '-s': None,
#   '-t': None,
#   '--help': None,
#   '--version': None,
#   '-c': None},
#  'tail': {'-n': None,
#   '-z': None,
#   '-s': 'N',
#   '--retry': None,
#   '-v': None,
#   '--follow': 'name in that case  That causes tail to track the named',
#   '--pid': 'PID',
#   '-F': 'name --retry',
#   '--help': None,
#   '--max-unchanged-stats': 'N',
#   '-c': '+',
#   '--version': None,
#   '-f': '{name|descriptor}',
#   '-q': None},
#  'dirname': {'->': None, '--help': None, '--version': None, '-z': None},
#  'tar': {'-C': 'DIR',
#   '--verbatim-files-from': None,
#   '--no-quote-chars': 'STRING',
#   '--posix': None,
#   '--strip-components': 'NUMBER',
#   '--rmt-command': None,
#   '--no-ignore-case': None,
#   '--rsh-command': '/usr/bin/ssh',
#   '-z': None,
#   '--no-wildcards-match-slash': None,
#   '--exclude-tag': 'FILE',
#   '--show-defaults': None,
#   '-g': 'FILE',
#   '-B': None,
#   '--lzop': None,
#   '--acls': None,
#   '--usage': None,
#   '--restrict': None,
#   '--exclude-tag-all': 'FILE',
#   '--hole-detection': 'METHOD',
#   '--auto-compress': None,
#   '-J': None,
#   '-m': None,
#   '--group': ':GID',
#   '--group-map': 'FILE',
#   '-j': None,
#   '--hard-dereference': None,
#   '--wildcards-match-slash': None,
#   '--transform': 'EXPRESSION --xform',
#   '--owner': ':UID',
#   '--exclude-vcs': None,
#   '--suffix': 'STRING',
#   '-c': None,
#   '--utc': None,
#   '-v': None,
#   '-u': None,
#   '--help': None,
#   '--newer-mtime': 'DATE',
#   '-N': 'DATE --after-date',
#   '--sparse-version': 'MINOR',
#   '--version': None,
#   '--one-top-level': 'DIR',
#   '-h': None,
#   '--recursion': None,
#   '-O': None,
#   '-w': None,
#   '--list': None,
#   '--no-same-owner': None,
#   '--exclude-caches-all': None,
#   '--zstd': None,
#   '--no-anchored': None,
#   '--exclude-caches-under': None,
#   '--full-time': None,
#   '--mode': 'CHANGES',
#   '-P': None,
#   '--wildcards': None,
#   '--exclude': 'PATTERN',
#   '-d': None,
#   '-k': None,
#   '--delay-directory-restore': None,
#   '--multi-volume': None,
#   '--file': 'remotehost:/dev/sr0',
#   '-R': None,
#   '--level': 'NUMBER',
#   '--same-owner': None,
#   '--no-recursion': None,
#   '--lzip': None,
#   '--no-selinux': None,
#   '--check-device': None,
#   '-S': None,
#   '--exclude-ignore': 'FILE',
#   '--record-size': 'NUMBER',
#   '--ignore-command-error': None,
#   '--backup': 'CONTROL',
#   '--quoting-style': 'STYLE',
#   '-a': None,
#   '--recursive-unlink': None,
#   '-W': None,
#   '--index-file': 'FILE',
#   '--exclude-tag-under': 'FILE',
#   '-F': 'COMMAND --new-volume-script',
#   '--xattrs-exclude': 'PATTERN',
#   '-T': 'FILE',
#   '-x': None,
#   '-f': 'ARCHIVE',
#   '--no-ignore-command-error': None,
#   '--skip-old-files': None,
#   '--ignore-failed-read': None,
#   '--quote-chars': 'STRING',
#   '--null': None,
#   '--no-check-device': None,
#   '--no-seek': None,
#   '--delete': None,
#   '--no-null': None,
#   '--no-overwrite-dir': None,
#   '--exclude-ignore-recursive': 'FILE',
#   '--no-xattrs': None,
#   '--warning': 'KEYWORD',
#   '--totals': 'SIGNAL',
#   '--no-auto-compress': None,
#   '--xattrs': None,
#   '-o': None,
#   '--sort': 'ORDER',
#   '--checkpoint-action': 'ACTION',
#   '-V': 'TEXT',
#   '--xattrs-include': 'PATTERN',
#   '-I': 'COMMAND',
#   '--selinux': None,
#   '--anchored': None,
#   '--volno-file': 'FILE',
#   '--no-delay-directory-restore': None,
#   '-l': None,
#   '--show-transformed-names': None,
#   '--owner-map': 'FILE',
#   '--show-omitted-dirs': None,
#   '-r': None,
#   '-X': 'FILE',
#   '-n': None,
#   '--unquote': None,
#   '--pax-option': '[:',
#   '-M': None,
#   '--test-label': None,
#   '-p': None,
#   '--ignore-case': None,
#   '-G': None,
#   '-s': None,
#   '-?': None,
#   '--to-command': 'COMMAND',
#   '-U': None,
#   '--exclude-backups': None,
#   '--no-same-permissions': None,
#   '--numeric-owner': None,
#   '-b': 'BLOCKS',
#   '--occurrence': 'N',
#   '--add-file': 'FILE',
#   '--atime-preserve': 'METHOD',
#   '-t': None,
#   '--keep-newer-files': None,
#   '--overwrite': None,
#   '--old-archive': None,
#   '--clamp-mtime': None,
#   '--no-unquote': None,
#   '-L': 'N',
#   '--checkpoint': 'N',
#   '--force-local': None,
#   '--remove-files': None,
#   '-Z': None,
#   '--no-verbatim-files-from': None,
#   '--exclude-vcs-ignores': None,
#   '-K': 'MEMBER',
#   '--lzma': None,
#   '--keep-directory-symlink': None,
#   '--overwrite-dir': None,
#   '--no-wildcards': None,
#   '-A': None,
#   '--exclude-caches': None,
#   '-H': 'FORMAT',
#   '--mtime': 'DATE-OR-FILE',
#   '--sparse': None,
#   '-i': None,
#   '--one-file-system': None,
#   '--no-acls': None},
#  'uniq': {'-D': None,
#   '-s': 'N',
#   '--group': 'METHOD',
#   '-z': None,
#   '-c': None,
#   '--all-repeated': 'METHOD',
#   '-w': 'N',
#   '-u': None,
#   '--help': None,
#   '-f': 'N',
#   '--version': None,
#   '-d': None,
#   '-i': None},
#  'ln': {'-r': None,
#   '-i': None,
#   '-n': None,
#   '-f': None,
#   '-S': 'SUFFIX',
#   '-b': None,
#   '-v': None,
#   '-d': None,
#   '-L': None,
#   '-P': None,
#   '-t': 'DIRECTORY',
#   '--help': None,
#   '-T': None,
#   '--version': None,
#   '-s': None,
#   '--backup': 'CONTROL',
#   '--symbolic': None},
#  'split': {'-C': 'SIZE',
#   '-n': 'CHUNKS',
#   '--verbose': None,
#   '--numeric-suffixes': 'FROM',
#   '--filter': 'COMMAND',
#   '-e': None,
#   '-t': 'SEP',
#   '-u': None,
#   '-x': None,
#   '--help': None,
#   '--additional-suffix': 'SUFFIX',
#   '--hex-suffixes': 'FROM',
#   '-d': None,
#   '-l': 'NUMBER',
#   '--version': None,
#   '-a': 'N',
#   '-b': 'SIZE'},
#  'tee': {'-a': None,
#   '-p': None,
#   '-i': None,
#   '--help': None,
#   '--version': None,
#   '--output-error': 'MODE'},
#  'date': {'-u': None,
#   '-s': 'STRING',
#   '-04': None,
#   '--debug': None,
#   '-R': None,
#   '--rfc-3339': 'FMT',
#   '-': None,
#   '--help': None,
#   '-d': 'STRING',
#   '-f': 'DATEFILE',
#   '-r': 'FILE',
#   '--version': None,
#   '-I': 'FMT'},
#  'pwd': {'-L': None, '--help': None, '-P': None, '--version': None},
#  'ssh': {'-O': None,
#   '-g': None,
#   '-L': None,
#   '-A': None,
#   '-p': None,
#   '-T': None,
#   '-m': None,
#   '-q': None,
#   '-e': None,
#   '-R': 'bind_address:',
#   '-KD': 'bind_address:',
#   '-N': None,
#   '-M': None,
#   '-6': None,
#   '-Y': None,
#   '-V': None,
#   '-KR': 'bind_address:',
#   '-W': None,
#   '-x': None,
#   '-i': None,
#   '-s': None,
#   '-B': None,
#   '-v': None,
#   '-y': None,
#   '-E': None,
#   '-J': None,
#   '-4': None,
#   '-K': None,
#   '-S': None,
#   '-w': ':remote_tun',
#   '-X': None,
#   '-F': None,
#   '-C': None,
#   '-D': 'bind_address:',
#   '-G': None,
#   '-a': None,
#   '-c': None,
#   '-I': None,
#   '-f': None,
#   '-k': None,
#   '-b': None,
#   '-t': None,
#   '-o': None,
#   '-Q': None,
#   '-n': None,
#   '-l': None},
#  'diff': {'-c': 'NUM',
#   '-e': None,
#   '-r': None,
#   '-x': 'PAT',
#   '-q': None,
#   '--strip-trailing-cr': None,
#   '--help': None,
#   '-u': 'NUM',
#   '--GTYPE-group-format': 'GFMT',
#   '--color': 'WHEN',
#   '-i': None,
#   '-T': None,
#   '-n': None,
#   '-I': 'RE',
#   '--label': None,
#   '-v': None,
#   '--left-column': None,
#   '-N': None,
#   '-w': None,
#   '--unidirectional-new-file': None,
#   '--ignore-file-name-case': None,
#   '-b': None,
#   '-W': 'NUM',
#   '-E': None,
#   '-p': None,
#   '--LTYPE-line-format': 'LFMT',
#   '-t': None,
#   '--palette': 'PALETTE',
#   '--tabsize': 'NUM',
#   '--line-format': 'LFMT',
#   '--suppress-common-lines': None,
#   '--to-file': 'FILE2',
#   '-B': None,
#   '-F': 'RE',
#   '-S': 'FILE',
#   '--no-dereference': None,
#   '--no-ignore-file-name-case': None,
#   '-s': None,
#   '--speed-large-files': None,
#   '-y': None,
#   '-D': 'NAME',
#   '-d': None,
#   '--horizon-lines': 'NUM',
#   '--suppress-blank-empty': None,
#   '-X': 'FILE',
#   '--normal': None,
#   '-l': None,
#   '-a': None,
#   '-Z': None,
#   '--from-file': 'FILE1'},
#  'du': {'-m': '1M',
#   '-B': 'SIZE',
#   '--si': None,
#   '-t': 'SIZE',
#   '-a': None,
#   '--help': None,
#   '--exclude': 'PATTERN',
#   '--time-style': 'STYLE',
#   '-P': None,
#   '-S': None,
#   '--inodes': None,
#   '-0': None,
#   '-L': None,
#   '-x': None,
#   '-D': None,
#   '-b': None,
#   '-h': None,
#   '-k': '1K',
#   '-s': None,
#   '-H': None,
#   '--time': None,
#   '--apparent-size': None,
#   '-d': 'N',
#   '--files0-from': 'F',
#   '-c': None,
#   '-X': 'FILE',
#   '--block-size': None,
#   '--version': None,
#   '-l': None},
#  'file': {'-c': None,
#   '-E': None,
#   '-Z': None,
#   '--extension': None,
#   '-N': None,
#   '-e': None,
#   '-d': None,
#   '-f': None,
#   '-S': None,
#   '-z': None,
#   '-h': None,
#   '-r': None,
#   '-v': None,
#   '--apple': None,
#   '-b': None,
#   '--help': None,
#   '-L': None,
#   '-k': None,
#   '-l': None,
#   '-0': None,
#   '-s': None,
#   '-F': None,
#   '-P': 'value',
#   '-p': None,
#   '-m': None,
#   '--exclude-quiet': None,
#   '-C': None,
#   '-n': None,
#   '-i': None,
#   '--mime-type': None},
#  'rename': {'-s': None,
#   '-i': None,
#   '-V': None,
#   '-v': None,
#   '-l': None,
#   '-a': None,
#   '-o': None,
#   '-n': None,
#   '-h': None},
#  'md5sum': {'--status': None,
#   '--tag': None,
#   '-c': None,
#   '-t': None,
#   '-b': None,
#   '--ignore-missing': None,
#   '--help': None,
#   '-w': None,
#   '--version': None,
#   '--strict': None,
#   '--quiet': None,
#   '-z': None},
#  'comm': {'-1': None,
#   '--check-order': None,
#   '--total': None,
#   '-z': None,
#   '--output-delimiter': 'STR',
#   '-2': None,
#   '--help': None,
#   '--version': None,
#   '-3': None,
#   '--nocheck-order': None},
#  'mktemp': {'-t': None,
#   '-q': None,
#   '-d': None,
#   '-u': None,
#   '--help': None,
#   '--suffix': 'SUFF',
#   '--version': None,
#   '--tmpdir': None,
#   '-p': 'DIR'},
#  'df': {'-i': None,
#   '--sync': None,
#   '--block-size': None,
#   '-B': 'SIZE',
#   '--help': None,
#   '-a': None,
#   '-t': 'TYPE',
#   '-P': None,
#   '-T': None,
#   '-v': None,
#   '--total': None,
#   '--no-sync': None,
#   '-h': None,
#   '-k': '1K',
#   '-l': None,
#   '--output': 'FIELD_LIST',
#   '-H': None,
#   '--version': None,
#   '-x': 'TYPE'},
#  'rev': {'-V': None, '-h': None},
#  'rmdir': {'-v': None,
#   '--help': None,
#   '-p': None,
#   '--version': None,
#   '--ignore-fail-on-non-empty': None},
#  'od': {'-a': None,
#   '-c': None,
#   '-d': None,
#   '--help': None,
#   '-b': None,
#   '--endian': '{big|little}',
#   '-N': 'BYTES',
#   '-s': None,
#   '-j': 'BYTES',
#   '--traditional': None,
#   '-i': None,
#   '-o': None,
#   '-f': None,
#   '-w': 'BYTES',
#   '-v': None,
#   '-S': 'BYTES',
#   '-l': None,
#   '-x': None,
#   '--version': None,
#   '-A': 'RADIX',
#   '-t': 'TYPE'},
#  'hostname': {'-n': None,
#   '-f': None,
#   '-d': None,
#   '-V': None,
#   '-v': None,
#   '-s': None,
#   '--file': None,
#   '-F': None,
#   '-y': None,
#   '-i': None,
#   '-h': None,
#   '-a': None}}

# %%
# the number of flags that have arguments
count = 0
for ut in data:
    for flag in data[ut]:
        if data[ut][flag]: count +=1
count
# Out:
# 212

# %% [markdown]
# ## Manually Inserting Argument Types
#
# Now that we have the utilities mapped to the appropriate flags, we will need to manually insert the data types corresponding to each flag.

# %%
argument_types = [
    'Regex',
    'File',
    'Directory',
    'Path',
    'Number',
    '+Number',
    '-Number',
    'Quantity',
    '+Quantity',
    '-Quantity',
    'Size',
    '+Size',
    '-Size',
    'Timespan',
    '+Timespan',
    '-Timespan',
    'DateTime',
    '+DateTime',
    '-DateTime',
    'Permission',
    '+Permission',
    '-Permission'
]

# %% [markdown]
# Getting a sense of the argument types the parser has discovered

# %%
def flag_types(data):
    l = []
    for ut in data:
        for flag in data[ut]:
            if data[ut][flag]:
                l.append(data[ut][flag])
    return l
flag_types(data)[:20]
# Out:
# ['cwbkMG',
#  'max-args',
#  'eof-str',
#  'max-procs',
#  'file',
#  'replace-str',
#  'max-lines',
#  'name',
#  'delim -d delim',
#  'SEP',
#  'PATTERNS',
#  'TYPE',
#  'NUM',
#  'WHEN',
#  'ACTION',
#  'FILE',
#  'GLOB',
#  'LABEL',
#  'GLOB',
#  'FILE']

# %%
type_mapping = {
    'Regex': {'str', 'sep', 'pattern', 'word', 'delim', 'suffix', 'from', 'glob'},
    'File': {'file'},
    'Directory': {'dir'},
    'Path': {'path'},
    'Number': {'num', 'n', 'cols', 'pid', 'max', 'bytes'},
    'Quantity': {},
    'Size':{'size'},
    'Timespan':{},
    'DateTime': {'timestamp', 'time'},
    'Permission':{},
}
# _NUMBER, _PATH,
# _FILE, _DIRECTORY, _DATETIME, _PERMISSION,
# _TIMESPAN, _SIZE
# ,  with  the  default  option  of
# _REGEX

def non_conforming_flags(data, types):
    l = []
    for ut in data:
        for flag in data[ut]:
            if data[ut][flag] and data[ut][flag] not in types:
                l.append(":".join([ut, flag, data[ut][flag]]))
    return l

# %% [markdown]
# ## Converting Argument Types in Structure to Known Types
#
# Using the type mappings, we can convert the argument types we parsed into the set number of types we know.

# %%
def convert_flag_types(data, mapping):
    for ut in data:
        for flag in data[ut]:
            if data[ut][flag]:
                for t in mapping:
                    for substr in mapping[t]:
                        if substr in data[ut][flag].lower():
                            data[ut][flag] = t
                        
convert_flag_types(data, type_mapping)
non_conforming_flags(data, argument_types)
# Out:
# ['find:-size:cwbkMG',
#  'grep:--binary-files:TYPE',
#  'grep:--label:LABEL',
#  'rm:--preserve-root:all',
#  'ls:-p:slash',
#  'sort:--compress-program:PROG',
#  'sort:-C:quiet --check',
#  'sort:-k:KEYDEF',
#  'sort:--files0-from:F',
#  'wc:--files0-from:F',
#  'cut:-f:LIST',
#  'cut:-c:LIST',
#  'cut:-b:LIST',
#  'head:-n:-',
#  'head:-c:-',
#  'cp:--no-preserve:ATTR_LIST',
#  'cp:--preserve:ATTR_LIST',
#  'cp:--context:CTX',
#  'mkdir:-m:MODE',
#  'mkdir:--context:CTX',
#  'tail:-c:+',
#  'tar:--hole-detection:METHOD',
#  'tar:--group::GID',
#  'tar:--owner::UID',
#  'tar:--newer-mtime:DATE',
#  'tar:-N:DATE --after-date',
#  'tar:--file:remotehost:/dev/sr0',
#  'tar:--quoting-style:STYLE',
#  'tar:-f:ARCHIVE',
#  'tar:--sort:ORDER',
#  'tar:-V:TEXT',
#  'tar:--pax-option:[:',
#  'tar:-b:BLOCKS',
#  'tar:--atime-preserve:METHOD',
#  'tar:-K:MEMBER',
#  'tar:-H:FORMAT',
#  'uniq:--group:METHOD',
#  'uniq:--all-repeated:METHOD',
#  'tee:--output-error:MODE',
#  'date:--rfc-3339:FMT',
#  'date:-I:FMT',
#  'diff:-x:PAT',
#  'diff:--GTYPE-group-format:GFMT',
#  'diff:-I:RE',
#  'diff:--LTYPE-line-format:LFMT',
#  'diff:--palette:PALETTE',
#  'diff:--line-format:LFMT',
#  'diff:-F:RE',
#  'du:-m:1M',
#  'du:--time-style:STYLE',
#  'du:-k:1K',
#  'du:--files0-from:F',
#  'file:-P:value',
#  'mktemp:--suffix:SUFF',
#  'df:-t:TYPE',
#  'df:-k:1K',
#  'df:--output:FIELD_LIST',
#  'df:-x:TYPE',
#  'od:--endian:{big|little}',
#  'od:-A:RADIX',
#  'od:-t:TYPE']

# %%
len(data['grep'])
# Out:
# 51

# %%
descs
# Out:
# {'find': 'find [-H] [-L] [-P] [-D debugopts] [-Olevel] [starting-point...]',
#  'xargs': 'xargs [options] [command [initial-arguments]]',
#  'grep': 'grep [OPTION...] PATTERNS [FILE...]',
#  'rm': 'rm [OPTION]... [FILE]...',
#  'echo': 'echo [SHORT-OPTION]... [STRING]...',
#  'ls': 'ls [OPTION]... [FILE]...',
#  'sort': 'sort [OPTION]... [FILE]...',
#  'chmod': 'chmod [OPTION]... MODE[,MODE]... FILE...',
#  'wc': 'wc [OPTION]... [FILE]...',
#  'cat': 'cat [OPTION]... [FILE]...',
#  'cut': 'cut OPTION... [FILE]...',
#  'head': 'head [OPTION]... [FILE]...',
#  'mv': 'mv [OPTION]... [-T] SOURCE DEST',
#  'chown': 'chown [OPTION]... [OWNER][:[GROUP]] FILE...',
#  'cp': 'cp [OPTION]... [-T] SOURCE DEST',
#  'mkdir': 'mkdir [OPTION]... DIRECTORY...',
#  'tr': 'tr [OPTION]... SET1 [SET2]',
#  'tail': 'tail [OPTION]... [FILE]...',
#  'dirname': 'dirname [OPTION] NAME...',
#  'tar': 'Traditional usage',
#  'uniq': 'uniq [OPTION]... [INPUT [OUTPUT]]',
#  'ln': 'ln [OPTION]... [-T] TARGET LINK_NAME',
#  'split': 'split [OPTION]... [FILE [PREFIX]]',
#  'tee': 'tee [OPTION]... [FILE]...',
#  'date': 'date [OPTION]... [+FORMAT]',
#  'pwd': 'pwd [OPTION]...',
#  'ssh': 'ssh [-46AaCfGgKkMNnqsTtVvXxYy] [-B bind_interface]',
#  'diff': 'diff [OPTION]... FILES',
#  'du': 'du [OPTION]... [FILE]...',
#  'file': 'file [-bcdEhiklLNnprsSvzZ0] [--apple] [--exclude-quiet]',
#  'rename': 'rename [options] expression replacement file...',
#  'md5sum': 'md5sum [OPTION]... [FILE]...',
#  'comm': 'comm [OPTION]... FILE1 FILE2',
#  'mktemp': 'mktemp [OPTION]... [TEMPLATE]',
#  'df': 'df [OPTION]... [FILE]...',
#  'rev': 'rev [option] [file...]',
#  'rmdir': 'rmdir [OPTION]... DIRECTORY...',
#  'od': 'od [OPTION]... [FILE]...',
#  'hostname': 'hostname [-v] [-s|--short]'}

# %%
l = descs['find']

# %%
l.strip()
# Out:
# 'find [-H] [-L] [-P] [-D debugopts] [-Olevel] [starting-point...]'

# %%
def valid_flag(flag):
    return flag in argument_types or not flag

def generate_options(utility):
    flag_map = data[utility]
    
    ret = []
    keys = list(flag_map.keys())
    for i in range(len(keys)):
        for j in range(i + 1, len(keys)):
            for k in range(j + 1, len(keys)):
                if all(valid_flag(flag_map[x]) for x in [keys[i], keys[j], keys[k]]):
                    f1 = " ".join([keys[i], flag_map[keys[i]]]) if flag_map[keys[i]] else keys[i]
                    f2 = " ".join([keys[j], flag_map[keys[j]]]) if flag_map[keys[j]] else keys[j]
                    f3 = " ".join([keys[k], flag_map[keys[k]]]) if flag_map[keys[k]] else keys[k]
                    ret.append(f1)
                    ret.append(" ".join([f1, f2]))
                    ret.append(" ".join([f1, f2, f3]))
    return list(set(ret))

def generate_syntax(utility):
    syntax = descs[utility]
    
    if 'option' not in syntax.lower():
        return f"Invalid syntax for utility {utility}, {syntax}"
        
    s = syntax.replace('...', '')
    s = remove_punctuation(s)
    s = remove_brackets(s)
    s = s.lower()
    
    sp = s.split(" ")
    cleaned = []
    for val in sp:
        if val == utility:
            cleaned.append(val)
        elif "option" in val:
            cleaned.append("option")
        elif val and val[0] != "-":
            s = ""
            for data_type in type_mapping:
                for match in type_mapping[data_type]:
                    if match in val:
                        s = data_type
            cleaned.append(s)
    
    return " ".join(cleaned)

def generate_commands(utility):
    ops = generate_options(utility)
    ret = []
    syntax = generate_syntax(utility)
    if "Invalid" in syntax:
        return ret
    for option_combo in ops:
        ret.append(syntax.replace("option", option_combo))
    return ret

total = []
for ut in utilities:
    print(f"{ut}: {len(generate_commands(ut))}")
    for r in generate_commands(ut):
        total.append(r)
len(total)
# Out:
# find: 0
# xargs: 1539
# grep: 19599
# rm: 219
# echo: 19
# ls: 32508
# sort: 3275
# chmod: 119
# wc: 55
# cat: 285
# cut: 119
# head: 19
# mv: 454
# chown: 559
# cp: 4494
# mkdir: 19
# tr: 34
# tail: 363
# dirname: 9
# tar: 0
# uniq: 219
# ln: 815
# split: 815
# tee: 19
# date: 219
# pwd: 9
# ssh: 0
# diff: 13243
# du: 2599
# file: 0
# rename: 119
# md5sum: 285
# comm: 164
# mktemp: 83
# df: 559
# rev: 0
# rmdir: 19
# od: 968
# hostname: 0
# 83823

# %%
generate_commands('grep')[:100]
# Out:
# ['grep -e Regex -b -A Number Number File',
#  'grep -v --exclude Regex -L Number File',
#  'grep --count -v -a Number File',
#  'grep -r -C Number -b Number File',
#  'grep -q --no-messages -a Number File',
#  'grep -d -G -a Number File',
#  'grep -z -n -l Number File',
#  'grep --exclude-dir Regex --exclude Regex -Z Number File',
#  'grep --no-group-separator --exclude-dir Regex -P Number File',
#  'grep -r -n -h Number File',
#  'grep --color Number --line-buffered -o Number File',
#  'grep -i -c --only-matching Number File',
#  'grep -r -T --line-buffered Number File',
#  'grep -T -F Number File',
#  'grep --count -c -m Number Number File',
#  'grep --no-group-separator --no-ignore-case -i Number File',
#  'grep --group-separator Regex --line-buffered -s Number File',
#  'grep -e Regex -n -P Number File',
#  'grep -C Number -V -R Number File',
#  'grep --exclude-from File -v -b Number File',
#  'grep -r -G -o Number File',
#  'grep --help --only-matching -m Number Number File',
#  'grep -e Regex -i -D Number Number File',
#  'grep -e Regex -F -s Number File',
#  'grep -e Regex --exclude-from File Number File',
#  'grep -E -v -A Number Number File',
#  'grep --count -v -Z Number File',
#  'grep -C Number -E --exclude Regex Number File',
#  'grep -H -P -R Number File',
#  'grep -E -o -R Number File',
#  'grep --group-separator Regex --no-group-separator --line-buffered Number File',
#  'grep -b -c -B Number Number File',
#  'grep -o -l -m Number Number File',
#  'grep -F --line-buffered -c Number File',
#  'grep -T --count --no-messages Number File',
#  'grep --include Regex -o -a Number File',
#  'grep -i --exclude-from File -A Number Number File',
#  'grep -T --exclude Regex -L Number File',
#  'grep --no-messages --exclude Regex -P Number File',
#  'grep -q --exclude Regex -R Number File',
#  'grep -e Regex -E -R Number File',
#  'grep -y -n -G Number File',
#  'grep -T --only-matching -s Number File',
#  'grep -i --count -f File Number File',
#  'grep --line-buffered -P -x Number File',
#  'grep --group-separator Regex -z -F Number File',
#  'grep -C Number --exclude-dir Regex -a Number File',
#  'grep -w --no-messages -G Number File',
#  'grep -y -r -I Number File',
#  'grep -i --color Number -s Number File',
#  'grep -q -v --exclude Regex Number File',
#  'grep -P -s Number File',
#  'grep --group-separator Regex -C Number --help Number File',
#  'grep --no-ignore-case --exclude-dir Regex Number File',
#  'grep -H --exclude Regex --only-matching Number File',
#  'grep -T --count -d Number File',
#  'grep -w --line-buffered -R Number File',
#  'grep -w --include Regex -V Number File',
#  'grep -e Regex --count -b Number File',
#  'grep -z -n -c Number File',
#  'grep --no-ignore-case -w -B Number Number File',
#  'grep -n -Z -l Number File',
#  'grep -z -i -P Number File',
#  'grep -V -P -A Number Number File',
#  'grep --exclude-dir Regex -n --help Number File',
#  'grep --include Regex --exclude Regex -Z Number File',
#  'grep -w -n -G Number File',
#  'grep -H --exclude-dir Regex -a Number File',
#  'grep -T -s -l Number File',
#  'grep --color Number --line-buffered --include Regex Number File',
#  'grep -A Number -m Number -a Number File',
#  'grep -e Regex --no-ignore-case -T Number File',
#  'grep --no-group-separator -i --no-messages Number File',
#  'grep -i -C Number -G Number File',
#  'grep --no-messages --include Regex -L Number File',
#  'grep -y -b -Z Number File',
#  'grep -d --help -I Number File',
#  'grep -x -G -h Number File',
#  'grep -C Number --count --line-buffered Number File',
#  'grep -v -s Number File',
#  'grep -V -P -a Number File',
#  'grep -V Number File',
#  'grep -z -n -a Number File',
#  'grep --group-separator Regex -w -E Number File',
#  'grep --group-separator Regex -F --exclude Regex Number File',
#  'grep -r --count Number File',
#  'grep --color Number -q --help Number File',
#  'grep --exclude-dir Regex -V -x Number File',
#  'grep -v -l Number File',
#  'grep --no-group-separator -q --exclude-from File Number File',
#  'grep -y -w -o Number File',
#  'grep -r -I -B Number Number File',
#  'grep -r -d -I Number File',
#  'grep -e Regex -F -a Number File',
#  'grep -y -d -m Number Number File',
#  'grep -T --color Number -F Number File',
#  'grep -T -I -l Number File',
#  'grep -w -V -x Number File',
#  'grep -y --no-ignore-case --exclude-from File Number File',
#  'grep -z --no-ignore-case Number File']

# %%
data['find']
# Out:
# {'-ls': None,
#  '-delete': None,
#  '-cnewer': None,
#  '-ignore_readdir_race': None,
#  '-Olevel': None,
#  '-cmin': None,
#  '-perm': None,
#  '-fstype': None,
#  '-not': None,
#  '-printf': None,
#  '-writable': None,
#  '-follow': None,
#  '-H': None,
#  '-O': None,
#  '-print': None,
#  '-prune': None,
#  '-fls': None,
#  '-L': None,
#  '-lname': None,
#  '-D': None,
#  '-links': None,
#  '-atime': None,
#  '-quit': None,
#  '-wholename': None,
#  '-name': None,
#  '-uid': None,
#  '-iwholename': None,
#  '-group': None,
#  '-iname': None,
#  '-execdir': None,
#  '-path': None,
#  '-newer': None,
#  '-inum': None,
#  '-fprintf': None,
#  '-mtime': None,
#  '-noignore_readdir_race': None,
#  '-warn': None,
#  '-ilname': None,
#  '-files0-from': None,
#  '-true': None,
#  '-ok': None,
#  '-xtype': None,
#  '-help': None,
#  '-iregex': None,
#  '-newerXY': None,
#  '-regextype': None,
#  '-depth': None,
#  '-samefile': None,
#  '-or': None,
#  '-regex': None,
#  '-amin': None,
#  '-executable': None,
#  '-ipath': None,
#  '-type': None,
#  '-readable': None,
#  '-mmin': None,
#  '-user': None,
#  '-fprint0': None,
#  '-okdir': None,
#  '-noleaf': None,
#  '-exec': None,
#  '-anewer': None,
#  '-false': None,
#  '-daystart': None,
#  '-fprint': None,
#  '-context': None,
#  '-mindepth': None,
#  '-maxdepth': None,
#  '-size': 'cwbkMG',
#  '-print0': None,
#  '-empty': None,
#  '-P': None,
#  '-o': None,
#  '-d': None,
#  '-n': None,
#  '-mount': None,
#  '-gid': None,
#  '-ctime': None,
#  '-nouser': None,
#  '-version': None,
#  '-nogroup': None,
#  '-xdev': None,
#  '-used': None}
