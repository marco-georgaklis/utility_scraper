# %% [markdown]
# # Exploratory Data Analysis: Web Scraping Utilities with Beautiful Soup
#
# In this notebook, I hope to create a parser for web scraping the linux man pages to gather information on some of the most common utilities and their corresponding flags.

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 23 of the most common utilities
utilities = [
    "find",
    "xargs",
    "grep",
    "rm",
    "echo",
    "ls",
    "sort",
    "chmod",
    "wc",
    "cat",
    "cut",
    "head",
    "mv",
    "chown",
    "cp",
    "mkdir",
    "tr",
    "tail",
    "dirname",
    "tar",
    "uniq",
    "ln",
    "split",
]

# %% [markdown]
# ## Finding Flags for 1 Utility
# First, we want to create a parser to find the available flags for just one of the utilities. We will start with the 'find' utility and use the BeautifulSoup package to parse for the corresponding flags.

# %%
utility = "uniq"
utility_url = f'https://man7.org/linux/man-pages/man1/{utility}.1.html'
r = requests.get(utility_url)
soup = BeautifulSoup(r.text)
print(soup.prettify()[:])
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    uniq(1) - Linux manual page
#   </title>
#   <link href="../../../style.css" rel="stylesheet" title="style" type="text/css"/>
#   <link href="../style.css" rel="stylesheet" title="style" type="text/css"/>
#  </head>
#  <body>
#   <div class="page-top">
#    <a id="top_of_page">
#    </a>
#   </div>
#   <!--%%%TOP_BAR%%%-->
#   <div class="nav-bar">
#    <table class="nav-table">
#     <tr>
#      <td class="nav-cell">
#       <p class="nav-text">
#        <a href="../../../index.html">
#         man7.org
#        </a>
#        &gt; Linux &gt;
#        <a href="../index.html">
#         man-pages
#        </a>
#       </p>
#      </td>
#      <td class="training-cell">
#       <p class="training-text">
#        <a class="training-link" href="http://man7.org/training/">
#         Linux/UNIX system programming training
#        </a>
#       </p>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <hr class="nav-end"/>
#   <!--%%%PAGE_START%%%-->
#   <h1>
#    uniq(1) — Linux manual page
#   </h1>
#   <table class="sec-table">
#    <tr>
#     <td>
#      <p class="section-dir">
#       <a href="#NAME">
#        NAME
#       </a>
#       |
#       <a href="#SYNOPSIS">
#        SYNOPSIS
#       </a>
#       |
#       <a href="#DESCRIPTION">
#        DESCRIPTION
#       </a>
#       |
#       <a href="#AUTHOR">
#        AUTHOR
#       </a>
#       |
#       <a href="#REPORTING_BUGS">
#        REPORTING BUGS
#       </a>
#       |
#       <a href="#COPYRIGHT">
#        COPYRIGHT
#       </a>
#       |
#       <a href="#SEE_ALSO">
#        SEE ALSO
#       </a>
#       |
#       <a href="#COLOPHON">
#        COLOPHON
#       </a>
#      </p>
#     </td>
#    </tr>
#    <tr>
#     <td class="search-box">
#      <div class="man-search-box">
#       <form action="https://www.google.com/search" method="get">
#        <fieldset class="man-search">
#         <input maxlength="255" name="q" size="10" type="text" value=""/>
#         <input name="sitesearch" type="hidden" value="man7.org/linux/man-pages"/>
#         <input name="sa" type="submit" value="Search online pages"/>
#        </fieldset>
#       </form>
#      </div>
#     </td>
#     <td>
#     </td>
#    </tr>
#   </table>
#   <!--%%%TEXT_START%%%-->
#   <pre>
# <span class="headline">UNIQ(1)                       User Commands                      UNIQ(1)</span>
# </pre>
#   <h2>
#    <a href="#NAME" id="NAME">
#    </a>
#    NAME
#    <a href="#top_of_page">
#     <span class="top-link">
#      top
#     </span>
#    </a>
#   </h2>
#   <pre>
#        uniq - report or omit repeated lines
# </pre>
#   <h2>
#    <a href="#SYNOPSIS" id="SYNOPSIS">
#    </a>
#    SYNOPSIS
#    <a href="#top_of_page">
#     <span class="top-link">
#      top
#     </span>
#    </a>
#   </h2>
#   <pre>
#        <b>uniq </b>[<i>OPTION</i>]... [<i>INPUT</i> [<i>OUTPUT</i>]]
# </pre>
#   <h2>
#    <a href="#DESCRIPTION" id="DESCRIPTION">
#    </a>
#    DESCRIPTION
#    <a href="#top_of_page">
#     <span class="top-link">
#      top
#     </span>
#    </a>
#   </h2>
#   <pre>
#        Filter adjacent matching lines from INPUT (or standard input),
#        writing to OUTPUT (or standard output).
#
#        With no options, matching lines are merged to the first
#        occurrence.
#
#        Mandatory arguments to long options are mandatory for short
#        options too.
#
#        <b>-c</b>, <b>--count</b>
#               prefix lines by the number of occurrences
#
#        <b>-d</b>, <b>--repeated</b>
#               only print duplicate lines, one for each group
#
#        <b>-D     </b>print all duplicate lines
#
#        <b>--all-repeated</b>[=<i>METHOD</i>]
#               like <b>-D</b>, but allow separating groups with an empty line;
#               METHOD={none(default),prepend,separate}
#
#        <b>-f</b>, <b>--skip-fields</b>=<i>N</i>
#               avoid comparing the first N fields
#
#        <b>--group</b>[=<i>METHOD</i>]
#               show all items, separating groups with an empty line;
#               METHOD={separate(default),prepend,append,both}
#
#        <b>-i</b>, <b>--ignore-case</b>
#               ignore differences in case when comparing
#
#        <b>-s</b>, <b>--skip-chars</b>=<i>N</i>
#               avoid comparing the first N characters
#
#        <b>-u</b>, <b>--unique</b>
#               only print unique lines
#
#        <b>-z</b>, <b>--zero-terminated</b>
#               line delimiter is NUL, not newline
#
#        <b>-w</b>, <b>--check-chars</b>=<i>N</i>
#               compare no more than N characters in lines
#
#        <b>--help </b>display this help and exit
#
#        <b>--version</b>
#               output version information and exit
#
#        A field is a run of blanks (usually spaces and/or TABs), then
#        non-blank characters.  Fields are skipped before chars.
#
#        Note: 'uniq' does not detect repeated lines unless they are
#        adjacent.  You may want to sort the input first, or use 'sort <b>-u</b>'
#        without 'uniq'.
# </pre>
#   <h2>
#    <a href="#AUTHOR" id="AUTHOR">
#    </a>
#    AUTHOR
#    <a href="#top_of_page">
#     <span class="top-link">
#      top
#     </span>
#    </a>
#   </h2>
#   <pre>
#        Written by Richard M. Stallman and David MacKenzie.
# </pre>
#   <h2>
#    <a href="#REPORTING_BUGS" id="REPORTING_BUGS">
#    </a>
#    REPORTING BUGS
#    <a href="#top_of_page">
#     <span class="top-link">
#      top
#     </span>
#    </a>
#   </h2>
#   <pre>
#        GNU coreutils online help:
#        &lt;<a href="https://www.gnu.org/software/coreutils/">https://www.gnu.org/software/coreutils/</a>&gt;
#        Report any translation bugs to
#        &lt;<a href="https://translationproject.org/team/">https://translationproject.org/team/</a>&gt;
# </pre>
#   <h2>
#    <a href="#COPYRIGHT" id="COPYRIGHT">
#    </a>
#    COPYRIGHT
#    <a href="#top_of_page">
#     <span class="top-link">
#      top
#     </span>
#    </a>
#   </h2>
#   <pre>
#        Copyright Â© 2020 Free Software Foundation, Inc.  License GPLv3+:
#        GNU GPL version 3 or later &lt;<a href="https://gnu.org/licenses/gpl.html">https://gnu.org/licenses/gpl.html</a>&gt;.
#        This is free software: you are free to change and redistribute
#        it.  There is NO WARRANTY, to the extent permitted by law.
# </pre>
#   <h2>
#    <a href="#SEE_ALSO" id="SEE_ALSO">
#    </a>
#    SEE ALSO
#    <a href="#top_of_page">
#     <span class="top-link">
#      top
#     </span>
#    </a>
#   </h2>
#   <pre>
#        <a href="../man1/comm.1.html">comm(1)</a>, <a href="../man1/join.1.html">join(1)</a>, <a href="../man1/sort.1.html">sort(1)</a>
#
#        Full documentation &lt;<a href="https://www.gnu.org/software/coreutils/uniq">https://www.gnu.org/software/coreutils/uniq</a>&gt;
#        or available locally via: info '(coreutils) uniq invocation'
# </pre>
#   <h2>
#    <a href="#COLOPHON" id="COLOPHON">
#    </a>
#    COLOPHON
#    <a href="#top_of_page">
#     <span class="top-link">
#      top
#     </span>
#    </a>
#   </h2>
#   <pre>
#        This page is part of the <i>coreutils</i> (basic file, shell and text
#        manipulation utilities) project.  Information about the project
#        can be found at â¨<a href="http://www.gnu.org/software/coreutils/">http://www.gnu.org/software/coreutils/</a>â©.  If you
#        have a bug report for this manual page, see
#        â¨<a href="http://www.gnu.org/software/coreutils/">http://www.gnu.org/software/coreutils/</a>â©.  This page was obtained
#        from the tarball coreutils-8.32.tar.xz fetched from
#        â¨<a href="http://ftp.gnu.org/gnu/coreutils/">http://ftp.gnu.org/gnu/coreutils/</a>â© on 2021-08-27.  If you
#        discover any rendering problems in this HTML version of the page,
#        or you believe there is a better or more up-to-date source for
#        the page, or you have corrections or improvements to the
#        information in this COLOPHON (which is <i>not</i> part of the original
#        manual page), send a mail to man-pages@man7.org
#
# <span class="footline">GNU coreutils 8.32             March 2020                        UNIQ(1)</span>
# </pre>
#   <hr class="end-man-text"/>
#   <p>
#    Pages that refer to this page:
#    <a href="../man1/comm.1.html">
#     comm(1)
#    </a>
#    ,
#    <a href="../man1/join.1.html">
#     join(1)
#    </a>
#    ,
#    <a href="../man1/sort.1.html">
#     sort(1)
#    </a>
#   </p>
#   <hr/>
#   <hr class="start-footer"/>
#   <div class="footer">
#    <table class="colophon-table">
#     <tr>
#      <td class="pub-info">
#       <p>
#        HTML rendering created 2021-08-27
#             by
#        <a href="https://man7.org/mtk/index.html">
#         Michael Kerrisk
#        </a>
#        ,
#             author of
#        <a href="https://man7.org/tlpi/">
#         <em>
#          The Linux Programming Interface
#         </em>
#        </a>
#        ,
#             maintainer of the
#        <a href="https://www.kernel.org/doc/man-pages/">
#         Linux
#         <em>
#          man-pages
#         </em>
#         project
#        </a>
#        .
#       </p>
#       <p>
#        For details of in-depth
#        <strong>
#         Linux/UNIX system programming training courses
#        </strong>
#        that I teach, look
#        <a href="https://man7.org/training/">
#         here
#        </a>
#        .
#       </p>
#       <p>
#        Hosting by
#        <a href="https://www.jambit.com/index_en.html">
#         jambit GmbH
#        </a>
#        .
#       </p>
#      </td>
#      <td class="colophon-divider">
#      </td>
#      <td class="tlpi-cover">
#       <a href="https://man7.org/tlpi/">
#        <img alt="Cover of TLPI" src="https://man7.org/tlpi/cover/TLPI-front-cover-vsmall.png"/>
#       </a>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <hr class="end-footer"/>
#   <!--BEGIN-SITETRACKING-->
#   <!-- SITETRACKING.man7.org_linux_man-pages -->
#   <!-- Default Statcounter code for man7.org/linux/man-pages
# http://www.man7.org/linux/man-pages -->
#   <script type="text/javascript">
#    var sc_project=7422636;
# var sc_invisible=1;
# var sc_security="9b6714ff";
#   </script>
#   <script async="" src="https://www.statcounter.com/counter/counter.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div class="statcounter">
#     <a href="https://statcounter.com/" target="_blank" title="Web Analytics
# Made Easy - StatCounter">
#      <img alt="Web Analytics Made Easy -
# StatCounter" class="statcounter" src="https://c.statcounter.com/7422636/0/9b6714ff/1/"/>
#     </a>
#    </div>
#   </noscript>
#   <!-- End of Statcounter Code -->
#   <!-- Start of Google Analytics Code -->
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-9830363-8']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#   </script>
#   <!-- End of Google Analytics Code -->
#   <!--END-SITETRACKING-->
#  </body>
# </html>

# %% [markdown]
# The syntax example could definitely be extremely useful in the future when creating the generator and determining the order in which to assemble the options and arguments.

# %%
desc = soup.find_all('pre')[2].text
print(desc)
# Out:
#        uniq [OPTION]... [INPUT [OUTPUT]]

# %%
options = "\n".join([soup.find_all('pre')[3].text, soup.find_all('pre')[4].text])
print(options[:500])
# Out:
#        Filter adjacent matching lines from INPUT (or standard input),
#        writing to OUTPUT (or standard output).
#
#        With no options, matching lines are merged to the first
#        occurrence.
#
#        Mandatory arguments to long options are mandatory for short
#        options too.
#
#        -c, --count
#               prefix lines by the number of occurrences
#
#        -d, --repeated
#               only print duplicate lines, one for each group
#
#        -D     print all duplicate lines
#
#        --

# %%
# extracting and cleaning the corresponding flags
punctuation = set(_ for _ in ",.()")
stripped_options = [line.strip() for line in options.split('\n')]
flag_lines = list(filter(lambda x: x and x[0] == "-", stripped_options))
flags = [line.split(" ")[0] for line in flag_lines]
clean_flags = [f if f[-1] not in punctuation else f[:-1] for f in flags]
clean_flags = [f if "[" not in f else f.split("[")[0] for f in clean_flags]
set(clean_flags)
# Out:
# {'-D',
#  '-H',
#  '-L',
#  '-Olevel',
#  '-P',
#  '-cnewer',
#  '-execdir',
#  '-files0-from',
#  '-noleaf',
#  '-regex'}

# %% [markdown]
# ## Scaling for all of our utilities
#
# Now that we've been able to get a list of flags for one of our utilities, we can scale the solution to collect all of the available flags for each utility in our list of 23 utilities. To do this, we will apply the same parsing above to each utility webpage.

# %%
data = {}

# %%
for utility in utilities:
    utility_url = f'https://man7.org/linux/man-pages/man1/{utility}.1.html'
    r = requests.get(utility_url)
    soup = BeautifulSoup(r.text)
    desc = soup.find_all('pre')[2].text
    options = "\n".join([soup.find_all('pre')[3].text, soup.find_all('pre')[4].text])
    stripped_options = [line.strip() for line in options.split('\n')]
    flag_lines = list(filter(lambda x: x and x[0] == "-", stripped_options))
    clean_flags = flag_lines
    d = set(flag for flag in clean_flags)
    data[utility] = {}
    data[utility]['lines'] = d
    print(desc)
# Out:
#        find [-H] [-L] [-P] [-D debugopts] [-Olevel] [starting-point...]
#        [expression]
#
#
#        xargs [options] [command [initial-arguments]]
#
#
#        grep [OPTION...] PATTERNS [FILE...]
#        grep [OPTION...] -e PATTERNS ... [FILE...]
#        grep [OPTION...] -f PATTERN_FILE ... [FILE...]
#
#
#        rm [OPTION]... [FILE]...
#
#
#        echo [SHORT-OPTION]... [STRING]...
#        echo LONG-OPTION
#
#
#        ls [OPTION]... [FILE]...
#
#
#        sort [OPTION]... [FILE]...
#        sort [OPTION]... --files0-from=F
#
#
#        chmod [OPTION]... MODE[,MODE]... FILE...
#        chmod [OPTION]... OCTAL-MODE FILE...
#        chmod [OPTION]... --reference=RFILE FILE...
#
#
#        wc [OPTION]... [FILE]...
#        wc [OPTION]... --files0-from=F
#
#
#        cat [OPTION]... [FILE]...
#
#
#        cut OPTION... [FILE]...
#
#
#        head [OPTION]... [FILE]...
#
#
#        mv [OPTION]... [-T] SOURCE DEST
#        mv [OPTION]... SOURCE... DIRECTORY
#        mv [OPTION]... -t DIRECTORY SOURCE...
#
#
#        chown [OPTION]... [OWNER][:[GROUP]] FILE...
#        chown [OPTION]... --reference=RFILE FILE...
#
#
#        cp [OPTION]... [-T] SOURCE DEST
#        cp [OPTION]... SOURCE... DIRECTORY
#        cp [OPTION]... -t DIRECTORY SOURCE...
#
#
#        mkdir [OPTION]... DIRECTORY...
#
#
#        tr [OPTION]... SET1 [SET2]
#
#
#        tail [OPTION]... [FILE]...
#
#
#        dirname [OPTION] NAME...
#
#
#    Traditional usage
#        tar {A|c|d|r|t|u|x}[GnSkUWOmpsMBiajJzZhPlRvwo] [ARG...]
#
#    UNIX-style usage
#        tar -A [OPTIONS] ARCHIVE ARCHIVE
#
#        tar -c [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -d [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -t [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#        tar -r [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -u [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -x [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#    GNU-style usage
#        tar {--catenate|--concatenate} [OPTIONS] ARCHIVE ARCHIVE
#
#        tar --create [--file ARCHIVE] [OPTIONS] [FILE...]
#
#        tar {--diff|--compare} [--file ARCHIVE] [OPTIONS] [FILE...]
#
#        tar --delete [--file ARCHIVE] [OPTIONS] [MEMBER...]
#
#        tar --append [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar --list [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#        tar --test-label [--file ARCHIVE] [OPTIONS] [LABEL...]
#
#        tar --update [--file ARCHIVE] [OPTIONS] [FILE...]
#
#        tar --update [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar {--extract|--get} [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#
#        uniq [OPTION]... [INPUT [OUTPUT]]
#
#
#        ln [OPTION]... [-T] TARGET LINK_NAME
#        ln [OPTION]... TARGET
#        ln [OPTION]... TARGET... DIRECTORY
#        ln [OPTION]... -t DIRECTORY TARGET...
#
#
#        split [OPTION]... [FILE [PREFIX]]

# %%
data
# Out:
# {'find': {'lines': {'-D debugopts',
#    '-D help.  Valid debug options include',
#    '-H     Do not follow symbolic links, except while processing the',
#    '-L     Follow symbolic links.  When find examines or prints',
#    '-Olevel',
#    '-P     Never follow symbolic links.  This is the default',
#    '-cnewer.',
#    '-execdir, -ok and -okdir',
#    '-files0-from to pass arbitrary starting points to find.',
#    '-noleaf.  If you later use the -P option, -noleaf will',
#    '-regex) are performed first.'}},
#  'xargs': {'lines': {'--delimiter=delim, -d delim',
#    '--help Print a summary of the options to xargs and exit.',
#    '--process-slot-var=name',
#    '--show-limits',
#    '--version',
#    '-0, --null',
#    '-E eof-str',
#    '-I replace-str',
#    '-L max-lines',
#    '-P max-procs, --max-procs=max-procs',
#    '-P option.',
#    '-a file, --arg-file=file',
#    '-e[eof-str], --eof[=eof-str]',
#    '-i[replace-str], --replace[=replace-str]',
#    '-l[max-lines], --max-lines[=max-lines]',
#    '-n max-args, --max-args=max-args',
#    '-o, --open-tty',
#    '-p, --interactive',
#    '-r, --no-run-if-empty',
#    '-s max-chars, --max-chars=max-chars',
#    '-s option) is exceeded, unless the -x option is given, in',
#    '-t, --verbose',
#    '-x, --exit'}},
#  'grep': {'lines': {'--binary-files=TYPE',
#    '--binary-files=without-match option.',
#    '--color[=WHEN], --colour[=WHEN]',
#    '--count option is also used, grep does not output a count',
#    '--exclude-dir=GLOB',
#    '--exclude-from=FILE',
#    '--exclude=GLOB',
#    '--group-separator=SEP',
#    '--help Output a usage message and exit.',
#    '--include=GLOB',
#    '--label=LABEL',
#    '--line-buffered',
#    '--no-group-separator',
#    '--no-ignore-case',
#    '--no-messages option.',
#    '--only-matching option, this has no effect and a warning',
#    '-A NUM, --after-context=NUM',
#    '-B NUM, --before-context=NUM',
#    '-C NUM, -NUM, --context=NUM',
#    '-D ACTION, --devices=ACTION',
#    '-E, --extended-regexp',
#    '-F, --fixed-strings',
#    '-G, --basic-regexp',
#    '-H, --with-filename',
#    '-I     Process a binary file as if it did not contain matching',
#    '-L, --files-without-match',
#    '-P, --perl-regexp',
#    '-R, --dereference-recursive',
#    '-T, --initial-tab',
#    '-U, --binary',
#    '-V, --version',
#    '-Z, --null',
#    '-a, --text',
#    '-b, --byte-offset',
#    '-c, --count',
#    '-d ACTION, --directories=ACTION',
#    '-d recurse option.',
#    '-e PATTERNS, --regexp=PATTERNS',
#    '-f FILE, --file=FILE',
#    '-h, --no-filename',
#    '-i, --ignore-case',
#    '-l, --files-with-matches',
#    '-m NUM, --max-count=NUM',
#    '-n, --line-number',
#    '-o, --only-matching',
#    '-q, --quiet, --silent',
#    '-r, --recursive',
#    '-s, --no-messages',
#    '-v, --invert-match',
#    '-w, --word-regexp',
#    '-x, --line-regexp',
#    '-y     Obsolete synonym for -i.',
#    '-z, --null-data',
#    '-z, and xargs -0 to process arbitrary file names, even'}},
#  'rm': {'lines': {'--help display this help and exit',
#    '--interactive=always option is given, rm prompts the user for',
#    '--interactive[=WHEN]',
#    '--no-preserve-root',
#    '--one-file-system',
#    '--preserve-root[=all]',
#    '--version',
#    '-I     prompt once before removing more than three files, or when',
#    '-d, --dir',
#    '-f, --force',
#    '-i     prompt before every removal',
#    '-r, -R, --recursive',
#    '-v, --verbose'}},
#  'echo': {'lines': {'--help display this help and exit',
#    '--version',
#    '-E     disable interpretation of backslash escapes (default)',
#    '-e     enable interpretation of backslash escapes',
#    '-n     do not output the trailing newline'}},
#  'ls': {'lines': {'--author',
#    '--block-size=SIZE',
#    '--color[=WHEN]',
#    '--dereference-command-line-symlink-to-dir',
#    '--file-type',
#    '--format=WORD',
#    '--full-time',
#    '--group-directories-first',
#    '--help display this help and exit',
#    '--hide=PATTERN',
#    '--hyperlink[=WHEN]',
#    '--indicator-style=WORD',
#    '--quoting-style=WORD',
#    '--show-control-chars',
#    '--si   likewise, but use powers of 1000 not 1024',
#    '--sort is specified.',
#    '--sort=WORD',
#    '--sort=none (-U) disables grouping',
#    '--sort=time, sort by WORD (newest first)',
#    '--time-style=TIME_STYLE',
#    '--time=WORD',
#    '--version',
#    "-1     list one file per line.  Avoid '\\n' with -q or -b",
#    '-A, --almost-all',
#    '-B, --ignore-backups',
#    '-C     list entries by columns',
#    '-D, --dired',
#    '-F, --classify',
#    '-G, --no-group',
#    '-H, --dereference-command-line',
#    '-I, --ignore=PATTERN',
#    '-L, --dereference',
#    '-N, --literal',
#    '-Q, --quote-name',
#    '-R, --recursive',
#    '-S     sort by file size, largest first',
#    '-T, --tabsize=COLS',
#    '-U     do not sort; list entries in directory order',
#    '-X     sort alphabetically by entry extension',
#    '-Z, --context',
#    '-a, --all',
#    '-b, --escape',
#    '-c     with -lt: sort by, and show, ctime (time of last',
#    '-d, --directory',
#    '-f     do not sort, enable -aU, disable -ls --color',
#    '-g     like -l, but do not list owner',
#    '-h, --human-readable',
#    '-i, --inode',
#    '-k, --kibibytes',
#    '-l     use a long listing format',
#    '-m     fill width with a comma separated list of entries',
#    '-n, --numeric-uid-gid',
#    '-o     like -l, but do not list group information',
#    '-p, --indicator-style=slash',
#    '-q, --hide-control-chars',
#    '-r, --reverse',
#    '-s and per directory totals',
#    '-s, --size',
#    '-t     sort by time, newest first; see --time',
#    '-u     with -lt: sort by, and show, access time; with -l: show',
#    '-v     natural sort of (version) numbers within text',
#    '-w, --width=COLS',
#    '-x     list entries by lines instead of by columns'}},
#  'sort': {'lines': {'--batch-size=NMERGE',
#    '--compress-program=PROG',
#    '--debug',
#    '--files0-from=F',
#    '--help display this help and exit',
#    '--parallel=N',
#    '--random-source=FILE',
#    '--sort=WORD',
#    '--version',
#    '-C, --check=quiet, --check=silent',
#    '-M, --month-sort',
#    '-R, --random-sort',
#    '-S, --buffer-size=SIZE',
#    '-T, --temporary-directory=DIR',
#    '-V, --version-sort',
#    '-b, --ignore-leading-blanks',
#    '-c, --check, --check=diagnose-first',
#    '-d',
#    '-d, --dictionary-order',
#    '-f, --ignore-case',
#    '-g, --general-numeric-sort',
#    '-h, --human-numeric-sort',
#    '-h, month -M, numeric -n, random -R, version -V',
#    '-i, --ignore-nonprinting',
#    '-k, --key=KEYDEF',
#    '-m, --merge',
#    '-n, --numeric-sort',
#    '-o, --output=FILE',
#    '-r, --reverse',
#    '-s, --stable',
#    '-t, --field-separator=SEP',
#    '-u, --unique',
#    '-z, --zero-terminated'}},
#  'chmod': {'lines': set()},
#  'wc': {'lines': {'--files0-from=F',
#    '--help display this help and exit',
#    '--version',
#    '-L, --max-line-length',
#    '-c, --bytes',
#    '-l, --lines',
#    '-m, --chars',
#    '-w, --words'}},
#  'cat': {'lines': {'--help display this help and exit',
#    '--version',
#    '-A, --show-all',
#    '-E, --show-ends',
#    '-T, --show-tabs',
#    '-b, --number-nonblank',
#    '-e     equivalent to -vE',
#    '-n, --number',
#    '-s, --squeeze-blank',
#    '-t     equivalent to -vT',
#    '-u     (ignored)',
#    '-v, --show-nonprinting'}},
#  'cut': {'lines': {'--complement',
#    '--help display this help and exit',
#    '--output-delimiter=STRING',
#    '--version',
#    "-M     from first to M'th (included) byte, character or field",
#    '-b, --bytes=LIST',
#    '-c, --characters=LIST',
#    '-d, --delimiter=DELIM',
#    '-f, --fields=LIST',
#    '-n     (ignored)',
#    '-s, --only-delimited',
#    '-z, --zero-terminated'}},
#  'head': {'lines': {'--help display this help and exit',
#    '--version',
#    '-c, --bytes=[-]NUM',
#    '-n, --lines=[-]NUM',
#    '-q, --quiet, --silent',
#    '-v, --verbose',
#    '-z, --zero-terminated'}},
#  'mv': {'lines': {'--backup[=CONTROL]',
#    '--help display this help and exit',
#    '--strip-trailing-slashes',
#    '--version',
#    '-S, --suffix=SUFFIX',
#    '-T, --no-target-directory',
#    '-Z, --context',
#    '-b     like --backup but does not accept an argument',
#    '-f, --force',
#    '-i, --interactive',
#    '-n, --no-clobber',
#    '-t, --target-directory=DIRECTORY',
#    '-u, --update',
#    '-v, --verbose'}},
#  'chown': {'lines': {'--dereference',
#    '--from=CURRENT_OWNER:CURRENT_GROUP',
#    '--help display this help and exit',
#    '--no-preserve-root',
#    '--preserve-root',
#    '--reference=RFILE',
#    '--version',
#    '-H     if a command line argument is a symbolic link to a',
#    '-L     traverse every symbolic link to a directory encountered',
#    '-P     do not traverse any symbolic links (default)',
#    '-R, --recursive',
#    '-c, --changes',
#    '-f, --silent, --quiet',
#    '-h, --no-dereference',
#    '-v, --verbose'}},
#  'cp': {'lines': {'--attributes-only',
#    '--backup[=CONTROL]',
#    '--context[=CTX]',
#    '--copy-contents',
#    '--help display this help and exit',
#    '--no-preserve=ATTR_LIST',
#    '--parents',
#    '--preserve[=ATTR_LIST]',
#    '--reflink[=WHEN]',
#    '--remove-destination',
#    '--sparse=WHEN',
#    '--strip-trailing-slashes',
#    '--version',
#    '-H     follow command-line symbolic links in SOURCE',
#    '-L, --dereference',
#    '-P, --no-dereference',
#    '-R, -r, --recursive',
#    '-S, --suffix=SUFFIX',
#    '-T, --no-target-directory',
#    '-Z     set SELinux security context of destination file to',
#    '-a, --archive',
#    '-b     like --backup but does not accept an argument',
#    '-d     same as --no-dereference --preserve=links',
#    '-f, --force',
#    '-i, --interactive',
#    '-l, --link',
#    '-n, --no-clobber',
#    '-p     same as --preserve=mode,ownership,timestamps',
#    '-s, --symbolic-link',
#    '-t, --target-directory=DIRECTORY',
#    '-u, --update',
#    '-v, --verbose',
#    '-x, --one-file-system'}},
#  'mkdir': {'lines': {'--context[=CTX]',
#    '--help display this help and exit',
#    '--version',
#    '-Z     set SELinux security context of each created directory to',
#    '-m, --mode=MODE',
#    '-p, --parents',
#    '-v, --verbose'}},
#  'tr': {'lines': {'--help display this help and exit',
#    '--version',
#    '-c, -C, --complement',
#    '-d, --delete',
#    '-s, --squeeze-repeats',
#    '-t, --truncate-set1'}},
#  'tail': {'lines': {'--follow=name in that case.  That causes tail to track the named',
#    '--help display this help and exit',
#    '--max-unchanged-stats=N',
#    '--pid=PID',
#    '--retry',
#    '--version',
#    '-F     same as --follow=name --retry',
#    '-c, --bytes=[+]NUM',
#    '-f, --follow[={name|descriptor}]',
#    '-n +NUM to output starting with line NUM',
#    '-n, --lines=[+]NUM',
#    '-q, --quiet, --silent',
#    '-s, --sleep-interval=N',
#    '-v, --verbose',
#    '-z, --zero-terminated'}},
#  'dirname': {'lines': {'--help display this help and exit',
#    '--version',
#    '-> "."',
#    '-> "/usr"',
#    '-> "dir1" followed by "dir2"',
#    '-z, --zero'}},
#  'tar': {'lines': {'--delete',
#    '--show-defaults',
#    '--test-label',
#    '--usage',
#    '--version',
#    '-?, --help',
#    '-A, --catenate, --concatenate',
#    "-c and -r options.  Notice, that newer files don't replace",
#    '-c, --create',
#    '-d, --diff, --compare',
#    '-r, --append',
#    '-t, --list',
#    '-u, --update',
#    '-x, --extract, --get'}},
#  'uniq': {'lines': {'--all-repeated[=METHOD]',
#    '--group[=METHOD]',
#    '--help display this help and exit',
#    '--version',
#    '-D     print all duplicate lines',
#    '-c, --count',
#    '-d, --repeated',
#    '-f, --skip-fields=N',
#    '-i, --ignore-case',
#    '-s, --skip-chars=N',
#    '-u, --unique',
#    '-w, --check-chars=N',
#    '-z, --zero-terminated'}},
#  'ln': {'lines': {'--backup[=CONTROL]',
#    '--help display this help and exit',
#    '--symbolic.  By default, each destination (name of new link)',
#    '--version',
#    '-L, --logical',
#    '-P, --physical',
#    '-P.',
#    '-S, --suffix=SUFFIX',
#    '-T, --no-target-directory',
#    '-b     like --backup but does not accept an argument',
#    '-d, -F, --directory',
#    '-f, --force',
#    '-i, --interactive',
#    '-n, --no-dereference',
#    '-r, --relative',
#    '-s, --symbolic',
#    '-t, --target-directory=DIRECTORY',
#    '-v, --verbose'}},
#  'split': {'lines': {'--additional-suffix=SUFFIX',
#    '--filter=COMMAND',
#    '--help display this help and exit',
#    '--hex-suffixes[=FROM]',
#    '--numeric-suffixes[=FROM]',
#    '--verbose',
#    '--version',
#    '-C, --line-bytes=SIZE',
#    '-a, --suffix-length=N',
#    '-b, --bytes=SIZE',
#    '-d     use numeric suffixes starting at 0, not alphabetic',
#    '-e, --elide-empty-files',
#    '-l, --lines=NUMBER',
#    '-n, --number=CHUNKS',
#    '-t, --separator=SEP',
#    '-u, --unbuffered',
#    '-x     use hex suffixes starting at 0, not alphabetic'}}}

# %%
# The number of flags in our data structure
sum(len(data[x]['lines']) for x in data)
# Out:
# 399

# %%
def get_inner_brackets(s):
    open_idx = s.index("[") + 1
    closed_idx = s.index("]")
    a = s[open_idx: closed_idx]
    a = a.replace("=", "")
    return a

def get_equal_arg(s):
    return remove_punctuation(s.split("=")[1])
    
def remove_punctuation(s):
    punctuation = set(_ for _ in ",.()")
    return "".join([x if x not in punctuation else "" for x in s])
    
def remove_brackets(s):
    brackets = {"[", "]"}
    return "".join([x if x not in brackets else "" for x in s])

def get_flag(line):
    punctuation = set(p for p in "[].,()=[]")
    for val in punctuation:
        line = line.replace(val, " ")
    flag = line.split(" ")[0]
    return flag

# %% [markdown]
# ## Cleaning Flags

# %%
for ut in data:
    for flag_line in data[ut]['lines']:
        flag_line = remove_punctuation(flag_line)
        flag, arg = get_flag(flag_line), None
        if "[" in flag_line and "]" in flag_line:
            arg = get_inner_brackets(flag_line)
        elif "=" in flag_line:
            arg = get_equal_arg(flag_line)
        data[ut][flag] = arg

# %%
for ut in data:
    if 'lines' in data[ut]:
        del data[ut]['lines']
        
data
# Out:
# {'find': {'-D': None,
#   '-execdir': None,
#   '-Olevel': None,
#   '-files0-from': None,
#   '-regex': None,
#   '-cnewer': None,
#   '-H': None,
#   '-noleaf': None,
#   '-P': None,
#   '-L': None},
#  'xargs': {'-s': 'max-chars',
#   '--delimiter': 'delim -d delim',
#   '-p': None,
#   '-0': None,
#   '--process-slot-var': 'name',
#   '-n': 'max-args',
#   '-t': None,
#   '-L': None,
#   '-a': 'file',
#   '-P': 'max-procs',
#   '-l': 'max-lines',
#   '-r': None,
#   '-I': None,
#   '-i': 'replace-str',
#   '--version': None,
#   '-o': None,
#   '--help': None,
#   '-E': None,
#   '--show-limits': None,
#   '-e': 'eof-str',
#   '-x': None},
#  'grep': {'-n': None,
#   '--binary-files': 'TYPE',
#   '-b': None,
#   '--exclude': 'GLOB',
#   '-z': None,
#   '-d': None,
#   '-R': None,
#   '-l': None,
#   '--line-buffered': None,
#   '--no-ignore-case': None,
#   '--count': None,
#   '-I': None,
#   '-o': None,
#   '-x': None,
#   '--label': 'LABEL',
#   '--include': 'GLOB',
#   '-C': 'NUM',
#   '-H': None,
#   '--no-messages': None,
#   '-c': None,
#   '-D': 'ACTION',
#   '-T': None,
#   '-L': None,
#   '-U': None,
#   '--exclude-from': 'FILE',
#   '-G': None,
#   '-A': 'NUM',
#   '-f': 'FILE',
#   '-s': None,
#   '-B': 'NUM',
#   '--no-group-separator': None,
#   '--help': None,
#   '--color': 'WHEN',
#   '-y': None,
#   '-V': None,
#   '--exclude-dir': 'GLOB',
#   '-e': 'PATTERNS',
#   '-w': None,
#   '-q': None,
#   '-v': None,
#   '-F': None,
#   '-m': 'NUM',
#   '-h': None,
#   '--only-matching': None,
#   '-a': None,
#   '-Z': None,
#   '-E': None,
#   '--group-separator': 'SEP',
#   '-r': None,
#   '-i': None,
#   '-P': None},
#  'rm': {'-f': None,
#   '--help': None,
#   '--no-preserve-root': None,
#   '-d': None,
#   '-i': None,
#   '--version': None,
#   '--one-file-system': None,
#   '--preserve-root': 'all',
#   '--interactive': 'WHEN',
#   '-I': None,
#   '-v': None,
#   '-r': None},
#  'echo': {'-n': None,
#   '--help': None,
#   '--version': None,
#   '-E': None,
#   '-e': None},
#  'ls': {'-u': None,
#   '-F': None,
#   '-x': None,
#   '--dereference-command-line-symlink-to-dir': None,
#   '--sort': 'none -U disables grouping',
#   '--hide': 'PATTERN',
#   '-w': 'COLS',
#   '-I': 'PATTERN',
#   '-v': None,
#   '--time': 'WORD',
#   '-b': None,
#   '--si': None,
#   '-n': None,
#   '-h': None,
#   '-H': None,
#   '--hyperlink': 'WHEN',
#   '-1': None,
#   '--block-size': 'SIZE',
#   '--format': 'WORD',
#   '--quoting-style': 'WORD',
#   '-t': None,
#   '-N': None,
#   '-S': None,
#   '-A': None,
#   '-X': None,
#   '-o': None,
#   '--color': 'WHEN',
#   '-r': None,
#   '--file-type': None,
#   '-R': None,
#   '-Z': None,
#   '--help': None,
#   '--show-control-chars': None,
#   '--author': None,
#   '-f': None,
#   '--indicator-style': 'WORD',
#   '-q': None,
#   '--version': None,
#   '--group-directories-first': None,
#   '-i': None,
#   '-s': None,
#   '-l': None,
#   '--time-style': 'TIME_STYLE',
#   '-p': 'slash',
#   '-a': None,
#   '--full-time': None,
#   '-U': None,
#   '-g': None,
#   '-T': 'COLS',
#   '-G': None,
#   '-B': None,
#   '-m': None,
#   '-k': None,
#   '-d': None,
#   '-Q': None,
#   '-C': None,
#   '-D': None,
#   '-c': None,
#   '-L': None},
#  'sort': {'-u': None,
#   '-h': None,
#   '--sort': 'WORD',
#   '--debug': None,
#   '--parallel': 'N',
#   '-M': None,
#   '-i': None,
#   '-z': None,
#   '-V': None,
#   '-T': 'DIR',
#   '-t': 'SEP',
#   '--compress-program': 'PROG',
#   '-f': None,
#   '-R': None,
#   '--help': None,
#   '-k': 'KEYDEF',
#   '-d': None,
#   '-b': None,
#   '-S': 'SIZE',
#   '--version': None,
#   '--batch-size': 'NMERGE',
#   '--files0-from': 'F',
#   '--random-source': 'FILE',
#   '-c': 'diagnose-first',
#   '-o': 'FILE',
#   '-s': None,
#   '-n': None,
#   '-m': None,
#   '-r': None,
#   '-C': 'quiet --check',
#   '-g': None},
#  'chmod': {},
#  'wc': {'--help': None,
#   '--version': None,
#   '-m': None,
#   '--files0-from': 'F',
#   '-c': None,
#   '-l': None,
#   '-w': None,
#   '-L': None},
#  'cat': {'-u': None,
#   '--help': None,
#   '-A': None,
#   '-v': None,
#   '-n': None,
#   '-E': None,
#   '--version': None,
#   '-b': None,
#   '-e': None,
#   '-s': None,
#   '-T': None,
#   '-t': None},
#  'cut': {'-f': 'LIST',
#   '-c': 'LIST',
#   '-z': None,
#   '--help': None,
#   '--version': None,
#   '-b': 'LIST',
#   '-d': 'DELIM',
#   '--output-delimiter': 'STRING',
#   '--complement': None,
#   '-n': None,
#   '-M': None,
#   '-s': None},
#  'head': {'-z': None,
#   '--help': None,
#   '--version': None,
#   '-c': '-',
#   '-v': None,
#   '-q': None,
#   '-n': '-'},
#  'mv': {'-f': None,
#   '-Z': None,
#   '-b': None,
#   '--help': None,
#   '-i': None,
#   '-S': 'SUFFIX',
#   '-T': None,
#   '-u': None,
#   '--version': None,
#   '--strip-trailing-slashes': None,
#   '-t': 'DIRECTORY',
#   '-v': None,
#   '--backup': 'CONTROL',
#   '-n': None},
#  'chown': {'-R': None,
#   '--help': None,
#   '--no-preserve-root': None,
#   '-P': None,
#   '-L': None,
#   '-H': None,
#   '--version': None,
#   '-c': None,
#   '-f': None,
#   '--from': 'CURRENT_OWNER:CURRENT_GROUP',
#   '--reference': 'RFILE',
#   '-v': None,
#   '--preserve-root': None,
#   '-h': None,
#   '--dereference': None},
#  'cp': {'--parents': None,
#   '--remove-destination': None,
#   '-P': None,
#   '-d': 'links',
#   '-H': None,
#   '--context': 'CTX',
#   '-i': None,
#   '-T': None,
#   '-u': None,
#   '-v': None,
#   '--backup': 'CONTROL',
#   '--reflink': 'WHEN',
#   '--copy-contents': None,
#   '-f': None,
#   '--help': None,
#   '-l': None,
#   '--sparse': 'WHEN',
#   '-Z': None,
#   '--version': None,
#   '-a': None,
#   '-R': None,
#   '-n': None,
#   '-b': None,
#   '--no-preserve': 'ATTR_LIST',
#   '-S': 'SUFFIX',
#   '-s': None,
#   '--attributes-only': None,
#   '-p': 'modeownershiptimestamps',
#   '--preserve': 'ATTR_LIST',
#   '--strip-trailing-slashes': None,
#   '-t': 'DIRECTORY',
#   '-x': None,
#   '-L': None},
#  'mkdir': {'--context': 'CTX',
#   '--help': None,
#   '--version': None,
#   '-Z': None,
#   '-m': 'MODE',
#   '-p': None,
#   '-v': None},
#  'tr': {'--help': None,
#   '--version': None,
#   '-d': None,
#   '-t': None,
#   '-s': None,
#   '-c': None},
#  'tail': {'-z': None,
#   '-n': None,
#   '--retry': None,
#   '--help': None,
#   '--max-unchanged-stats': 'N',
#   '--version': None,
#   '--pid': 'PID',
#   '-F': 'name --retry',
#   '-f': '{name|descriptor}',
#   '--follow': 'name in that case  That causes tail to track the named',
#   '-s': 'N',
#   '-v': None,
#   '-q': None,
#   '-c': '+'},
#  'dirname': {'--help': None, '->': None, '--version': None, '-z': None},
#  'tar': {'-?': None,
#   '--version': None,
#   '-u': None,
#   '-x': None,
#   '-c': None,
#   '--test-label': None,
#   '--show-defaults': None,
#   '-d': None,
#   '-A': None,
#   '-r': None,
#   '--usage': None,
#   '-t': None,
#   '--delete': None},
#  'uniq': {'-z': None,
#   '--help': None,
#   '-s': 'N',
#   '-u': None,
#   '--version': None,
#   '-c': None,
#   '-i': None,
#   '-w': 'N',
#   '--all-repeated': 'METHOD',
#   '-D': None,
#   '-f': 'N',
#   '--group': 'METHOD',
#   '-d': None},
#  'ln': {'-f': None,
#   '-n': None,
#   '--symbolic': None,
#   '-b': None,
#   '--help': None,
#   '-i': None,
#   '-S': 'SUFFIX',
#   '-T': None,
#   '-P': None,
#   '--version': None,
#   '-d': None,
#   '-L': None,
#   '-r': None,
#   '-t': 'DIRECTORY',
#   '-v': None,
#   '--backup': 'CONTROL',
#   '-s': None},
#  'split': {'--additional-suffix': 'SUFFIX',
#   '--help': None,
#   '-e': None,
#   '-C': 'SIZE',
#   '--filter': 'COMMAND',
#   '--version': None,
#   '-n': 'CHUNKS',
#   '--hex-suffixes': 'FROM',
#   '-a': 'N',
#   '--numeric-suffixes': 'FROM',
#   '-b': 'SIZE',
#   '--verbose': None,
#   '-l': 'NUMBER',
#   '-t': 'SEP',
#   '-x': None,
#   '-d': None,
#   '-u': None}}

# %%
# the number of flags that have arguments
count = 0
for ut in data:
    for flag in data[ut]:
        if data[ut][flag]: count +=1
count
# Out:
# 103

# %% [markdown]
# ## Manually Inserting Argument Types
#
# Now that we have the utilities mapped to the appropriate flags, we will need to manually insert the data types corresponding to each flag.

# %%
argument_types = [
    'Regex',
    'File',
    'Directory',
    'Path'
    'Number',
    '+Number',
    '-Number',
    'Quantity',
    '+Quantity',
    '-Quantity',
    'Size',
    '+Size',
    '-Size',
    'Timespan',
    '+Timespan',
    '-Timespan',
    'DateTime',
    '+DateTime',
    '-DateTime',
    'Permission',
    '+Permission',
    '-Permission'
]

# %% [markdown]
# Getting a sense of the argument types the parser has discovered

# %%
for ut in data:
    for flag in data[ut]:
        if data[ut][flag]:
            print(data[ut][flag])
# Out:
# max-chars
# delim -d delim
# name
# max-args
# file
# max-procs
# max-lines
# replace-str
# eof-str
# TYPE
# GLOB
# LABEL
# GLOB
# NUM
# ACTION
# FILE
# NUM
# FILE
# NUM
# WHEN
# GLOB
# PATTERNS
# NUM
# SEP
# all
# WHEN
# none -U disables grouping
# PATTERN
# COLS
# PATTERN
# WORD
# WHEN
# SIZE
# WORD
# WORD
# WHEN
# WORD
# TIME_STYLE
# slash
# COLS
# WORD
# N
# DIR
# SEP
# PROG
# KEYDEF
# SIZE
# NMERGE
# F
# FILE
# diagnose-first
# FILE
# quiet --check
# F
# LIST
# LIST
# LIST
# DELIM
# STRING
# -
# -
# SUFFIX
# DIRECTORY
# CONTROL
# CURRENT_OWNER:CURRENT_GROUP
# RFILE
# links
# CTX
# CONTROL
# WHEN
# WHEN
# ATTR_LIST
# SUFFIX
# modeownershiptimestamps
# ATTR_LIST
# DIRECTORY
# CTX
# MODE
# N
# PID
# name --retry
# {name|descriptor}
# name in that case  That causes tail to track the named
# N
# +
# N
# N
# METHOD
# N
# METHOD
# SUFFIX
# DIRECTORY
# CONTROL
# SUFFIX
# SIZE
# COMMAND
# CHUNKS
# FROM
# N
# FROM
# SIZE
# NUMBER
# SEP

# %%
type_mappings = {
    'Regex': {'str', 'sep', 'pattern', 'word'},
    'File': {'file'},
    'Directory': {'dir'},
    'Path': {'path'},
    'Number': {'num', 'n'},
    '+Number': {'max'},
}

# %%
# # find
# data['find']['-P'] = [None]
# data['find']['-L']= [None]
# data['find']['-noleaf'] = [None]
# data['find']['-H'] = [None]
# data['find']['-cnewer'] = ['File']
# if '-D' in data['find']:
#     del data['find']['-D']
# if '-D' in data['find']:
#     del data['find']['-execdir']
# data['find']['-Olevel'] = ['+Number'] 
# data['find']['-regex'] = ['regex'] 

# # xargs
# data['xargs']['-0'] = [None]
# data['xargs']['-a'] = ['File']
# if '--delimineter=delim' in data['xargs']:
#     del data['xargs']['--delimineter=delim']
# data['xargs']['-E'] = ['Regex']
# if '-e' in data['xargs']:
#     del data['xargs']['-e']
# data['xargs']['-I'] = ['Regex']
# if '-i' in data['xargs']:
#     del data['xargs']['-i']
# data['xargs']['-L'] = ['+Number']
# data['xargs']['-l']= ['+Number']
# data['xargs']['-n'] = ['+Number']
# data['xargs']['-s'] = ['+Number']
# data['xargs']['-P'] = ['Number']
# data['xargs']['-o'] = [None]
# data['xargs']['-p'] = [None]
# if '--process-slot-var=name' in data['xargs']:
#     del data['xargs']['--process-slot-var=name']
# data['xargs']['-r'] = [None]
# data['xargs']['--show-limits'] = [None]
# data['xargs']['-t'] = [None]
# data['xargs']['-x'] = [None]
# data['xargs']['--help'] = [None]
# data['xargs']['--version'] = [None]

# #grep
# data['grep']['--help'] = [None]
# data['grep']['-V'] = [None]
# data['grep']['-E'] = [None]
# data['grep']['-F'] = [None]
# data['grep']['-G'] = [None]
# data['grep']['-P'] = [None]
# data['grep']['-e'] = ['Regex']
# data['grep']['-f'] = ['File']
# data['grep']['-i'] = [None]
# data['grep']['--no-ignore-case'] = [None]
# data['grep']['-v'] = [None]
# data['grep']['-w'] = [None]
# data['grep']['-x'] = [None]
# data['grep']['-y'] = [None]
# data['grep']['-c'] = [None]
# if '--color' in data['grep']:
#     del data['grep']['--color']
# data['grep']['-L'] = [None]
# data['grep']['-l'] = [None]
# data['grep']['-m'] = ['+Number']
# data['grep']['--count'] = [None]
# data['grep']['-o'] = [None]
# data['grep']['-q'] = [None]
# data['grep']['--no-messages'] = [None]
# data['grep']['-s'] = [None]
# data['grep']['-b'] = [None]
# data['grep']['-H'] = [None]
# data['grep']['-h'] = [None]
# data['grep']['--label'] = ['Regex']
# if '--label=LABEL' in data['grep']:
#     del data['grep']['--label=LABEL']
# data['grep']['-n'] = [None]
# data['grep']['-T'] = [None]
# data['grep']['-Z'] = [None]
# if '-z' in data['grep']:
#     del data['grep']['-z']
# data['grep']['-A'] = ['+Number']
# data['grep']['--only-matching'] = [None]
# data['grep']['-B'] = ['+Number']
# data['grep']['-C'] = ['+Number']
# data['grep']['--group-separator'] = ['Regex']
# if '--group-separator=SEP' in data['grep']['']
#     del data['grep']['--group-separator=SEP']
# data['grep']['-a']
