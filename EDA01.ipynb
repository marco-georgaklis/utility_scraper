# %% [markdown]
# # Exploratory Data Analysis: Web Scraping Utilities with Beautiful Soup
#
# In this notebook, I hope to create a parser for web scraping the linux man pages to gather information on some of the most common utilities and their corresponding flags.

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 23 of the most common utilities
utilities = [
    "find",
    "xargs",
    "grep",
    "rm",
    "echo",
    "ls",
    "sort",
    "chmod",
    "wc",
    "cat",
    "cut",
    "head",
    "mv",
    "chown",
    "cp",
    "mkdir",
    "tr",
    "tail",
    "dirname",
    "tar",
    "uniq",
    "ln",
    "split",
]

# %% [markdown]
# ## Finding Flags for 1 Utility
# First, we want to create a parser to find the available flags for just one of the utilities. We will start with the 'find' utility and use the BeautifulSoup package to parse for the corresponding flags.

# %%
utility = "uniq"
utility_url = f'https://man7.org/linux/man-pages/man1/{utility}.1.html'
r = requests.get(utility_url)
soup = BeautifulSoup(r.text)
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    uniq(1) - Linux manual page
#   </title>
#   <link href="../../../style.css" rel="stylesheet" title="style" type="text/css"/>
#   <link href="../style.css" rel="stylesheet" title="style" type="text/css"/>
#  </head>
#  <body>
#   <div class="page-top">
#    <a id="top_of_page">
#    </a>
#   </div>
#   <!--%%%TOP_BAR%%%-->
#   <div class="nav-bar">
#    <table class="nav-table">
#     <tr>
#      <td class="nav-cell">
#       <p class="nav-text">
#        <a href="../../../index.html">
#         man7.org
#        </a>
#        &gt; Linux &gt;
#        <a href="../index.html">
#         man-pages
#        </a>
#       </p>
#      </td>
#      <td class="training-cell">
#       <p class="training-text">
#        <a class="training-link" href="http://man7.org/training/">
#         Linux/UNIX system programming training
#        </a>
#       </p>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <hr cl

# %% [markdown]
# The syntax example could definitely be extremely useful in the future when creating the generator and determining the order in which to assemble the options and arguments.

# %%
desc = soup.find_all('pre')[2].text
print(desc)
# Out:
#        uniq [OPTION]... [INPUT [OUTPUT]]

# %%
options = "\n".join([soup.find_all('pre')[3].text, soup.find_all('pre')[4].text])
print(options[:500])
# Out:
#        Filter adjacent matching lines from INPUT (or standard input),
#        writing to OUTPUT (or standard output).
#
#        With no options, matching lines are merged to the first
#        occurrence.
#
#        Mandatory arguments to long options are mandatory for short
#        options too.
#
#        -c, --count
#               prefix lines by the number of occurrences
#
#        -d, --repeated
#               only print duplicate lines, one for each group
#
#        -D     print all duplicate lines
#
#        --

# %%
# extracting and cleaning the corresponding flags
punctuation = set(_ for _ in ",.()")
stripped_options = [line.strip() for line in options.split('\n')]
flag_lines = list(filter(lambda x: x and x[0] == "-", stripped_options))
flags = [line.split(" ")[0] for line in flag_lines]
clean_flags = [f if f[-1] not in punctuation else f[:-1] for f in flags]
clean_flags = [f if "[" not in f else f.split("[")[0] for f in clean_flags]
set(clean_flags)
# Out:
# {'--all-repeated',
#  '--group',
#  '--help',
#  '--version',
#  '-D',
#  '-c',
#  '-d',
#  '-f',
#  '-i',
#  '-s',
#  '-u',
#  '-w',
#  '-z'}

# %% [markdown]
# ## Scaling for all of our utilities
#
# Now that we've been able to get a list of flags for one of our utilities, we can scale the solution to collect all of the available flags for each utility in our list of 23 utilities. To do this, we will apply the same parsing above to each utility webpage.

# %%
data = {}
descs = {}

# %%
for utility in utilities:
    utility_url = f'https://man7.org/linux/man-pages/man1/{utility}.1.html'
    r = requests.get(utility_url)
    soup = BeautifulSoup(r.text)
    desc = soup.find_all('pre')[2].text
    descs[utility] = desc.split('\n')[1].strip()
    options = "\n".join([soup.find_all('pre')[3].text, soup.find_all('pre')[4].text])
    stripped_options = [line.strip() for line in options.split('\n')]
    flag_lines = list(filter(lambda x: x and x[0] == "-", stripped_options))
    clean_flags = flag_lines
    d = set(flag for flag in clean_flags)
    data[utility] = {}
    data[utility]['lines'] = d
    print(desc)
# Out:
#        find [-H] [-L] [-P] [-D debugopts] [-Olevel] [starting-point...]
#        [expression]
#
#
#        xargs [options] [command [initial-arguments]]
#
#
#        grep [OPTION...] PATTERNS [FILE...]
#        grep [OPTION...] -e PATTERNS ... [FILE...]
#        grep [OPTION...] -f PATTERN_FILE ... [FILE...]
#
#
#        rm [OPTION]... [FILE]...
#
#
#        echo [SHORT-OPTION]... [STRING]...
#        echo LONG-OPTION
#
#
#        ls [OPTION]... [FILE]...
#
#
#        sort [OPTION]... [FILE]...
#        sort [OPTION]... --files0-from=F
#
#
#        chmod [OPTION]... MODE[,MODE]... FILE...
#        chmod [OPTION]... OCTAL-MODE FILE...
#        chmod [OPTION]... --reference=RFILE FILE...
#
#
#        wc [OPTION]... [FILE]...
#        wc [OPTION]... --files0-from=F
#
#
#        cat [OPTION]... [FILE]...
#
#
#        cut OPTION... [FILE]...
#
#
#        head [OPTION]... [FILE]...
#
#
#        mv [OPTION]... [-T] SOURCE DEST
#        mv [OPTION]... SOURCE... DIRECTORY
#        mv [OPTION]... -t DIRECTORY SOURCE...
#
#
#        chown [OPTION]... [OWNER][:[GROUP]] FILE...
#        chown [OPTION]... --reference=RFILE FILE...
#
#
#        cp [OPTION]... [-T] SOURCE DEST
#        cp [OPTION]... SOURCE... DIRECTORY
#        cp [OPTION]... -t DIRECTORY SOURCE...
#
#
#        mkdir [OPTION]... DIRECTORY...
#
#
#        tr [OPTION]... SET1 [SET2]
#
#
#        tail [OPTION]... [FILE]...
#
#
#        dirname [OPTION] NAME...
#
#
#    Traditional usage
#        tar {A|c|d|r|t|u|x}[GnSkUWOmpsMBiajJzZhPlRvwo] [ARG...]
#
#    UNIX-style usage
#        tar -A [OPTIONS] ARCHIVE ARCHIVE
#
#        tar -c [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -d [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -t [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#        tar -r [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -u [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar -x [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#    GNU-style usage
#        tar {--catenate|--concatenate} [OPTIONS] ARCHIVE ARCHIVE
#
#        tar --create [--file ARCHIVE] [OPTIONS] [FILE...]
#
#        tar {--diff|--compare} [--file ARCHIVE] [OPTIONS] [FILE...]
#
#        tar --delete [--file ARCHIVE] [OPTIONS] [MEMBER...]
#
#        tar --append [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar --list [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#        tar --test-label [--file ARCHIVE] [OPTIONS] [LABEL...]
#
#        tar --update [--file ARCHIVE] [OPTIONS] [FILE...]
#
#        tar --update [-f ARCHIVE] [OPTIONS] [FILE...]
#
#        tar {--extract|--get} [-f ARCHIVE] [OPTIONS] [MEMBER...]
#
#
#        uniq [OPTION]... [INPUT [OUTPUT]]
#
#
#        ln [OPTION]... [-T] TARGET LINK_NAME
#        ln [OPTION]... TARGET
#        ln [OPTION]... TARGET... DIRECTORY
#        ln [OPTION]... -t DIRECTORY TARGET...
#
#
#        split [OPTION]... [FILE [PREFIX]]

# %%
data
# Out:
# {'find': {'lines': {'-D debugopts',
#    '-D help.  Valid debug options include',
#    '-H     Do not follow symbolic links, except while processing the',
#    '-L     Follow symbolic links.  When find examines or prints',
#    '-Olevel',
#    '-P     Never follow symbolic links.  This is the default',
#    '-cnewer.',
#    '-execdir, -ok and -okdir',
#    '-files0-from to pass arbitrary starting points to find.',
#    '-noleaf.  If you later use the -P option, -noleaf will',
#    '-regex) are performed first.'}},
#  'xargs': {'lines': {'--delimiter=delim, -d delim',
#    '--help Print a summary of the options to xargs and exit.',
#    '--process-slot-var=name',
#    '--show-limits',
#    '--version',
#    '-0, --null',
#    '-E eof-str',
#    '-I replace-str',
#    '-L max-lines',
#    '-P max-procs, --max-procs=max-procs',
#    '-P option.',
#    '-a file, --arg-file=file',
#    '-e[eof-str], --eof[=eof-str]',
#    '-i[replace-str], --replace[=replace-str]',
#    '-l[max-lines], --max-lines[=max-lines]',
#    '-n max-args, --max-args=max-args',
#    '-o, --open-tty',
#    '-p, --interactive',
#    '-r, --no-run-if-empty',
#    '-s max-chars, --max-chars=max-chars',
#    '-s option) is exceeded, unless the -x option is given, in',
#    '-t, --verbose',
#    '-x, --exit'}},
#  'grep': {'lines': {'--binary-files=TYPE',
#    '--binary-files=without-match option.',
#    '--color[=WHEN], --colour[=WHEN]',
#    '--count option is also used, grep does not output a count',
#    '--exclude-dir=GLOB',
#    '--exclude-from=FILE',
#    '--exclude=GLOB',
#    '--group-separator=SEP',
#    '--help Output a usage message and exit.',
#    '--include=GLOB',
#    '--label=LABEL',
#    '--line-buffered',
#    '--no-group-separator',
#    '--no-ignore-case',
#    '--no-messages option.',
#    '--only-matching option, this has no effect and a warning',
#    '-A NUM, --after-context=NUM',
#    '-B NUM, --before-context=NUM',
#    '-C NUM, -NUM, --context=NUM',
#    '-D ACTION, --devices=ACTION',
#    '-E, --extended-regexp',
#    '-F, --fixed-strings',
#    '-G, --basic-regexp',
#    '-H, --with-filename',
#    '-I     Process a binary file as if it did not contain matching',
#    '-L, --files-without-match',
#    '-P, --perl-regexp',
#    '-R, --dereference-recursive',
#    '-T, --initial-tab',
#    '-U, --binary',
#    '-V, --version',
#    '-Z, --null',
#    '-a, --text',
#    '-b, --byte-offset',
#    '-c, --count',
#    '-d ACTION, --directories=ACTION',
#    '-d recurse option.',
#    '-e PATTERNS, --regexp=PATTERNS',
#    '-f FILE, --file=FILE',
#    '-h, --no-filename',
#    '-i, --ignore-case',
#    '-l, --files-with-matches',
#    '-m NUM, --max-count=NUM',
#    '-n, --line-number',
#    '-o, --only-matching',
#    '-q, --quiet, --silent',
#    '-r, --recursive',
#    '-s, --no-messages',
#    '-v, --invert-match',
#    '-w, --word-regexp',
#    '-x, --line-regexp',
#    '-y     Obsolete synonym for -i.',
#    '-z, --null-data',
#    '-z, and xargs -0 to process arbitrary file names, even'}},
#  'rm': {'lines': {'--help display this help and exit',
#    '--interactive=always option is given, rm prompts the user for',
#    '--interactive[=WHEN]',
#    '--no-preserve-root',
#    '--one-file-system',
#    '--preserve-root[=all]',
#    '--version',
#    '-I     prompt once before removing more than three files, or when',
#    '-d, --dir',
#    '-f, --force',
#    '-i     prompt before every removal',
#    '-r, -R, --recursive',
#    '-v, --verbose'}},
#  'echo': {'lines': {'--help display this help and exit',
#    '--version',
#    '-E     disable interpretation of backslash escapes (default)',
#    '-e     enable interpretation of backslash escapes',
#    '-n     do not output the trailing newline'}},
#  'ls': {'lines': {'--author',
#    '--block-size=SIZE',
#    '--color[=WHEN]',
#    '--dereference-command-line-symlink-to-dir',
#    '--file-type',
#    '--format=WORD',
#    '--full-time',
#    '--group-directories-first',
#    '--help display this help and exit',
#    '--hide=PATTERN',
#    '--hyperlink[=WHEN]',
#    '--indicator-style=WORD',
#    '--quoting-style=WORD',
#    '--show-control-chars',
#    '--si   likewise, but use powers of 1000 not 1024',
#    '--sort is specified.',
#    '--sort=WORD',
#    '--sort=none (-U) disables grouping',
#    '--sort=time, sort by WORD (newest first)',
#    '--time-style=TIME_STYLE',
#    '--time=WORD',
#    '--version',
#    "-1     list one file per line.  Avoid '\\n' with -q or -b",
#    '-A, --almost-all',
#    '-B, --ignore-backups',
#    '-C     list entries by columns',
#    '-D, --dired',
#    '-F, --classify',
#    '-G, --no-group',
#    '-H, --dereference-command-line',
#    '-I, --ignore=PATTERN',
#    '-L, --dereference',
#    '-N, --literal',
#    '-Q, --quote-name',
#    '-R, --recursive',
#    '-S     sort by file size, largest first',
#    '-T, --tabsize=COLS',
#    '-U     do not sort; list entries in directory order',
#    '-X     sort alphabetically by entry extension',
#    '-Z, --context',
#    '-a, --all',
#    '-b, --escape',
#    '-c     with -lt: sort by, and show, ctime (time of last',
#    '-d, --directory',
#    '-f     do not sort, enable -aU, disable -ls --color',
#    '-g     like -l, but do not list owner',
#    '-h, --human-readable',
#    '-i, --inode',
#    '-k, --kibibytes',
#    '-l     use a long listing format',
#    '-m     fill width with a comma separated list of entries',
#    '-n, --numeric-uid-gid',
#    '-o     like -l, but do not list group information',
#    '-p, --indicator-style=slash',
#    '-q, --hide-control-chars',
#    '-r, --reverse',
#    '-s and per directory totals',
#    '-s, --size',
#    '-t     sort by time, newest first; see --time',
#    '-u     with -lt: sort by, and show, access time; with -l: show',
#    '-v     natural sort of (version) numbers within text',
#    '-w, --width=COLS',
#    '-x     list entries by lines instead of by columns'}},
#  'sort': {'lines': {'--batch-size=NMERGE',
#    '--compress-program=PROG',
#    '--debug',
#    '--files0-from=F',
#    '--help display this help and exit',
#    '--parallel=N',
#    '--random-source=FILE',
#    '--sort=WORD',
#    '--version',
#    '-C, --check=quiet, --check=silent',
#    '-M, --month-sort',
#    '-R, --random-sort',
#    '-S, --buffer-size=SIZE',
#    '-T, --temporary-directory=DIR',
#    '-V, --version-sort',
#    '-b, --ignore-leading-blanks',
#    '-c, --check, --check=diagnose-first',
#    '-d',
#    '-d, --dictionary-order',
#    '-f, --ignore-case',
#    '-g, --general-numeric-sort',
#    '-h, --human-numeric-sort',
#    '-h, month -M, numeric -n, random -R, version -V',
#    '-i, --ignore-nonprinting',
#    '-k, --key=KEYDEF',
#    '-m, --merge',
#    '-n, --numeric-sort',
#    '-o, --output=FILE',
#    '-r, --reverse',
#    '-s, --stable',
#    '-t, --field-separator=SEP',
#    '-u, --unique',
#    '-z, --zero-terminated'}},
#  'chmod': {'lines': set()},
#  'wc': {'lines': {'--files0-from=F',
#    '--help display this help and exit',
#    '--version',
#    '-L, --max-line-length',
#    '-c, --bytes',
#    '-l, --lines',
#    '-m, --chars',
#    '-w, --words'}},
#  'cat': {'lines': {'--help display this help and exit',
#    '--version',
#    '-A, --show-all',
#    '-E, --show-ends',
#    '-T, --show-tabs',
#    '-b, --number-nonblank',
#    '-e     equivalent to -vE',
#    '-n, --number',
#    '-s, --squeeze-blank',
#    '-t     equivalent to -vT',
#    '-u     (ignored)',
#    '-v, --show-nonprinting'}},
#  'cut': {'lines': {'--complement',
#    '--help display this help and exit',
#    '--output-delimiter=STRING',
#    '--version',
#    "-M     from first to M'th (included) byte, character or field",
#    '-b, --bytes=LIST',
#    '-c, --characters=LIST',
#    '-d, --delimiter=DELIM',
#    '-f, --fields=LIST',
#    '-n     (ignored)',
#    '-s, --only-delimited',
#    '-z, --zero-terminated'}},
#  'head': {'lines': {'--help display this help and exit',
#    '--version',
#    '-c, --bytes=[-]NUM',
#    '-n, --lines=[-]NUM',
#    '-q, --quiet, --silent',
#    '-v, --verbose',
#    '-z, --zero-terminated'}},
#  'mv': {'lines': {'--backup[=CONTROL]',
#    '--help display this help and exit',
#    '--strip-trailing-slashes',
#    '--version',
#    '-S, --suffix=SUFFIX',
#    '-T, --no-target-directory',
#    '-Z, --context',
#    '-b     like --backup but does not accept an argument',
#    '-f, --force',
#    '-i, --interactive',
#    '-n, --no-clobber',
#    '-t, --target-directory=DIRECTORY',
#    '-u, --update',
#    '-v, --verbose'}},
#  'chown': {'lines': {'--dereference',
#    '--from=CURRENT_OWNER:CURRENT_GROUP',
#    '--help display this help and exit',
#    '--no-preserve-root',
#    '--preserve-root',
#    '--reference=RFILE',
#    '--version',
#    '-H     if a command line argument is a symbolic link to a',
#    '-L     traverse every symbolic link to a directory encountered',
#    '-P     do not traverse any symbolic links (default)',
#    '-R, --recursive',
#    '-c, --changes',
#    '-f, --silent, --quiet',
#    '-h, --no-dereference',
#    '-v, --verbose'}},
#  'cp': {'lines': {'--attributes-only',
#    '--backup[=CONTROL]',
#    '--context[=CTX]',
#    '--copy-contents',
#    '--help display this help and exit',
#    '--no-preserve=ATTR_LIST',
#    '--parents',
#    '--preserve[=ATTR_LIST]',
#    '--reflink[=WHEN]',
#    '--remove-destination',
#    '--sparse=WHEN',
#    '--strip-trailing-slashes',
#    '--version',
#    '-H     follow command-line symbolic links in SOURCE',
#    '-L, --dereference',
#    '-P, --no-dereference',
#    '-R, -r, --recursive',
#    '-S, --suffix=SUFFIX',
#    '-T, --no-target-directory',
#    '-Z     set SELinux security context of destination file to',
#    '-a, --archive',
#    '-b     like --backup but does not accept an argument',
#    '-d     same as --no-dereference --preserve=links',
#    '-f, --force',
#    '-i, --interactive',
#    '-l, --link',
#    '-n, --no-clobber',
#    '-p     same as --preserve=mode,ownership,timestamps',
#    '-s, --symbolic-link',
#    '-t, --target-directory=DIRECTORY',
#    '-u, --update',
#    '-v, --verbose',
#    '-x, --one-file-system'}},
#  'mkdir': {'lines': {'--context[=CTX]',
#    '--help display this help and exit',
#    '--version',
#    '-Z     set SELinux security context of each created directory to',
#    '-m, --mode=MODE',
#    '-p, --parents',
#    '-v, --verbose'}},
#  'tr': {'lines': {'--help display this help and exit',
#    '--version',
#    '-c, -C, --complement',
#    '-d, --delete',
#    '-s, --squeeze-repeats',
#    '-t, --truncate-set1'}},
#  'tail': {'lines': {'--follow=name in that case.  That causes tail to track the named',
#    '--help display this help and exit',
#    '--max-unchanged-stats=N',
#    '--pid=PID',
#    '--retry',
#    '--version',
#    '-F     same as --follow=name --retry',
#    '-c, --bytes=[+]NUM',
#    '-f, --follow[={name|descriptor}]',
#    '-n +NUM to output starting with line NUM',
#    '-n, --lines=[+]NUM',
#    '-q, --quiet, --silent',
#    '-s, --sleep-interval=N',
#    '-v, --verbose',
#    '-z, --zero-terminated'}},
#  'dirname': {'lines': {'--help display this help and exit',
#    '--version',
#    '-> "."',
#    '-> "/usr"',
#    '-> "dir1" followed by "dir2"',
#    '-z, --zero'}},
#  'tar': {'lines': {'--delete',
#    '--show-defaults',
#    '--test-label',
#    '--usage',
#    '--version',
#    '-?, --help',
#    '-A, --catenate, --concatenate',
#    "-c and -r options.  Notice, that newer files don't replace",
#    '-c, --create',
#    '-d, --diff, --compare',
#    '-r, --append',
#    '-t, --list',
#    '-u, --update',
#    '-x, --extract, --get'}},
#  'uniq': {'lines': {'--all-repeated[=METHOD]',
#    '--group[=METHOD]',
#    '--help display this help and exit',
#    '--version',
#    '-D     print all duplicate lines',
#    '-c, --count',
#    '-d, --repeated',
#    '-f, --skip-fields=N',
#    '-i, --ignore-case',
#    '-s, --skip-chars=N',
#    '-u, --unique',
#    '-w, --check-chars=N',
#    '-z, --zero-terminated'}},
#  'ln': {'lines': {'--backup[=CONTROL]',
#    '--help display this help and exit',
#    '--symbolic.  By default, each destination (name of new link)',
#    '--version',
#    '-L, --logical',
#    '-P, --physical',
#    '-P.',
#    '-S, --suffix=SUFFIX',
#    '-T, --no-target-directory',
#    '-b     like --backup but does not accept an argument',
#    '-d, -F, --directory',
#    '-f, --force',
#    '-i, --interactive',
#    '-n, --no-dereference',
#    '-r, --relative',
#    '-s, --symbolic',
#    '-t, --target-directory=DIRECTORY',
#    '-v, --verbose'}},
#  'split': {'lines': {'--additional-suffix=SUFFIX',
#    '--filter=COMMAND',
#    '--help display this help and exit',
#    '--hex-suffixes[=FROM]',
#    '--numeric-suffixes[=FROM]',
#    '--verbose',
#    '--version',
#    '-C, --line-bytes=SIZE',
#    '-a, --suffix-length=N',
#    '-b, --bytes=SIZE',
#    '-d     use numeric suffixes starting at 0, not alphabetic',
#    '-e, --elide-empty-files',
#    '-l, --lines=NUMBER',
#    '-n, --number=CHUNKS',
#    '-t, --separator=SEP',
#    '-u, --unbuffered',
#    '-x     use hex suffixes starting at 0, not alphabetic'}}}

# %%
# The number of flags in our data structure
sum(len(data[x]['lines']) for x in data)
# Out:
# 399

# %%
def get_inner_brackets(s):
    open_idx = s.index("[") + 1
    closed_idx = s.index("]")
    a = s[open_idx: closed_idx]
    a = a.replace("=", "")
    return a

def get_equal_arg(s):
    return remove_punctuation(s.split("=")[1])
    
def remove_punctuation(s):
    punctuation = set(_ for _ in ",.()")
    return "".join([x if x not in punctuation else "" for x in s])
    
def remove_brackets(s):
    brackets = {"[", "]"}
    return "".join([x if x not in brackets else "" for x in s])

def get_flag(line):
    punctuation = set(p for p in "[].,()=[]")
    for val in punctuation:
        line = line.replace(val, " ")
    flag = line.split(" ")[0]
    return flag

# %% [markdown]
# ## Cleaning Flags

# %%
for ut in data:
    for flag_line in data[ut]['lines']:
        flag_line = remove_punctuation(flag_line)
        flag, arg = get_flag(flag_line), None
        if "[" in flag_line and "]" in flag_line:
            arg = get_inner_brackets(flag_line)
        elif "=" in flag_line:
            arg = get_equal_arg(flag_line)
        data[ut][flag] = arg

# %%
for ut in data:
    if 'lines' in data[ut]:
        del data[ut]['lines']
        
data
# Out:
# {'find': {'-execdir': None,
#   '-D': None,
#   '-noleaf': None,
#   '-regex': None,
#   '-P': None,
#   '-files0-from': None,
#   '-L': None,
#   '-H': None,
#   '-Olevel': None,
#   '-cnewer': None},
#  'xargs': {'-l': 'max-lines',
#   '-L': None,
#   '-0': None,
#   '--delimiter': 'delim -d delim',
#   '-i': 'replace-str',
#   '--process-slot-var': 'name',
#   '-P': 'max-procs',
#   '-x': None,
#   '--show-limits': None,
#   '--version': None,
#   '-r': None,
#   '-s': None,
#   '-a': 'file',
#   '-p': None,
#   '-t': None,
#   '--help': None,
#   '-I': None,
#   '-e': 'eof-str',
#   '-n': 'max-args',
#   '-o': None,
#   '-E': None},
#  'grep': {'-o': None,
#   '-w': None,
#   '-z': None,
#   '-T': None,
#   '-h': None,
#   '-G': None,
#   '-f': 'FILE',
#   '-x': None,
#   '-d': None,
#   '-R': None,
#   '--binary-files': 'TYPE',
#   '-r': None,
#   '-c': None,
#   '--exclude': 'GLOB',
#   '-L': None,
#   '--line-buffered': None,
#   '-e': 'PATTERNS',
#   '--count': None,
#   '-F': None,
#   '-s': None,
#   '-n': None,
#   '-E': None,
#   '-i': None,
#   '--help': None,
#   '--no-messages': None,
#   '-y': None,
#   '--color': 'WHEN',
#   '--exclude-dir': 'GLOB',
#   '-U': None,
#   '-P': None,
#   '-A': 'NUM',
#   '-v': None,
#   '-l': None,
#   '-V': None,
#   '--include': 'GLOB',
#   '--label': 'LABEL',
#   '-B': 'NUM',
#   '-q': None,
#   '-Z': None,
#   '--exclude-from': 'FILE',
#   '-m': 'NUM',
#   '--only-matching': None,
#   '-b': None,
#   '--group-separator': 'SEP',
#   '-H': None,
#   '-a': None,
#   '-D': 'ACTION',
#   '-I': None,
#   '--no-group-separator': None,
#   '--no-ignore-case': None,
#   '-C': 'NUM'},
#  'rm': {'-d': None,
#   '--interactive': 'WHEN',
#   '-i': None,
#   '-f': None,
#   '-r': None,
#   '--one-file-system': None,
#   '--help': None,
#   '--no-preserve-root': None,
#   '--version': None,
#   '-v': None,
#   '-I': None,
#   '--preserve-root': 'all'},
#  'echo': {'--help': None,
#   '-E': None,
#   '-e': None,
#   '-n': None,
#   '--version': None},
#  'ls': {'-w': 'COLS',
#   '--sort': None,
#   '-T': 'COLS',
#   '-U': None,
#   '-a': None,
#   '-i': None,
#   '-v': None,
#   '--quoting-style': 'WORD',
#   '--group-directories-first': None,
#   '-g': None,
#   '-l': None,
#   '-G': None,
#   '-d': None,
#   '-u': None,
#   '-h': None,
#   '-k': None,
#   '-n': None,
#   '-S': None,
#   '-m': None,
#   '-N': None,
#   '-C': None,
#   '-B': None,
#   '-1': None,
#   '--indicator-style': 'WORD',
#   '-F': None,
#   '--file-type': None,
#   '--color': 'WHEN',
#   '--si': None,
#   '-X': None,
#   '--version': None,
#   '-c': None,
#   '-q': None,
#   '-s': None,
#   '--help': None,
#   '--format': 'WORD',
#   '-I': 'PATTERN',
#   '-A': None,
#   '--full-time': None,
#   '-H': None,
#   '-R': None,
#   '-t': None,
#   '-L': None,
#   '-b': None,
#   '--hyperlink': 'WHEN',
#   '--time-style': 'TIME_STYLE',
#   '-Z': None,
#   '-r': None,
#   '-D': None,
#   '--hide': 'PATTERN',
#   '-f': None,
#   '-o': None,
#   '--show-control-chars': None,
#   '-p': 'slash',
#   '-x': None,
#   '--block-size': 'SIZE',
#   '--dereference-command-line-symlink-to-dir': None,
#   '-Q': None,
#   '--author': None,
#   '--time': 'WORD'},
#  'sort': {'-d': None,
#   '-k': 'KEYDEF',
#   '--parallel': 'N',
#   '-i': None,
#   '-M': None,
#   '-c': 'diagnose-first',
#   '-s': None,
#   '-C': 'quiet --check',
#   '-b': None,
#   '-m': None,
#   '-f': None,
#   '--debug': None,
#   '-R': None,
#   '--sort': 'WORD',
#   '--random-source': 'FILE',
#   '--version': None,
#   '--batch-size': 'NMERGE',
#   '-u': None,
#   '-h': None,
#   '--help': None,
#   '-V': None,
#   '-S': 'SIZE',
#   '-t': 'SEP',
#   '-n': None,
#   '--compress-program': 'PROG',
#   '-r': None,
#   '--files0-from': 'F',
#   '-z': None,
#   '-g': None,
#   '-T': 'DIR',
#   '-o': 'FILE'},
#  'chmod': {},
#  'wc': {'-w': None,
#   '--help': None,
#   '-c': None,
#   '-l': None,
#   '--files0-from': 'F',
#   '-L': None,
#   '-m': None,
#   '--version': None},
#  'cat': {'-T': None,
#   '--help': None,
#   '-b': None,
#   '-n': None,
#   '-A': None,
#   '-u': None,
#   '-s': None,
#   '-v': None,
#   '-E': None,
#   '--version': None,
#   '-t': None,
#   '-e': None},
#  'cut': {'-c': 'LIST',
#   '--help': None,
#   '--output-delimiter': 'STRING',
#   '-M': None,
#   '-s': None,
#   '--complement': None,
#   '-z': None,
#   '-b': 'LIST',
#   '-f': 'LIST',
#   '-d': 'DELIM',
#   '--version': None,
#   '-n': None},
#  'head': {'-q': None,
#   '--help': None,
#   '-c': '-',
#   '-n': '-',
#   '-z': None,
#   '-v': None,
#   '--version': None},
#  'mv': {'-n': None,
#   '-S': 'SUFFIX',
#   '--backup': 'CONTROL',
#   '-i': None,
#   '-f': None,
#   '-t': 'DIRECTORY',
#   '--strip-trailing-slashes': None,
#   '-T': None,
#   '-Z': None,
#   '--help': None,
#   '-b': None,
#   '-v': None,
#   '--version': None,
#   '-u': None},
#  'chown': {'-f': None,
#   '--help': None,
#   '-h': None,
#   '--dereference': None,
#   '--preserve-root': None,
#   '--reference': 'RFILE',
#   '--from': 'CURRENT_OWNER:CURRENT_GROUP',
#   '-H': None,
#   '-L': None,
#   '-c': None,
#   '--no-preserve-root': None,
#   '-P': None,
#   '-v': None,
#   '-R': None,
#   '--version': None},
#  'cp': {'-n': None,
#   '-T': None,
#   '-t': 'DIRECTORY',
#   '--copy-contents': None,
#   '-s': None,
#   '-H': None,
#   '-x': None,
#   '-f': None,
#   '-a': None,
#   '-d': 'links',
#   '--no-preserve': 'ATTR_LIST',
#   '-v': None,
#   '--version': None,
#   '--reflink': 'WHEN',
#   '-S': 'SUFFIX',
#   '--help': None,
#   '--parents': None,
#   '--strip-trailing-slashes': None,
#   '--sparse': 'WHEN',
#   '-L': None,
#   '-R': None,
#   '-u': None,
#   '--backup': 'CONTROL',
#   '-i': None,
#   '--preserve': 'ATTR_LIST',
#   '-l': None,
#   '-Z': None,
#   '-b': None,
#   '-p': 'modeownershiptimestamps',
#   '--attributes-only': None,
#   '-P': None,
#   '--remove-destination': None,
#   '--context': 'CTX'},
#  'mkdir': {'--help': None,
#   '-p': None,
#   '-m': 'MODE',
#   '--version': None,
#   '-v': None,
#   '-Z': None,
#   '--context': 'CTX'},
#  'tr': {'--help': None,
#   '-d': None,
#   '-c': None,
#   '-t': None,
#   '-s': None,
#   '--version': None},
#  'tail': {'-q': None,
#   '--pid': 'PID',
#   '--help': None,
#   '-s': 'N',
#   '-F': 'name --retry',
#   '--follow': 'name in that case  That causes tail to track the named',
#   '-f': '{name|descriptor}',
#   '-n': None,
#   '-z': None,
#   '-v': None,
#   '-c': '+',
#   '--retry': None,
#   '--version': None,
#   '--max-unchanged-stats': 'N'},
#  'dirname': {'->': None, '--help': None, '-z': None, '--version': None},
#  'tar': {'--usage': None,
#   '-c': None,
#   '-t': None,
#   '-?': None,
#   '-d': None,
#   '--delete': None,
#   '-x': None,
#   '--test-label': None,
#   '-r': None,
#   '--version': None,
#   '-A': None,
#   '-u': None,
#   '--show-defaults': None},
#  'uniq': {'-u': None,
#   '-d': None,
#   '-D': None,
#   '--help': None,
#   '-s': 'N',
#   '-i': None,
#   '-z': None,
#   '--version': None,
#   '--group': 'METHOD',
#   '-c': None,
#   '-w': 'N',
#   '-f': 'N',
#   '--all-repeated': 'METHOD'},
#  'ln': {'-n': None,
#   '-S': 'SUFFIX',
#   '-s': None,
#   '--backup': 'CONTROL',
#   '-f': None,
#   '-i': None,
#   '-t': 'DIRECTORY',
#   '-T': None,
#   '--help': None,
#   '-P': None,
#   '-b': None,
#   '-L': None,
#   '-v': None,
#   '-d': None,
#   '--symbolic': None,
#   '-r': None,
#   '--version': None},
#  'split': {'-n': 'CHUNKS',
#   '--help': None,
#   '-e': None,
#   '-x': None,
#   '-t': 'SEP',
#   '--hex-suffixes': 'FROM',
#   '-l': 'NUMBER',
#   '--numeric-suffixes': 'FROM',
#   '-u': None,
#   '-C': 'SIZE',
#   '-a': 'N',
#   '-b': 'SIZE',
#   '--additional-suffix': 'SUFFIX',
#   '--version': None,
#   '-d': None,
#   '--filter': 'COMMAND',
#   '--verbose': None}}

# %%
# the number of flags that have arguments
count = 0
for ut in data:
    for flag in data[ut]:
        if data[ut][flag]: count +=1
count
# Out:
# 101

# %% [markdown]
# ## Manually Inserting Argument Types
#
# Now that we have the utilities mapped to the appropriate flags, we will need to manually insert the data types corresponding to each flag.

# %%
argument_types = [
    'Regex',
    'File',
    'Directory',
    'Path',
    'Number',
    '+Number',
    '-Number',
    'Quantity',
    '+Quantity',
    '-Quantity',
    'Size',
    '+Size',
    '-Size',
    'Timespan',
    '+Timespan',
    '-Timespan',
    'DateTime',
    '+DateTime',
    '-DateTime',
    'Permission',
    '+Permission',
    '-Permission'
]

# %% [markdown]
# Getting a sense of the argument types the parser has discovered

# %%
def flag_types(data):
    l = []
    for ut in data:
        for flag in data[ut]:
            if data[ut][flag]:
                l.append(data[ut][flag])
    return l
flag_types(data)[:20]
# Out:
# ['max-lines',
#  'delim -d delim',
#  'replace-str',
#  'name',
#  'max-procs',
#  'file',
#  'eof-str',
#  'max-args',
#  'FILE',
#  'TYPE',
#  'GLOB',
#  'PATTERNS',
#  'WHEN',
#  'GLOB',
#  'NUM',
#  'GLOB',
#  'LABEL',
#  'NUM',
#  'FILE',
#  'NUM']

# %%
type_mapping = {
    'Regex': {'str', 'sep', 'pattern', 'word', 'delim', 'suffix', 'from', 'glob'},
    'File': {'file'},
    'Directory': {'dir'},
    'Path': {'path'},
    'Number': {'num', 'n', 'cols', 'pid', 'max'},
    'Quantity': {},
    'Size':{'size'},
    'Timespan':{},
    'DateTime': {'timestamp', 'time'},
    'Permission':{},
}
# _NUMBER, _PATH,
# _FILE, _DIRECTORY, _DATETIME, _PERMISSION,
# _TIMESPAN, _SIZE
# ,  with  the  default  option  of
# _REGEX

def non_conforming_flags(data, types):
    l = []
    for ut in data:
        for flag in data[ut]:
            if data[ut][flag] and data[ut][flag] not in types:
                l.append(":".join([ut, flag, data[ut][flag]]))
    return l

# %% [markdown]
# ## Converting Argument Types in Structure to Known Types
#
# Using the type mappings, we can convert the argument types we parsed into the set number of types we know.

# %%
def convert_flag_types(data, mapping):
    for ut in data:
        for flag in data[ut]:
            if data[ut][flag]:
                for t in mapping:
                    for substr in mapping[t]:
                        if substr in data[ut][flag].lower():
                            data[ut][flag] = t
                        
convert_flag_types(data, type_mapping)
non_conforming_flags(data, argument_types)
# Out:
# ['grep:--binary-files:TYPE',
#  'grep:--label:LABEL',
#  'rm:--preserve-root:all',
#  'ls:-p:slash',
#  'sort:-k:KEYDEF',
#  'sort:-C:quiet --check',
#  'sort:--compress-program:PROG',
#  'sort:--files0-from:F',
#  'wc:--files0-from:F',
#  'cut:-c:LIST',
#  'cut:-b:LIST',
#  'cut:-f:LIST',
#  'head:-c:-',
#  'head:-n:-',
#  'cp:--no-preserve:ATTR_LIST',
#  'cp:--preserve:ATTR_LIST',
#  'cp:--context:CTX',
#  'mkdir:-m:MODE',
#  'mkdir:--context:CTX',
#  'tail:-c:+',
#  'uniq:--group:METHOD',
#  'uniq:--all-repeated:METHOD']

# %%
descs
# Out:
# {'find': 'find [-H] [-L] [-P] [-D debugopts] [-Olevel] [starting-point...]',
#  'xargs': 'xargs [options] [command [initial-arguments]]',
#  'grep': 'grep [OPTION...] PATTERNS [FILE...]',
#  'rm': 'rm [OPTION]... [FILE]...',
#  'echo': 'echo [SHORT-OPTION]... [STRING]...',
#  'ls': 'ls [OPTION]... [FILE]...',
#  'sort': 'sort [OPTION]... [FILE]...',
#  'chmod': 'chmod [OPTION]... MODE[,MODE]... FILE...',
#  'wc': 'wc [OPTION]... [FILE]...',
#  'cat': 'cat [OPTION]... [FILE]...',
#  'cut': 'cut OPTION... [FILE]...',
#  'head': 'head [OPTION]... [FILE]...',
#  'mv': 'mv [OPTION]... [-T] SOURCE DEST',
#  'chown': 'chown [OPTION]... [OWNER][:[GROUP]] FILE...',
#  'cp': 'cp [OPTION]... [-T] SOURCE DEST',
#  'mkdir': 'mkdir [OPTION]... DIRECTORY...',
#  'tr': 'tr [OPTION]... SET1 [SET2]',
#  'tail': 'tail [OPTION]... [FILE]...',
#  'dirname': 'dirname [OPTION] NAME...',
#  'tar': 'Traditional usage',
#  'uniq': 'uniq [OPTION]... [INPUT [OUTPUT]]',
#  'ln': 'ln [OPTION]... [-T] TARGET LINK_NAME',
#  'split': 'split [OPTION]... [FILE [PREFIX]]'}

# %%
l = descs['find']

# %%
l.strip()
# Out:
# 'find [-H] [-L] [-P] [-D debugopts] [-Olevel] [starting-point...]'

# %%
def valid_flag(flag):
    return flag in argument_types

def generate_options(utility):
    flag_map = data[utility]
    
    ret = []
    keys = list(flag_map.keys())
    for i in range(len(keys)):
        for j in range(i + 1, len(keys)):
            for k in range(j + 1, len(keys)):
                if all(valid_flag(flag_map[x]) for x in [keys[i], keys[j], keys[k]]):
                    f1 = " ".join([keys[i], flag_map[keys[i]]]) if flag_map[keys[i]] else keys[i]
                    f2 = " ".join([keys[j], flag_map[keys[j]]]) if flag_map[keys[j]] else keys[j]
                    f3 = " ".join([keys[k], flag_map[keys[k]]]) if flag_map[keys[k]] else keys[k]
                    ret.append(f1)
                    ret.append(" ".join([f1, f2]))
                    ret.append(" ".join([f1, f2, f3]))
    return ret

def generate_syntax(utility):
    syntax = descs[utility]
    
    if 'option' not in syntax.lower():
        return f"Invalid syntax for utility {utility}, {syntax}"
        
    s = syntax.replace('...', '')
    s = remove_punctuation(s)
    s = remove_brackets(s)
    s = s.lower()
    
    sp = s.split(" ")
    cleaned = []
    for val in sp:
        if val == utility:
            cleaned.append(val)
        elif "option" in val:
            cleaned.append("option")
        elif val and val[0] != "-":
            s = ""
            for data_type in type_mapping:
                for match in type_mapping[data_type]:
                    if match in val:
                        s = data_type
            cleaned.append(s)
    
    return " ".join(cleaned)

def generate_commands(utility):
    ops = generate_options(utility)
    ret = []
    syntax = generate_syntax(utility)
    for option_combo in ops:
        ret.append(syntax.replace("option", option_combo))
    return ret

total = []
for ut in utilities:
    print(f"{ut}: {len(generate_commands(ut))}")
    for r in generate_commands(ut):
        total.append(r)
len(total)
# Out:
# find: 0
# xargs: 168
# grep: 858
# rm: 0
# echo: 0
# ls: 660
# sort: 252
# chmod: 0
# wc: 0
# cat: 0
# cut: 0
# head: 0
# mv: 3
# chown: 0
# cp: 105
# mkdir: 0
# tr: 0
# tail: 60
# dirname: 0
# tar: 0
# uniq: 3
# ln: 3
# split: 360
# 2472

# %%
for r in generate_commands('grep'):
    print(r)
# Out:
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex -e Regex Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex --color Number Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex --exclude-dir Regex Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex -A Number Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex --include Regex Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex -B Number Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex --exclude-from File Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex -m Number Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex --group-separator Regex Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex -D Number Number File
# grep -f File Number File
# grep -f File --exclude Regex Number File
# grep -f File --exclude Regex -C Number Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex --color Number Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex --exclude-dir Regex Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex -A Number Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex --include Regex Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex -B Number Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex --exclude-from File Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex -m Number Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex --group-separator Regex Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex -D Number Number File
# grep -f File Number File
# grep -f File -e Regex Number File
# grep -f File -e Regex -C Number Number File
# grep -f File Number File
# grep -f File --color Number Number File
# grep -f File --color Number --exclude-dir Regex Number File
# grep -f File Number File
# grep -f File --color Number Number File
# grep -f File --color Number -A Number Number File
# grep -f File Number File
# grep -f File --color Number Number File
# grep -f File --color Number --include Regex Number File
# grep -f File Number File
# grep -f File --color Number Number File
# grep -f File --color Number -B Number Number File
# grep -f File Number File
# grep -f File --color Number Number File
# grep -f File --color Number --exclude-from File Number File
# grep -f File Number File
# grep -f File --color Number Number File
# grep -f File --color Number -m Number Number File
# grep -f File Number File
# grep -f File --color Number Number File
# grep -f File --color Number --group-separator Regex Number File
# grep -f File Number File
# grep -f File --color Number Number File
# grep -f File --color Number -D Number Number File
# grep -f File Number File
# grep -f File --color Number Number File
# grep -f File --color Number -C Number Number File
# grep -f File Number File
# grep -f File --exclude-dir Regex Number File
# grep -f File --exclude-dir Regex -A Number Number File
# grep -f File Number File
# grep -f File --exclude-dir Regex Number File
# grep -f File --exclude-dir Regex --include Regex Number File
# grep -f File Number File
# grep -f File --exclude-dir Regex Number File
# grep -f File --exclude-dir Regex -B Number Number File
# grep -f File Number File
# grep -f File --exclude-dir Regex Number File
# grep -f File --exclude-dir Regex --exclude-from File Number File
# grep -f File Number File
# grep -f File --exclude-dir Regex Number File
# grep -f File --exclude-dir Regex -m Number Number File
# grep -f File Number File
# grep -f File --exclude-dir Regex Number File
# grep -f File --exclude-dir Regex --group-separator Regex Number File
# grep -f File Number File
# grep -f File --exclude-dir Regex Number File
# grep -f File --exclude-dir Regex -D Number Number File
# grep -f File Number File
# grep -f File --exclude-dir Regex Number File
# grep -f File --exclude-dir Regex -C Number Number File
# grep -f File Number File
# grep -f File -A Number Number File
# grep -f File -A Number --include Regex Number File
# grep -f File Number File
# grep -f File -A Number Number File
# grep -f File -A Number -B Number Number File
# grep -f File Number File
# grep -f File -A Number Number File
# grep -f File -A Number --exclude-from File Number File
# grep -f File Number File
# grep -f File -A Number Number File
# grep -f File -A Number -m Number Number File
# grep -f File Number File
# grep -f File -A Number Number File
# grep -f File -A Number --group-separator Regex Number File
# grep -f File Number File
# grep -f File -A Number Number File
# grep -f File -A Number -D Number Number File
# grep -f File Number File
# grep -f File -A Number Number File
# grep -f File -A Number -C Number Number File
# grep -f File Number File
# grep -f File --include Regex Number File
# grep -f File --include Regex -B Number Number File
# grep -f File Number File
# grep -f File --include Regex Number File
# grep -f File --include Regex --exclude-from File Number File
# grep -f File Number File
# grep -f File --include Regex Number File
# grep -f File --include Regex -m Number Number File
# grep -f File Number File
# grep -f File --include Regex Number File
# grep -f File --include Regex --group-separator Regex Number File
# grep -f File Number File
# grep -f File --include Regex Number File
# grep -f File --include Regex -D Number Number File
# grep -f File Number File
# grep -f File --include Regex Number File
# grep -f File --include Regex -C Number Number File
# grep -f File Number File
# grep -f File -B Number Number File
# grep -f File -B Number --exclude-from File Number File
# grep -f File Number File
# grep -f File -B Number Number File
# grep -f File -B Number -m Number Number File
# grep -f File Number File
# grep -f File -B Number Number File
# grep -f File -B Number --group-separator Regex Number File
# grep -f File Number File
# grep -f File -B Number Number File
# grep -f File -B Number -D Number Number File
# grep -f File Number File
# grep -f File -B Number Number File
# grep -f File -B Number -C Number Number File
# grep -f File Number File
# grep -f File --exclude-from File Number File
# grep -f File --exclude-from File -m Number Number File
# grep -f File Number File
# grep -f File --exclude-from File Number File
# grep -f File --exclude-from File --group-separator Regex Number File
# grep -f File Number File
# grep -f File --exclude-from File Number File
# grep -f File --exclude-from File -D Number Number File
# grep -f File Number File
# grep -f File --exclude-from File Number File
# grep -f File --exclude-from File -C Number Number File
# grep -f File Number File
# grep -f File -m Number Number File
# grep -f File -m Number --group-separator Regex Number File
# grep -f File Number File
# grep -f File -m Number Number File
# grep -f File -m Number -D Number Number File
# grep -f File Number File
# grep -f File -m Number Number File
# grep -f File -m Number -C Number Number File
# grep -f File Number File
# grep -f File --group-separator Regex Number File
# grep -f File --group-separator Regex -D Number Number File
# grep -f File Number File
# grep -f File --group-separator Regex Number File
# grep -f File --group-separator Regex -C Number Number File
# grep -f File Number File
# grep -f File -D Number Number File
# grep -f File -D Number -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex --color Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex --exclude-dir Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex -A Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex --include Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex -B Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex --exclude-from File Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex -m Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex --group-separator Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex -D Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -e Regex Number File
# grep --exclude Regex -e Regex -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --color Number Number File
# grep --exclude Regex --color Number --exclude-dir Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex --color Number Number File
# grep --exclude Regex --color Number -A Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --color Number Number File
# grep --exclude Regex --color Number --include Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex --color Number Number File
# grep --exclude Regex --color Number -B Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --color Number Number File
# grep --exclude Regex --color Number --exclude-from File Number File
# grep --exclude Regex Number File
# grep --exclude Regex --color Number Number File
# grep --exclude Regex --color Number -m Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --color Number Number File
# grep --exclude Regex --color Number --group-separator Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex --color Number Number File
# grep --exclude Regex --color Number -D Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --color Number Number File
# grep --exclude Regex --color Number -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-dir Regex Number File
# grep --exclude Regex --exclude-dir Regex -A Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-dir Regex Number File
# grep --exclude Regex --exclude-dir Regex --include Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-dir Regex Number File
# grep --exclude Regex --exclude-dir Regex -B Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-dir Regex Number File
# grep --exclude Regex --exclude-dir Regex --exclude-from File Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-dir Regex Number File
# grep --exclude Regex --exclude-dir Regex -m Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-dir Regex Number File
# grep --exclude Regex --exclude-dir Regex --group-separator Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-dir Regex Number File
# grep --exclude Regex --exclude-dir Regex -D Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-dir Regex Number File
# grep --exclude Regex --exclude-dir Regex -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -A Number Number File
# grep --exclude Regex -A Number --include Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex -A Number Number File
# grep --exclude Regex -A Number -B Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -A Number Number File
# grep --exclude Regex -A Number --exclude-from File Number File
# grep --exclude Regex Number File
# grep --exclude Regex -A Number Number File
# grep --exclude Regex -A Number -m Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -A Number Number File
# grep --exclude Regex -A Number --group-separator Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex -A Number Number File
# grep --exclude Regex -A Number -D Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -A Number Number File
# grep --exclude Regex -A Number -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --include Regex Number File
# grep --exclude Regex --include Regex -B Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --include Regex Number File
# grep --exclude Regex --include Regex --exclude-from File Number File
# grep --exclude Regex Number File
# grep --exclude Regex --include Regex Number File
# grep --exclude Regex --include Regex -m Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --include Regex Number File
# grep --exclude Regex --include Regex --group-separator Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex --include Regex Number File
# grep --exclude Regex --include Regex -D Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --include Regex Number File
# grep --exclude Regex --include Regex -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -B Number Number File
# grep --exclude Regex -B Number --exclude-from File Number File
# grep --exclude Regex Number File
# grep --exclude Regex -B Number Number File
# grep --exclude Regex -B Number -m Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -B Number Number File
# grep --exclude Regex -B Number --group-separator Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex -B Number Number File
# grep --exclude Regex -B Number -D Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -B Number Number File
# grep --exclude Regex -B Number -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-from File Number File
# grep --exclude Regex --exclude-from File -m Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-from File Number File
# grep --exclude Regex --exclude-from File --group-separator Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-from File Number File
# grep --exclude Regex --exclude-from File -D Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --exclude-from File Number File
# grep --exclude Regex --exclude-from File -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -m Number Number File
# grep --exclude Regex -m Number --group-separator Regex Number File
# grep --exclude Regex Number File
# grep --exclude Regex -m Number Number File
# grep --exclude Regex -m Number -D Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -m Number Number File
# grep --exclude Regex -m Number -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --group-separator Regex Number File
# grep --exclude Regex --group-separator Regex -D Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex --group-separator Regex Number File
# grep --exclude Regex --group-separator Regex -C Number Number File
# grep --exclude Regex Number File
# grep --exclude Regex -D Number Number File
# grep --exclude Regex -D Number -C Number Number File
# grep -e Regex Number File
# grep -e Regex --color Number Number File
# grep -e Regex --color Number --exclude-dir Regex Number File
# grep -e Regex Number File
# grep -e Regex --color Number Number File
# grep -e Regex --color Number -A Number Number File
# grep -e Regex Number File
# grep -e Regex --color Number Number File
# grep -e Regex --color Number --include Regex Number File
# grep -e Regex Number File
# grep -e Regex --color Number Number File
# grep -e Regex --color Number -B Number Number File
# grep -e Regex Number File
# grep -e Regex --color Number Number File
# grep -e Regex --color Number --exclude-from File Number File
# grep -e Regex Number File
# grep -e Regex --color Number Number File
# grep -e Regex --color Number -m Number Number File
# grep -e Regex Number File
# grep -e Regex --color Number Number File
# grep -e Regex --color Number --group-separator Regex Number File
# grep -e Regex Number File
# grep -e Regex --color Number Number File
# grep -e Regex --color Number -D Number Number File
# grep -e Regex Number File
# grep -e Regex --color Number Number File
# grep -e Regex --color Number -C Number Number File
# grep -e Regex Number File
# grep -e Regex --exclude-dir Regex Number File
# grep -e Regex --exclude-dir Regex -A Number Number File
# grep -e Regex Number File
# grep -e Regex --exclude-dir Regex Number File
# grep -e Regex --exclude-dir Regex --include Regex Number File
# grep -e Regex Number File
# grep -e Regex --exclude-dir Regex Number File
# grep -e Regex --exclude-dir Regex -B Number Number File
# grep -e Regex Number File
# grep -e Regex --exclude-dir Regex Number File
# grep -e Regex --exclude-dir Regex --exclude-from File Number File
# grep -e Regex Number File
# grep -e Regex --exclude-dir Regex Number File
# grep -e Regex --exclude-dir Regex -m Number Number File
# grep -e Regex Number File
# grep -e Regex --exclude-dir Regex Number File
# grep -e Regex --exclude-dir Regex --group-separator Regex Number File
# grep -e Regex Number File
# grep -e Regex --exclude-dir Regex Number File
# grep -e Regex --exclude-dir Regex -D Number Number File
# grep -e Regex Number File
# grep -e Regex --exclude-dir Regex Number File
# grep -e Regex --exclude-dir Regex -C Number Number File
# grep -e Regex Number File
# grep -e Regex -A Number Number File
# grep -e Regex -A Number --include Regex Number File
# grep -e Regex Number File
# grep -e Regex -A Number Number File
# grep -e Regex -A Number -B Number Number File
# grep -e Regex Number File
# grep -e Regex -A Number Number File
# grep -e Regex -A Number --exclude-from File Number File
# grep -e Regex Number File
# grep -e Regex -A Number Number File
# grep -e Regex -A Number -m Number Number File
# grep -e Regex Number File
# grep -e Regex -A Number Number File
# grep -e Regex -A Number --group-separator Regex Number File
# grep -e Regex Number File
# grep -e Regex -A Number Number File
# grep -e Regex -A Number -D Number Number File
# grep -e Regex Number File
# grep -e Regex -A Number Number File
# grep -e Regex -A Number -C Number Number File
# grep -e Regex Number File
# grep -e Regex --include Regex Number File
# grep -e Regex --include Regex -B Number Number File
# grep -e Regex Number File
# grep -e Regex --include Regex Number File
# grep -e Regex --include Regex --exclude-from File Number File
# grep -e Regex Number File
# grep -e Regex --include Regex Number File
# grep -e Regex --include Regex -m Number Number File
# grep -e Regex Number File
# grep -e Regex --include Regex Number File
# grep -e Regex --include Regex --group-separator Regex Number File
# grep -e Regex Number File
# grep -e Regex --include Regex Number File
# grep -e Regex --include Regex -D Number Number File
# grep -e Regex Number File
# grep -e Regex --include Regex Number File
# grep -e Regex --include Regex -C Number Number File
# grep -e Regex Number File
# grep -e Regex -B Number Number File
# grep -e Regex -B Number --exclude-from File Number File
# grep -e Regex Number File
# grep -e Regex -B Number Number File
# grep -e Regex -B Number -m Number Number File
# grep -e Regex Number File
# grep -e Regex -B Number Number File
# grep -e Regex -B Number --group-separator Regex Number File
# grep -e Regex Number File
# grep -e Regex -B Number Number File
# grep -e Regex -B Number -D Number Number File
# grep -e Regex Number File
# grep -e Regex -B Number Number File
# grep -e Regex -B Number -C Number Number File
# grep -e Regex Number File
# grep -e Regex --exclude-from File Number File
# grep -e Regex --exclude-from File -m Number Number File
# grep -e Regex Number File
# grep -e Regex --exclude-from File Number File
# grep -e Regex --exclude-from File --group-separator Regex Number File
# grep -e Regex Number File
# grep -e Regex --exclude-from File Number File
# grep -e Regex --exclude-from File -D Number Number File
# grep -e Regex Number File
# grep -e Regex --exclude-from File Number File
# grep -e Regex --exclude-from File -C Number Number File
# grep -e Regex Number File
# grep -e Regex -m Number Number File
# grep -e Regex -m Number --group-separator Regex Number File
# grep -e Regex Number File
# grep -e Regex -m Number Number File
# grep -e Regex -m Number -D Number Number File
# grep -e Regex Number File
# grep -e Regex -m Number Number File
# grep -e Regex -m Number -C Number Number File
# grep -e Regex Number File
# grep -e Regex --group-separator Regex Number File
# grep -e Regex --group-separator Regex -D Number Number File
# grep -e Regex Number File
# grep -e Regex --group-separator Regex Number File
# grep -e Regex --group-separator Regex -C Number Number File
# grep -e Regex Number File
# grep -e Regex -D Number Number File
# grep -e Regex -D Number -C Number Number File
# grep --color Number Number File
# grep --color Number --exclude-dir Regex Number File
# grep --color Number --exclude-dir Regex -A Number Number File
# grep --color Number Number File
# grep --color Number --exclude-dir Regex Number File
# grep --color Number --exclude-dir Regex --include Regex Number File
# grep --color Number Number File
# grep --color Number --exclude-dir Regex Number File
# grep --color Number --exclude-dir Regex -B Number Number File
# grep --color Number Number File
# grep --color Number --exclude-dir Regex Number File
# grep --color Number --exclude-dir Regex --exclude-from File Number File
# grep --color Number Number File
# grep --color Number --exclude-dir Regex Number File
# grep --color Number --exclude-dir Regex -m Number Number File
# grep --color Number Number File
# grep --color Number --exclude-dir Regex Number File
# grep --color Number --exclude-dir Regex --group-separator Regex Number File
# grep --color Number Number File
# grep --color Number --exclude-dir Regex Number File
# grep --color Number --exclude-dir Regex -D Number Number File
# grep --color Number Number File
# grep --color Number --exclude-dir Regex Number File
# grep --color Number --exclude-dir Regex -C Number Number File
# grep --color Number Number File
# grep --color Number -A Number Number File
# grep --color Number -A Number --include Regex Number File
# grep --color Number Number File
# grep --color Number -A Number Number File
# grep --color Number -A Number -B Number Number File
# grep --color Number Number File
# grep --color Number -A Number Number File
# grep --color Number -A Number --exclude-from File Number File
# grep --color Number Number File
# grep --color Number -A Number Number File
# grep --color Number -A Number -m Number Number File
# grep --color Number Number File
# grep --color Number -A Number Number File
# grep --color Number -A Number --group-separator Regex Number File
# grep --color Number Number File
# grep --color Number -A Number Number File
# grep --color Number -A Number -D Number Number File
# grep --color Number Number File
# grep --color Number -A Number Number File
# grep --color Number -A Number -C Number Number File
# grep --color Number Number File
# grep --color Number --include Regex Number File
# grep --color Number --include Regex -B Number Number File
# grep --color Number Number File
# grep --color Number --include Regex Number File
# grep --color Number --include Regex --exclude-from File Number File
# grep --color Number Number File
# grep --color Number --include Regex Number File
# grep --color Number --include Regex -m Number Number File
# grep --color Number Number File
# grep --color Number --include Regex Number File
# grep --color Number --include Regex --group-separator Regex Number File
# grep --color Number Number File
# grep --color Number --include Regex Number File
# grep --color Number --include Regex -D Number Number File
# grep --color Number Number File
# grep --color Number --include Regex Number File
# grep --color Number --include Regex -C Number Number File
# grep --color Number Number File
# grep --color Number -B Number Number File
# grep --color Number -B Number --exclude-from File Number File
# grep --color Number Number File
# grep --color Number -B Number Number File
# grep --color Number -B Number -m Number Number File
# grep --color Number Number File
# grep --color Number -B Number Number File
# grep --color Number -B Number --group-separator Regex Number File
# grep --color Number Number File
# grep --color Number -B Number Number File
# grep --color Number -B Number -D Number Number File
# grep --color Number Number File
# grep --color Number -B Number Number File
# grep --color Number -B Number -C Number Number File
# grep --color Number Number File
# grep --color Number --exclude-from File Number File
# grep --color Number --exclude-from File -m Number Number File
# grep --color Number Number File
# grep --color Number --exclude-from File Number File
# grep --color Number --exclude-from File --group-separator Regex Number File
# grep --color Number Number File
# grep --color Number --exclude-from File Number File
# grep --color Number --exclude-from File -D Number Number File
# grep --color Number Number File
# grep --color Number --exclude-from File Number File
# grep --color Number --exclude-from File -C Number Number File
# grep --color Number Number File
# grep --color Number -m Number Number File
# grep --color Number -m Number --group-separator Regex Number File
# grep --color Number Number File
# grep --color Number -m Number Number File
# grep --color Number -m Number -D Number Number File
# grep --color Number Number File
# grep --color Number -m Number Number File
# grep --color Number -m Number -C Number Number File
# grep --color Number Number File
# grep --color Number --group-separator Regex Number File
# grep --color Number --group-separator Regex -D Number Number File
# grep --color Number Number File
# grep --color Number --group-separator Regex Number File
# grep --color Number --group-separator Regex -C Number Number File
# grep --color Number Number File
# grep --color Number -D Number Number File
# grep --color Number -D Number -C Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -A Number Number File
# grep --exclude-dir Regex -A Number --include Regex Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -A Number Number File
# grep --exclude-dir Regex -A Number -B Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -A Number Number File
# grep --exclude-dir Regex -A Number --exclude-from File Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -A Number Number File
# grep --exclude-dir Regex -A Number -m Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -A Number Number File
# grep --exclude-dir Regex -A Number --group-separator Regex Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -A Number Number File
# grep --exclude-dir Regex -A Number -D Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -A Number Number File
# grep --exclude-dir Regex -A Number -C Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --include Regex Number File
# grep --exclude-dir Regex --include Regex -B Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --include Regex Number File
# grep --exclude-dir Regex --include Regex --exclude-from File Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --include Regex Number File
# grep --exclude-dir Regex --include Regex -m Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --include Regex Number File
# grep --exclude-dir Regex --include Regex --group-separator Regex Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --include Regex Number File
# grep --exclude-dir Regex --include Regex -D Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --include Regex Number File
# grep --exclude-dir Regex --include Regex -C Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -B Number Number File
# grep --exclude-dir Regex -B Number --exclude-from File Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -B Number Number File
# grep --exclude-dir Regex -B Number -m Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -B Number Number File
# grep --exclude-dir Regex -B Number --group-separator Regex Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -B Number Number File
# grep --exclude-dir Regex -B Number -D Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -B Number Number File
# grep --exclude-dir Regex -B Number -C Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --exclude-from File Number File
# grep --exclude-dir Regex --exclude-from File -m Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --exclude-from File Number File
# grep --exclude-dir Regex --exclude-from File --group-separator Regex Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --exclude-from File Number File
# grep --exclude-dir Regex --exclude-from File -D Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --exclude-from File Number File
# grep --exclude-dir Regex --exclude-from File -C Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -m Number Number File
# grep --exclude-dir Regex -m Number --group-separator Regex Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -m Number Number File
# grep --exclude-dir Regex -m Number -D Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -m Number Number File
# grep --exclude-dir Regex -m Number -C Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --group-separator Regex Number File
# grep --exclude-dir Regex --group-separator Regex -D Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex --group-separator Regex Number File
# grep --exclude-dir Regex --group-separator Regex -C Number Number File
# grep --exclude-dir Regex Number File
# grep --exclude-dir Regex -D Number Number File
# grep --exclude-dir Regex -D Number -C Number Number File
# grep -A Number Number File
# grep -A Number --include Regex Number File
# grep -A Number --include Regex -B Number Number File
# grep -A Number Number File
# grep -A Number --include Regex Number File
# grep -A Number --include Regex --exclude-from File Number File
# grep -A Number Number File
# grep -A Number --include Regex Number File
# grep -A Number --include Regex -m Number Number File
# grep -A Number Number File
# grep -A Number --include Regex Number File
# grep -A Number --include Regex --group-separator Regex Number File
# grep -A Number Number File
# grep -A Number --include Regex Number File
# grep -A Number --include Regex -D Number Number File
# grep -A Number Number File
# grep -A Number --include Regex Number File
# grep -A Number --include Regex -C Number Number File
# grep -A Number Number File
# grep -A Number -B Number Number File
# grep -A Number -B Number --exclude-from File Number File
# grep -A Number Number File
# grep -A Number -B Number Number File
# grep -A Number -B Number -m Number Number File
# grep -A Number Number File
# grep -A Number -B Number Number File
# grep -A Number -B Number --group-separator Regex Number File
# grep -A Number Number File
# grep -A Number -B Number Number File
# grep -A Number -B Number -D Number Number File
# grep -A Number Number File
# grep -A Number -B Number Number File
# grep -A Number -B Number -C Number Number File
# grep -A Number Number File
# grep -A Number --exclude-from File Number File
# grep -A Number --exclude-from File -m Number Number File
# grep -A Number Number File
# grep -A Number --exclude-from File Number File
# grep -A Number --exclude-from File --group-separator Regex Number File
# grep -A Number Number File
# grep -A Number --exclude-from File Number File
# grep -A Number --exclude-from File -D Number Number File
# grep -A Number Number File
# grep -A Number --exclude-from File Number File
# grep -A Number --exclude-from File -C Number Number File
# grep -A Number Number File
# grep -A Number -m Number Number File
# grep -A Number -m Number --group-separator Regex Number File
# grep -A Number Number File
# grep -A Number -m Number Number File
# grep -A Number -m Number -D Number Number File
# grep -A Number Number File
# grep -A Number -m Number Number File
# grep -A Number -m Number -C Number Number File
# grep -A Number Number File
# grep -A Number --group-separator Regex Number File
# grep -A Number --group-separator Regex -D Number Number File
# grep -A Number Number File
# grep -A Number --group-separator Regex Number File
# grep -A Number --group-separator Regex -C Number Number File
# grep -A Number Number File
# grep -A Number -D Number Number File
# grep -A Number -D Number -C Number Number File
# grep --include Regex Number File
# grep --include Regex -B Number Number File
# grep --include Regex -B Number --exclude-from File Number File
# grep --include Regex Number File
# grep --include Regex -B Number Number File
# grep --include Regex -B Number -m Number Number File
# grep --include Regex Number File
# grep --include Regex -B Number Number File
# grep --include Regex -B Number --group-separator Regex Number File
# grep --include Regex Number File
# grep --include Regex -B Number Number File
# grep --include Regex -B Number -D Number Number File
# grep --include Regex Number File
# grep --include Regex -B Number Number File
# grep --include Regex -B Number -C Number Number File
# grep --include Regex Number File
# grep --include Regex --exclude-from File Number File
# grep --include Regex --exclude-from File -m Number Number File
# grep --include Regex Number File
# grep --include Regex --exclude-from File Number File
# grep --include Regex --exclude-from File --group-separator Regex Number File
# grep --include Regex Number File
# grep --include Regex --exclude-from File Number File
# grep --include Regex --exclude-from File -D Number Number File
# grep --include Regex Number File
# grep --include Regex --exclude-from File Number File
# grep --include Regex --exclude-from File -C Number Number File
# grep --include Regex Number File
# grep --include Regex -m Number Number File
# grep --include Regex -m Number --group-separator Regex Number File
# grep --include Regex Number File
# grep --include Regex -m Number Number File
# grep --include Regex -m Number -D Number Number File
# grep --include Regex Number File
# grep --include Regex -m Number Number File
# grep --include Regex -m Number -C Number Number File
# grep --include Regex Number File
# grep --include Regex --group-separator Regex Number File
# grep --include Regex --group-separator Regex -D Number Number File
# grep --include Regex Number File
# grep --include Regex --group-separator Regex Number File
# grep --include Regex --group-separator Regex -C Number Number File
# grep --include Regex Number File
# grep --include Regex -D Number Number File
# grep --include Regex -D Number -C Number Number File
# grep -B Number Number File
# grep -B Number --exclude-from File Number File
# grep -B Number --exclude-from File -m Number Number File
# grep -B Number Number File
# grep -B Number --exclude-from File Number File
# grep -B Number --exclude-from File --group-separator Regex Number File
# grep -B Number Number File
# grep -B Number --exclude-from File Number File
# grep -B Number --exclude-from File -D Number Number File
# grep -B Number Number File
# grep -B Number --exclude-from File Number File
# grep -B Number --exclude-from File -C Number Number File
# grep -B Number Number File
# grep -B Number -m Number Number File
# grep -B Number -m Number --group-separator Regex Number File
# grep -B Number Number File
# grep -B Number -m Number Number File
# grep -B Number -m Number -D Number Number File
# grep -B Number Number File
# grep -B Number -m Number Number File
# grep -B Number -m Number -C Number Number File
# grep -B Number Number File
# grep -B Number --group-separator Regex Number File
# grep -B Number --group-separator Regex -D Number Number File
# grep -B Number Number File
# grep -B Number --group-separator Regex Number File
# grep -B Number --group-separator Regex -C Number Number File
# grep -B Number Number File
# grep -B Number -D Number Number File
# grep -B Number -D Number -C Number Number File
# grep --exclude-from File Number File
# grep --exclude-from File -m Number Number File
# grep --exclude-from File -m Number --group-separator Regex Number File
# grep --exclude-from File Number File
# grep --exclude-from File -m Number Number File
# grep --exclude-from File -m Number -D Number Number File
# grep --exclude-from File Number File
# grep --exclude-from File -m Number Number File
# grep --exclude-from File -m Number -C Number Number File
# grep --exclude-from File Number File
# grep --exclude-from File --group-separator Regex Number File
# grep --exclude-from File --group-separator Regex -D Number Number File
# grep --exclude-from File Number File
# grep --exclude-from File --group-separator Regex Number File
# grep --exclude-from File --group-separator Regex -C Number Number File
# grep --exclude-from File Number File
# grep --exclude-from File -D Number Number File
# grep --exclude-from File -D Number -C Number Number File
# grep -m Number Number File
# grep -m Number --group-separator Regex Number File
# grep -m Number --group-separator Regex -D Number Number File
# grep -m Number Number File
# grep -m Number --group-separator Regex Number File
# grep -m Number --group-separator Regex -C Number Number File
# grep -m Number Number File
# grep -m Number -D Number Number File
# grep -m Number -D Number -C Number Number File
# grep --group-separator Regex Number File
# grep --group-separator Regex -D Number Number File
# grep --group-separator Regex -D Number -C Number Number File
